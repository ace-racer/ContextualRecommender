# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors
from sklearn import preprocessing

# %%
# configurations
num_nghbrs = 5
stream_tag_frequency_location = "data/tag_frequency_streams.csv"
knn_columns_to_select = ["StreamID"]
min_distance_threshold = 0
nearest_neighbors_streams_output_file = "data/nearest_neighbor_streams.csv"
# end of configurations 

# constants
NEWLINE = "\n"
# end of constants

# %%
def getColumnNames():
        """Get the column names for the output file"""
        column_names = ""

        # Generate column names for the target from the test data
        for column in knn_columns_to_select:
            column_names += "Target " + column + ","


        for itr in range(0, num_nghbrs):
            for column in knn_columns_to_select:
                column_names += "Neighbour " + str(itr + 1) + " " + column + ","

        column_names += "\n"
        return column_names

# %%
def tag_distance(x, y):
    """Get the tag distance between the records x and y"""
    num_tags = len(x)
    print("Num tags x: " + str(num_tags))
    print("Num tags y: " + str(len(y)))
    print(x)
    print(y)
    c1 = 0
    c2 = 0
    for itr in range(0, num_tags):
        if x[itr] == '1' and x[itr] == y[itr]:
            c1 += 1
        elif x[itr] != y[itr]:
            c2 += 1
    distance = -(100*c1 - c2)
    return distance

# %%
stream_tag_frequencies = None
with open(stream_tag_frequency_location, "r") as fr:
    stream_tag_frequencies = [line.strip().split(",") for line in fr.readlines()]

# remove the first column for stream IDs
num_tags = len(stream_tag_frequencies[0]) - 1

# remove the first row for headers
num_streams = len(stream_tag_frequencies) - 1

print("# Tags: " + str(num_tags))
print("# Streams: " + str(num_streams))
# Out:
# # Tags: 67
# # Streams: 582

# %%
HIGH_VALUE = 1000000

nearest_neighbors_content = getColumnNames()

for stream_row_num in range(1,num_streams + 1):
    stream_id = stream_tag_frequencies[stream_row_num][0]
    stream_tag_frequencies = stream_tag_frequencies[stream_row_num][1:]
    nearest_neighbors_content += stream_id + ","
    print("Source stream: " + stream_id)
    distances = []
    
    for other_stream_row_num in range(1,num_streams + 1):
        # Get the required values from the other stream row
        other_stream_id = stream_tag_frequencies[other_stream_row_num][0]
        print("Other stream row number: " + stream_tag_frequencies[1][0])
        other_stream_tag_frequencies = stream_tag_frequencies[other_stream_row_num][1:]
        print("    Current stream: " + other_stream_id)
            
        if other_stream_row_num != stream_row_num:
            distance = tag_distance(stream_tag_frequencies, other_stream_tag_frequencies)
            print("    Distance: " + str(distance))
            distances.append((other_stream_id, distance))
        else:
            distances.append((other_stream_id, HIGH_VALUE))
            
    
    sorted(distances, key=lambda x: x[1])
    for idx, stream_id_distance_mapping in enumerate(distances):
        if idx < num_nghbrs:
            nearest_neighbors_content += stream_id + ","
    
    nearest_neighbors_content += NEWLINE
    
with open(nearest_neighbors_streams_output_file, "w") as fw:
    fw.writelines(nearest_neighbors_content)
    
print("Nearest neighbors generated...")
# Out:
# Source stream: 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-85badc439854> in <module>()
#      13
#      14         # Get the required values from the other stream row
# ---> 15         other_stream_id = stream_tag_frequencies[other_stream_row_num][0]
#      16         print("Other stream row number: " + stream_tag_frequencies[1][0])
#      17         other_stream_tag_frequencies = stream_tag_frequencies[other_stream_row_num][1:]
#
# IndexError: string index out of range

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors
from sklearn import preprocessing

# configurations
num_nghbrs = 5
stream_tag_frequency_location = "data/tag_frequency_streams.csv"
knn_columns_to_select = ["StreamID"]
min_distance_threshold = 0
nearest_neighbors_streams_output_file = "data/nearest_neighbor_streams.csv"
# end of configurations

# constants
NEWLINE = "\n"
# end of constants

def getColumnNames():
    """Get the column names for the output file"""
    column_names = ""

    # Generate column names for the target from the test data
    for column in knn_columns_to_select:
        column_names += "Target " + column + ","

    for itr in range(0, num_nghbrs):
        for column in knn_columns_to_select:
            column_names += "Neighbour " + str(itr + 1) + " " + column + ","

    column_names += "\n"
    return column_names

def tag_distance(x, y):
    """Get the tag distance between the records x and y"""
    num_tags = len(x)
    c1 = 0
    c2 = 0
    for itr in range(0, num_tags):
        if x[itr] == '1' and x[itr] == y[itr]:
            c1 += 1
        elif x[itr] != y[itr]:
            c2 += 1
    distance = -(100*c1 - c2)
    return distance

stream_tag_frequencies = None
with open(stream_tag_frequency_location, "r") as fr:
    stream_tag_frequencies = [line.strip().split(",") for line in fr.readlines()]

# remove the first column for stream IDs
num_tags = len(stream_tag_frequencies[0]) - 1

# remove the first row for headers
num_streams = len(stream_tag_frequencies) - 1

print("# Tags: " + str(num_tags))
print("# Streams: " + str(num_streams))

HIGH_VALUE = 1000000

nearest_neighbors_content = getColumnNames()

print("Value: " + stream_tag_frequencies[1][0])

for stream_row_num in range(1, num_streams + 1):
    stream_id = stream_tag_frequencies[stream_row_num][0]
    source_stream_tag_frequencies = stream_tag_frequencies[stream_row_num][1:]
    nearest_neighbors_content += stream_id + ","
    print("Source stream: " + stream_id)
    distances = []

    for other_stream_row_num in range(1, num_streams + 1):
        # Get the required values from the other stream row
        other_stream_id = stream_tag_frequencies[other_stream_row_num][0]
        other_stream_tag_frequencies = stream_tag_frequencies[other_stream_row_num][1:]
        # print("    Current stream: " + other_stream_id)

        if other_stream_row_num != stream_row_num:
            distance = tag_distance(source_stream_tag_frequencies, other_stream_tag_frequencies)
            #print("    Distance: " + str(distance))
            distances.append((other_stream_id, distance))
        else:
            distances.append((other_stream_id, HIGH_VALUE))

    idx = 0
    distances = sorted(distances, key=lambda x: x[1])
    for stream_id_distance_mapping in distances:
        if idx < num_nghbrs:
            print("    Distance: " + str(stream_id_distance_mapping[1]))
            nearest_neighbors_content += stream_id_distance_mapping[0] + ","
            idx += 1
        else:
            break

    nearest_neighbors_content += NEWLINE

with open(nearest_neighbors_streams_output_file, "w") as fw:
    fw.writelines(nearest_neighbors_content)

print("Nearest neighbors generated...")
# Out:
# # Tags: 67
# # Streams: 582
# Value: 580
# Source stream: 580
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 581
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 582
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 584
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 585
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 587
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 588
#     Distance: -393
#     Distance: -292
#     Distance: -292
#     Distance: -292
#     Distance: -291
# Source stream: 665
#     Distance: -297
#     Distance: -294
#     Distance: -294
#     Distance: -196
#     Distance: -196
# Source stream: 666
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 667
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 668
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 669
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 670
#     Distance: -197
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -195
# Source stream: 671
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 672
#     Distance: -396
#     Distance: -394
#     Distance: -295
#     Distance: -295
#     Distance: -294
# Source stream: 673
#     Distance: -294
#     Distance: -294
#     Distance: -294
#     Distance: -294
#     Distance: -293
# Source stream: 674
#     Distance: -396
#     Distance: -395
#     Distance: -294
#     Distance: -294
#     Distance: -293
# Source stream: 675
#     Distance: -197
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -195
# Source stream: 676
#     Distance: -395
#     Distance: -395
#     Distance: -295
#     Distance: -294
#     Distance: -294
# Source stream: 677
#     Distance: -298
#     Distance: -297
#     Distance: -295
#     Distance: -295
#     Distance: -197
# Source stream: 678
#     Distance: -197
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -194
# Source stream: 679
#     Distance: -295
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -194
# Source stream: 680
#     Distance: -395
#     Distance: -293
#     Distance: -293
#     Distance: -292
#     Distance: -292
# Source stream: 681
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -195
#     Distance: -194
# Source stream: 683
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 684
#     Distance: -198
#     Distance: -198
#     Distance: -197
#     Distance: -197
#     Distance: -196
# Source stream: 702
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 704
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 705
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 706
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 707
#     Distance: -296
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -195
# Source stream: 708
#     Distance: -294
#     Distance: -293
#     Distance: -293
#     Distance: -292
#     Distance: -292
# Source stream: 709
#     Distance: -295
#     Distance: -295
#     Distance: -293
#     Distance: -194
#     Distance: -193
# Source stream: 710
#     Distance: -198
#     Distance: -198
#     Distance: -197
#     Distance: -197
#     Distance: -196
# Source stream: 711
#     Distance: -395
#     Distance: -295
#     Distance: -195
#     Distance: -195
#     Distance: -195
# Source stream: 712
#     Distance: -196
#     Distance: -195
#     Distance: -194
#     Distance: -194
#     Distance: -194
# Source stream: 713
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 714
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 715
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 716
#     Distance: -197
#     Distance: -195
#     Distance: -194
#     Distance: -191
#     Distance: -98
# Source stream: 717
#     Distance: -197
#     Distance: -195
#     Distance: -195
#     Distance: -194
#     Distance: -194
# Source stream: 718
#     Distance: -197
#     Distance: -197
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 719
#     Distance: -294
#     Distance: -293
#     Distance: -293
#     Distance: -293
#     Distance: -292
# Source stream: 720
#     Distance: -294
#     Distance: -293
#     Distance: -293
#     Distance: -195
#     Distance: -195
# Source stream: 721
#     Distance: -195
#     Distance: -195
#     Distance: -195
#     Distance: -195
#     Distance: -98
# Source stream: 724
#     Distance: -292
#     Distance: -292
#     Distance: -194
#     Distance: -193
#     Distance: -193
# Source stream: 725
#     Distance: -194
#     Distance: -98
#     Distance: -98
#     Distance: -98
#     Distance: -98
# Source stream: 726
#     Distance: -194
#     Distance: -194
#     Distance: -194
#     Distance: -193
#     Distance: -193
# Source stream: 727
#     Distance: -196
#     Distance: -195
#     Distance: -193
#     Distance: -193
#     Distance: -97
# Source stream: 728
#     Distance: -397
#     Distance: -296
#     Distance: -293
#     Distance: -293
#     Distance: -194
# Source stream: 729
#     Distance: -394
#     Distance: -293
#     Distance: -292
#     Distance: -289
#     Distance: -194
# Source stream: 730
#     Distance: -295
#     Distance: -294
#     Distance: -293
#     Distance: -293
#     Distance: -293
# Source stream: 731
#     Distance: -296
#     Distance: -294
#     Distance: -293
#     Distance: -293
#     Distance: -293
# Source stream: 732
#     Distance: -196
#     Distance: -196
#     Distance: -196
#     Distance: -195
#     Distance: -195
# Source stream: 733
#     Distance: -394
#     Distance: -394
#     Distance: -294
#     Distance: -293
#     Distance: -292
# Source stream: 734
#     Distance: -198
#     Distance: -195
#     Distance: -195
#     Distance: -194
#     Distance: -194
# Source stream: 735
#     Distance: -197
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -195
# Source stream: 736
#     Distance: -296
#     Distance: -197
#     Distance: -197
#     Distance: -196
#     Distance: -196
# Source stream: 737
#     Distance: -394
#     Distance: -294
#     Distance: -292
#     Distance: -290
#     Distance: -194
# Source stream: 738
#     Distance: -298
#     Distance: -198
#     Distance: -197
#     Distance: -197
#     Distance: -197
# Source stream: 739
#     Distance: -297
#     Distance: -297
#     Distance: -294
#     Distance: -294
#     Distance: -294
# Source stream: 740
#     Distance: -296
#     Distance: -295
#     Distance: -294
#     Distance: -294
#     Distance: -196
# Source stream: 741
#     Distance: -198
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -195
# Source stream: 758
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 759
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 760
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 761
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 762
#     Distance: -198
#     Distance: -198
#     Distance: -196
#     Distance: -196
#     Distance: -195
# Source stream: 763
#     Distance: -296
#     Distance: -294
#     Distance: -294
#     Distance: -196
#     Distance: -195
# Source stream: 765
#     Distance: -195
#     Distance: -195
#     Distance: -194
#     Distance: -194
#     Distance: -194
# Source stream: 766
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 767
#     Distance: -198
#     Distance: -198
#     Distance: -196
#     Distance: -194
#     Distance: -98
# Source stream: 772
#     Distance: -197
#     Distance: -196
#     Distance: -196
#     Distance: -196
#     Distance: -195
# Source stream: 773
#     Distance: -197
#     Distance: -197
#     Distance: -196
#     Distance: -195
#     Distance: -195
# Source stream: 775
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 776
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 777
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 778
#     Distance: -296
#     Distance: -197
#     Distance: -195
#     Distance: -194
#     Distance: -194
# Source stream: 779
#     Distance: -294
#     Distance: -293
#     Distance: -293
#     Distance: -293
#     Distance: -195
# Source stream: 780
#     Distance: -294
#     Distance: -294
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 781
#     Distance: -295
#     Distance: -196
#     Distance: -196
#     Distance: -196
#     Distance: -195
# Source stream: 782
#     Distance: -293
#     Distance: -293
#     Distance: -195
#     Distance: -195
#     Distance: -194
# Source stream: 783
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 784
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 785
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 786
#     Distance: -294
#     Distance: -294
#     Distance: -294
#     Distance: -294
#     Distance: -293
# Source stream: 787
#     Distance: -198
#     Distance: -198
#     Distance: -195
#     Distance: -195
#     Distance: -195
# Source stream: 788
#     Distance: -295
#     Distance: -295
#     Distance: -294
#     Distance: -294
#     Distance: -293
# Source stream: 789
#     Distance: -396
#     Distance: -294
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 790
#     Distance: -294
#     Distance: -293
#     Distance: -293
#     Distance: -293
#     Distance: -293
# Source stream: 791
#     Distance: -395
#     Distance: -295
#     Distance: -295
#     Distance: -294
#     Distance: -294
# Source stream: 802
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 803
#     Distance: -294
#     Distance: -294
#     Distance: -196
#     Distance: -196
#     Distance: -195
# Source stream: 805
#     Distance: -294
#     Distance: -294
#     Distance: -294
#     Distance: -293
#     Distance: -293
# Source stream: 807
#     Distance: -394
#     Distance: -293
#     Distance: -292
#     Distance: -292
#     Distance: -292
# Source stream: 812
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 817
#     Distance: -296
#     Distance: -198
#     Distance: -198
#     Distance: -198
#     Distance: -198
# Source stream: 827
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 828
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 835
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 838
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 845
#     Distance: -294
#     Distance: -292
#     Distance: -194
#     Distance: -194
#     Distance: -194
# Source stream: 852
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 853
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 855
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 860
#     Distance: -293
#     Distance: -194
#     Distance: -194
#     Distance: -193
#     Distance: -193
# Source stream: 861
#     Distance: -297
#     Distance: -194
#     Distance: -194
#     Distance: -193
#     Distance: -193
# Source stream: 862
#     Distance: -295
#     Distance: -295
#     Distance: -197
#     Distance: -197
#     Distance: -196
# Source stream: 879
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 883
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 884
#     Distance: -296
#     Distance: -198
#     Distance: -198
#     Distance: -198
#     Distance: -197
# Source stream: 885
#     Distance: -295
#     Distance: -196
#     Distance: -196
#     Distance: -196
#     Distance: -195
# Source stream: 886
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -196
# Source stream: 887
#     Distance: -295
#     Distance: -294
#     Distance: -294
#     Distance: -196
#     Distance: -196
# Source stream: 888
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 889
#     Distance: -397
#     Distance: -296
#     Distance: -293
#     Distance: -293
#     Distance: -195
# Source stream: 890
#     Distance: -294
#     Distance: -294
#     Distance: -293
#     Distance: -195
#     Distance: -195
# Source stream: 891
#     Distance: -198
#     Distance: -196
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 892
#     Distance: -296
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -194
# Source stream: 893
#     Distance: -198
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -197
# Source stream: 894
#     Distance: -198
#     Distance: -197
#     Distance: -197
#     Distance: -194
#     Distance: -194
# Source stream: 895
#     Distance: -294
#     Distance: -196
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 896
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 897
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 898
#     Distance: -197
#     Distance: -197
#     Distance: -196
#     Distance: -196
#     Distance: -195
# Source stream: 899
#     Distance: -296
#     Distance: -295
#     Distance: -197
#     Distance: -196
#     Distance: -196
# Source stream: 900
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 901
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 902
#     Distance: -297
#     Distance: -197
#     Distance: -197
#     Distance: -196
#     Distance: -196
# Source stream: 904
#     Distance: -294
#     Distance: -294
#     Distance: -293
#     Distance: -195
#     Distance: -195
# Source stream: 905
#     Distance: -296
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -196
# Source stream: 906
#     Distance: -198
#     Distance: -198
#     Distance: -197
#     Distance: -197
#     Distance: -196
# Source stream: 907
#     Distance: -295
#     Distance: -197
#     Distance: -196
#     Distance: -196
#     Distance: -195
# Source stream: 908
#     Distance: -296
#     Distance: -294
#     Distance: -294
#     Distance: -294
#     Distance: -292
# Source stream: 909
#     Distance: -197
#     Distance: -196
#     Distance: -196
#     Distance: -194
#     Distance: -194
# Source stream: 911
#     Distance: -197
#     Distance: -195
#     Distance: -195
#     Distance: -195
#     Distance: -194
# Source stream: 912
#     Distance: -296
#     Distance: -296
#     Distance: -295
#     Distance: -196
#     Distance: -195
# Source stream: 913
#     Distance: -198
#     Distance: -198
#     Distance: -197
#     Distance: -197
#     Distance: -196
# Source stream: 914
#     Distance: -195
#     Distance: -194
#     Distance: -193
#     Distance: -193
#     Distance: -193
# Source stream: 915
#     Distance: -196
#     Distance: -194
#     Distance: -194
#     Distance: -98
#     Distance: -98
# Source stream: 916
#     Distance: -197
#     Distance: -194
#     Distance: -194
#     Distance: -194
#     Distance: -193
# Source stream: 917
#     Distance: -296
#     Distance: -197
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 919
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 921
#     Distance: -195
#     Distance: -194
#     Distance: -194
#     Distance: -193
#     Distance: -192
# Source stream: 922
#     Distance: -292
#     Distance: -194
#     Distance: -193
#     Distance: -193
#     Distance: -193
# Source stream: 923
#     Distance: -292
#     Distance: -194
#     Distance: -194
#     Distance: -193
#     Distance: -193
# Source stream: 924
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 925
#     Distance: -396
#     Distance: -295
#     Distance: -294
#     Distance: -293
#     Distance: -293
# Source stream: 927
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 928
#     Distance: -395
#     Distance: -295
#     Distance: -294
#     Distance: -293
#     Distance: -293
# Source stream: 929
#     Distance: -296
#     Distance: -295
#     Distance: -197
#     Distance: -197
#     Distance: -197
# Source stream: 930
#     Distance: -198
#     Distance: -195
#     Distance: -194
#     Distance: -194
#     Distance: -194
# Source stream: 931
#     Distance: -196
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -195
# Source stream: 932
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 933
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 934
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 935
#     Distance: -297
#     Distance: -296
#     Distance: -296
#     Distance: -294
#     Distance: -294
# Source stream: 936
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 937
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 938
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 939
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 940
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 941
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 942
#     Distance: -293
#     Distance: -293
#     Distance: -194
#     Distance: -194
#     Distance: -194
# Source stream: 943
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 945
#     Distance: -296
#     Distance: -295
#     Distance: -197
#     Distance: -196
#     Distance: -196
# Source stream: 950
#     Distance: -294
#     Distance: -294
#     Distance: -293
#     Distance: -293
#     Distance: -293
# Source stream: 954
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 955
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 956
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 957
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 958
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 959
#     Distance: -295
#     Distance: -197
#     Distance: -197
#     Distance: -195
#     Distance: -195
# Source stream: 961
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 962
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 963
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 964
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 965
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 972
#     Distance: -198
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -196
# Source stream: 975
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 976
#     Distance: -394
#     Distance: -295
#     Distance: -294
#     Distance: -294
#     Distance: -292
# Source stream: 977
#     Distance: -294
#     Distance: -294
#     Distance: -293
#     Distance: -293
#     Distance: -293
# Source stream: 978
#     Distance: -197
#     Distance: -196
#     Distance: -195
#     Distance: -191
#     Distance: -98
# Source stream: 979
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 980
#     Distance: -297
#     Distance: -297
#     Distance: -295
#     Distance: -197
#     Distance: -197
# Source stream: 981
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 982
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 983
#     Distance: -497
#     Distance: -295
#     Distance: -295
#     Distance: -294
#     Distance: -294
# Source stream: 984
#     Distance: -295
#     Distance: -196
#     Distance: -196
#     Distance: -196
#     Distance: -195
# Source stream: 987
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 988
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 989
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 991
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 992
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 994
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 997
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1004
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1005
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1006
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1007
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1008
#     Distance: -295
#     Distance: -295
#     Distance: -294
#     Distance: -292
#     Distance: -194
# Source stream: 1009
#     Distance: -394
#     Distance: -295
#     Distance: -294
#     Distance: -293
#     Distance: -293
# Source stream: 1010
#     Distance: -296
#     Distance: -198
#     Distance: -198
#     Distance: -196
#     Distance: -196
# Source stream: 1011
#     Distance: -297
#     Distance: -197
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 1013
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1014
#     Distance: -197
#     Distance: -197
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 1015
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1016
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1017
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1018
#     Distance: -195
#     Distance: -195
#     Distance: -194
#     Distance: -194
#     Distance: -194
# Source stream: 1022
#     Distance: -294
#     Distance: -293
#     Distance: -195
#     Distance: -195
#     Distance: -195
# Source stream: 1023
#     Distance: -198
#     Distance: -198
#     Distance: -197
#     Distance: -194
#     Distance: -194
# Source stream: 1024
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1025
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1026
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1028
#     Distance: -293
#     Distance: -293
#     Distance: -290
#     Distance: -193
#     Distance: -192
# Source stream: 1031
#     Distance: -397
#     Distance: -295
#     Distance: -295
#     Distance: -294
#     Distance: -195
# Source stream: 1032
#     Distance: -297
#     Distance: -296
#     Distance: -293
#     Distance: -293
#     Distance: -195
# Source stream: 1033
#     Distance: -195
#     Distance: -195
#     Distance: -194
#     Distance: -194
#     Distance: -194
# Source stream: 1035
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1036
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1037
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1038
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1039
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1040
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1041
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1044
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1045
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1046
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1047
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1048
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -196
#     Distance: -195
# Source stream: 1049
#     Distance: -295
#     Distance: -295
#     Distance: -295
#     Distance: -197
#     Distance: -197
# Source stream: 1050
#     Distance: -497
#     Distance: -295
#     Distance: -294
#     Distance: -294
#     Distance: -293
# Source stream: 1051
#     Distance: -198
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -196
# Source stream: 1052
#     Distance: -394
#     Distance: -293
#     Distance: -292
#     Distance: -292
#     Distance: -194
# Source stream: 1053
#     Distance: -295
#     Distance: -295
#     Distance: -294
#     Distance: -294
#     Distance: -293
# Source stream: 1054
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1055
#     Distance: -295
#     Distance: -294
#     Distance: -194
#     Distance: -194
#     Distance: -193
# Source stream: 1056
#     Distance: -396
#     Distance: -297
#     Distance: -294
#     Distance: -196
#     Distance: -196
# Source stream: 1057
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1061
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1062
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1064
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1065
#     Distance: -396
#     Distance: -296
#     Distance: -294
#     Distance: -293
#     Distance: -291
# Source stream: 1066
#     Distance: -297
#     Distance: -197
#     Distance: -197
#     Distance: -196
#     Distance: -196
# Source stream: 1067
#     Distance: -394
#     Distance: -292
#     Distance: -292
#     Distance: -292
#     Distance: -292
# Source stream: 1068
#     Distance: -294
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -194
# Source stream: 1070
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1073
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1075
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1076
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1078
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1079
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1080
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1083
#     Distance: -195
#     Distance: -195
#     Distance: -194
#     Distance: -194
#     Distance: -194
# Source stream: 1084
#     Distance: -195
#     Distance: -193
#     Distance: -193
#     Distance: -193
#     Distance: -193
# Source stream: 1085
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1086
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1087
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1088
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1098
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1099
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1101
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1102
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1104
#     Distance: -295
#     Distance: -294
#     Distance: -294
#     Distance: -196
#     Distance: -196
# Source stream: 1105
#     Distance: -395
#     Distance: -294
#     Distance: -293
#     Distance: -293
#     Distance: -194
# Source stream: 1106
#     Distance: -198
#     Distance: -198
#     Distance: -197
#     Distance: -196
#     Distance: -196
# Source stream: 1107
#     Distance: -296
#     Distance: -196
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 1108
#     Distance: -197
#     Distance: -197
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 1110
#     Distance: -294
#     Distance: -293
#     Distance: -292
#     Distance: -292
#     Distance: -289
# Source stream: 1111
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1113
#     Distance: -295
#     Distance: -294
#     Distance: -293
#     Distance: -293
#     Distance: -292
# Source stream: 1114
#     Distance: -295
#     Distance: -294
#     Distance: -292
#     Distance: -196
#     Distance: -196
# Source stream: 1115
#     Distance: -297
#     Distance: -296
#     Distance: -294
#     Distance: -294
#     Distance: -294
# Source stream: 1116
#     Distance: -198
#     Distance: -198
#     Distance: -198
#     Distance: -197
#     Distance: -196
# Source stream: 1117
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1118
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1121
#     Distance: -296
#     Distance: -296
#     Distance: -295
#     Distance: -294
#     Distance: -196
# Source stream: 1122
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -194
#     Distance: -193
# Source stream: 1129
#     Distance: -97
#     Distance: -97
#     Distance: -97
#     Distance: -97
#     Distance: -95
# Source stream: 1131
#     Distance: -298
#     Distance: -298
#     Distance: -298
#     Distance: -298
#     Distance: -197
# Source stream: 1135
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1139
#     Distance: -390
#     Distance: -293
#     Distance: -292
#     Distance: -291
#     Distance: -290
# Source stream: 1142
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1144
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1149
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -97
#     Distance: -97
# Source stream: 1152
#     Distance: -295
#     Distance: -194
#     Distance: -193
#     Distance: -193
#     Distance: -193
# Source stream: 1155
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1156
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1158
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1160
#     Distance: -394
#     Distance: -394
#     Distance: -295
#     Distance: -295
#     Distance: -295
# Source stream: 1167
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1168
#     Distance: -196
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -195
# Source stream: 1169
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1170
#     Distance: -295
#     Distance: -295
#     Distance: -197
#     Distance: -197
#     Distance: -196
# Source stream: 1171
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1172
#     Distance: -294
#     Distance: -292
#     Distance: -194
#     Distance: -194
#     Distance: -193
# Source stream: 1173
#     Distance: -396
#     Distance: -292
#     Distance: -292
#     Distance: -292
#     Distance: -193
# Source stream: 1174
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1175
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -196
#     Distance: -196
# Source stream: 1179
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1180
#     Distance: -194
#     Distance: -194
#     Distance: -194
#     Distance: -193
#     Distance: -193
# Source stream: 1183
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1184
#     Distance: -294
#     Distance: -294
#     Distance: -196
#     Distance: -196
#     Distance: -194
# Source stream: 1185
#     Distance: -297
#     Distance: -295
#     Distance: -197
#     Distance: -197
#     Distance: -197
# Source stream: 1186
#     Distance: -296
#     Distance: -295
#     Distance: -294
#     Distance: -294
#     Distance: -293
# Source stream: 1188
#     Distance: -396
#     Distance: -296
#     Distance: -294
#     Distance: -294
#     Distance: -294
# Source stream: 1189
#     Distance: -296
#     Distance: -197
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 1190
#     Distance: -298
#     Distance: -296
#     Distance: -196
#     Distance: -195
#     Distance: -195
# Source stream: 1191
#     Distance: -296
#     Distance: -295
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 1192
#     Distance: -294
#     Distance: -294
#     Distance: -196
#     Distance: -195
#     Distance: -194
# Source stream: 1193
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1194
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1195
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1196
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1198
#     Distance: -293
#     Distance: -194
#     Distance: -194
#     Distance: -194
#     Distance: -193
# Source stream: 1207
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1213
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1218
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1219
#     Distance: -296
#     Distance: -295
#     Distance: -294
#     Distance: -294
#     Distance: -293
# Source stream: 1220
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1221
#     Distance: -197
#     Distance: -197
#     Distance: -196
#     Distance: -195
#     Distance: -195
# Source stream: 1223
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1226
#     Distance: -297
#     Distance: -197
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 1227
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1228
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1229
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1232
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1233
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1237
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1238
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1239
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1240
#     Distance: -100
#     Distance: -100
#     Distance: -98
#     Distance: -98
#     Distance: -98
# Source stream: 1243
#     Distance: -294
#     Distance: -195
#     Distance: -195
#     Distance: -194
#     Distance: -194
# Source stream: 1244
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1246
#     Distance: -294
#     Distance: -294
#     Distance: -293
#     Distance: -291
#     Distance: -195
# Source stream: 1247
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1248
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1249
#     Distance: -294
#     Distance: -195
#     Distance: -194
#     Distance: -194
#     Distance: -194
# Source stream: 1252
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1253
#     Distance: -294
#     Distance: -195
#     Distance: -194
#     Distance: -193
#     Distance: -193
# Source stream: 1254
#     Distance: -294
#     Distance: -194
#     Distance: -193
#     Distance: -193
#     Distance: -193
# Source stream: 1263
#     Distance: -295
#     Distance: -293
#     Distance: -293
#     Distance: -293
#     Distance: -293
# Source stream: 1264
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1265
#     Distance: -100
#     Distance: -100
#     Distance: -98
#     Distance: -98
#     Distance: -98
# Source stream: 1266
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1268
#     Distance: -197
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -195
# Source stream: 1270
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1272
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1275
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1278
#     Distance: -295
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -197
# Source stream: 1279
#     Distance: -293
#     Distance: -293
#     Distance: -194
#     Distance: -194
#     Distance: -193
# Source stream: 1281
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1282
#     Distance: -196
#     Distance: -196
#     Distance: -196
#     Distance: -196
#     Distance: -195
# Source stream: 1285
#     Distance: -295
#     Distance: -195
#     Distance: -195
#     Distance: -195
#     Distance: -194
# Source stream: 1289
#     Distance: -294
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -194
# Source stream: 1290
#     Distance: -296
#     Distance: -196
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 1291
#     Distance: -294
#     Distance: -294
#     Distance: -294
#     Distance: -292
#     Distance: -292
# Source stream: 1293
#     Distance: -294
#     Distance: -294
#     Distance: -196
#     Distance: -196
#     Distance: -195
# Source stream: 1299
#     Distance: -498
#     Distance: -395
#     Distance: -294
#     Distance: -293
#     Distance: -293
# Source stream: 1300
#     Distance: -296
#     Distance: -296
#     Distance: -294
#     Distance: -294
#     Distance: -294
# Source stream: 1307
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1308
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1309
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1310
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1311
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1312
#     Distance: -394
#     Distance: -294
#     Distance: -292
#     Distance: -290
#     Distance: -289
# Source stream: 1313
#     Distance: -197
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -195
# Source stream: 1314
#     Distance: -295
#     Distance: -295
#     Distance: -295
#     Distance: -294
#     Distance: -294
# Source stream: 1315
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1316
#     Distance: -296
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -197
# Source stream: 1317
#     Distance: -294
#     Distance: -294
#     Distance: -293
#     Distance: -292
#     Distance: -292
# Source stream: 1319
#     Distance: -100
#     Distance: -98
#     Distance: -98
#     Distance: -98
#     Distance: -98
# Source stream: 1320
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1321
#     Distance: -197
#     Distance: -197
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 1322
#     Distance: -396
#     Distance: -394
#     Distance: -295
#     Distance: -294
#     Distance: -293
# Source stream: 1323
#     Distance: -295
#     Distance: -293
#     Distance: -293
#     Distance: -195
#     Distance: -195
# Source stream: 1324
#     Distance: -296
#     Distance: -293
#     Distance: -293
#     Distance: -293
#     Distance: -293
# Source stream: 1325
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1326
#     Distance: -295
#     Distance: -294
#     Distance: -196
#     Distance: -195
#     Distance: -195
# Source stream: 1327
#     Distance: -293
#     Distance: -293
#     Distance: -195
#     Distance: -195
#     Distance: -194
# Source stream: 1328
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1331
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1333
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1334
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1336
#     Distance: -195
#     Distance: -194
#     Distance: -194
#     Distance: -194
#     Distance: -194
# Source stream: 1337
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -196
#     Distance: -196
# Source stream: 1338
#     Distance: -294
#     Distance: -293
#     Distance: -293
#     Distance: -195
#     Distance: -194
# Source stream: 1341
#     Distance: -295
#     Distance: -294
#     Distance: -294
#     Distance: -294
#     Distance: -293
# Source stream: 1343
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -196
#     Distance: -195
# Source stream: 1344
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1345
#     Distance: -295
#     Distance: -294
#     Distance: -294
#     Distance: -294
#     Distance: -196
# Source stream: 1348
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1349
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1350
#     Distance: -396
#     Distance: -297
#     Distance: -294
#     Distance: -195
#     Distance: -195
# Source stream: 1351
#     Distance: -295
#     Distance: -295
#     Distance: -294
#     Distance: -293
#     Distance: -292
# Source stream: 1352
#     Distance: -397
#     Distance: -295
#     Distance: -294
#     Distance: -196
#     Distance: -195
# Source stream: 1353
#     Distance: -100
#     Distance: -98
#     Distance: -98
#     Distance: -98
#     Distance: -98
# Source stream: 1354
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -97
#     Distance: -97
# Source stream: 1362
#     Distance: -297
#     Distance: -295
#     Distance: -197
#     Distance: -196
#     Distance: -195
# Source stream: 1363
#     Distance: -498
#     Distance: -296
#     Distance: -295
#     Distance: -195
#     Distance: -195
# Source stream: 1365
#     Distance: -196
#     Distance: -196
#     Distance: -195
#     Distance: -194
#     Distance: -194
# Source stream: 1366
#     Distance: -196
#     Distance: -196
#     Distance: -196
#     Distance: -195
#     Distance: -195
# Source stream: 1375
#     Distance: -295
#     Distance: -292
#     Distance: -292
#     Distance: -194
#     Distance: -194
# Source stream: 1376
#     Distance: -396
#     Distance: -294
#     Distance: -294
#     Distance: -196
#     Distance: -196
# Source stream: 1377
#     Distance: -397
#     Distance: -294
#     Distance: -294
#     Distance: -293
#     Distance: -293
# Source stream: 1378
#     Distance: -397
#     Distance: -295
#     Distance: -294
#     Distance: -195
#     Distance: -195
# Source stream: 1379
#     Distance: -295
#     Distance: -294
#     Distance: -294
#     Distance: -292
#     Distance: -292
# Source stream: 1382
#     Distance: -294
#     Distance: -294
#     Distance: -293
#     Distance: -293
#     Distance: -293
# Source stream: 1383
#     Distance: -297
#     Distance: -295
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 1384
#     Distance: -196
#     Distance: -196
#     Distance: -196
#     Distance: -195
#     Distance: -195
# Source stream: 1398
#     Distance: -294
#     Distance: -293
#     Distance: -195
#     Distance: -194
#     Distance: -194
# Source stream: 1399
#     Distance: -297
#     Distance: -198
#     Distance: -198
#     Distance: -197
#     Distance: -197
# Source stream: 1403
#     Distance: -295
#     Distance: -295
#     Distance: -295
#     Distance: -196
#     Distance: -196
# Source stream: 1405
#     Distance: -298
#     Distance: -198
#     Distance: -197
#     Distance: -196
#     Distance: -196
# Source stream: 1406
#     Distance: -197
#     Distance: -196
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 1407
#     Distance: -295
#     Distance: -295
#     Distance: -295
#     Distance: -195
#     Distance: -195
# Source stream: 1408
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -195
#     Distance: -194
# ...
# Source stream: 1435
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1436
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1438
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1439
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1443
#     Distance: -294
#     Distance: -196
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 1451
#     Distance: -197
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -195
# Source stream: 1452
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -196
# Source stream: 1453
#     Distance: -298
#     Distance: -295
#     Distance: -196
#     Distance: -195
#     Distance: -195
# Source stream: 1454
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -196
#     Distance: -196
# Source stream: 1455
#     Distance: -195
#     Distance: -195
#     Distance: -194
#     Distance: -194
#     Distance: -193
# Source stream: 1460
#     Distance: -198
#     Distance: -198
#     Distance: -197
#     Distance: -197
#     Distance: -197
# Source stream: 1461
#     Distance: -196
#     Distance: -196
#     Distance: -196
#     Distance: -195
#     Distance: -195
# Source stream: 1462
#     Distance: -295
#     Distance: -293
#     Distance: -293
#     Distance: -293
#     Distance: -195
# Source stream: 1463
#     Distance: -296
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -195
# Source stream: 1464
#     Distance: -197
#     Distance: -196
#     Distance: -196
#     Distance: -196
#     Distance: -194
# Source stream: 1466
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1467
#     Distance: -396
#     Distance: -394
#     Distance: -295
#     Distance: -293
#     Distance: -292
# Source stream: 1468
#     Distance: -394
#     Distance: -394
#     Distance: -295
#     Distance: -294
#     Distance: -294
# Source stream: 1469
#     Distance: -294
#     Distance: -196
#     Distance: -196
#     Distance: -195
#     Distance: -195
# Source stream: 1470
#     Distance: -197
#     Distance: -196
#     Distance: -194
#     Distance: -98
#     Distance: -98
# Source stream: 1471
#     Distance: -296
#     Distance: -296
#     Distance: -294
#     Distance: -294
#     Distance: -293
# Source stream: 1477
#     Distance: -195
#     Distance: -194
#     Distance: -194
#     Distance: -194
#     Distance: -194
# Source stream: 1480
#     Distance: -296
#     Distance: -294
#     Distance: -293
#     Distance: -194
#     Distance: -194
# Source stream: 1481
#     Distance: -395
#     Distance: -294
#     Distance: -292
#     Distance: -292
#     Distance: -290
# Source stream: 1482
#     Distance: -294
#     Distance: -294
#     Distance: -196
#     Distance: -195
#     Distance: -195
# Source stream: 1487
#     Distance: -295
#     Distance: -294
#     Distance: -294
#     Distance: -293
#     Distance: -195
# Source stream: 1488
#     Distance: -295
#     Distance: -196
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 1490
#     Distance: -198
#     Distance: -197
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 1491
#     Distance: -294
#     Distance: -292
#     Distance: -195
#     Distance: -195
#     Distance: -194
# Source stream: 1492
#     Distance: -297
#     Distance: -296
#     Distance: -294
#     Distance: -291
#     Distance: -195
# Source stream: 1500
#     Distance: -400
#     Distance: -298
#     Distance: -298
#     Distance: -298
#     Distance: -197
# Source stream: 1502
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1503
#     Distance: -293
#     Distance: -292
#     Distance: -292
#     Distance: -292
#     Distance: -292
# Source stream: 1504
#     Distance: -395
#     Distance: -295
#     Distance: -294
#     Distance: -292
#     Distance: -292
# Source stream: 1507
#     Distance: -297
#     Distance: -296
#     Distance: -198
#     Distance: -196
#     Distance: -194
# Source stream: 1508
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -97
#     Distance: -97
# Source stream: 1515
#     Distance: -390
#     Distance: -291
#     Distance: -290
#     Distance: -191
#     Distance: -191
# Source stream: 1526
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1527
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1530
#     Distance: -196
#     Distance: -196
#     Distance: -195
#     Distance: -194
#     Distance: -193
# Source stream: 1538
#     Distance: -198
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -196
# Source stream: 1539
#     Distance: -295
#     Distance: -295
#     Distance: -294
#     Distance: -294
#     Distance: -293
# Source stream: 1541
#     Distance: -297
#     Distance: -294
#     Distance: -293
#     Distance: -293
#     Distance: -290
# Source stream: 1542
#     Distance: -198
#     Distance: -194
#     Distance: -98
#     Distance: -98
#     Distance: -98
# Source stream: 1543
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1544
#     Distance: -294
#     Distance: -195
#     Distance: -194
#     Distance: -194
#     Distance: -193
# Source stream: 1545
#     Distance: -194
#     Distance: -193
#     Distance: -193
#     Distance: -193
#     Distance: -192
# Source stream: 1546
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -194
#     Distance: -194
# Source stream: 1547
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1548
#     Distance: -100
#     Distance: -98
#     Distance: -98
#     Distance: -98
#     Distance: -98
# Source stream: 1550
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1551
#     Distance: -396
#     Distance: -294
#     Distance: -196
#     Distance: -196
#     Distance: -195
# Source stream: 1552
#     Distance: -296
#     Distance: -295
#     Distance: -295
#     Distance: -294
#     Distance: -293
# Source stream: 1553
#     Distance: -294
#     Distance: -292
#     Distance: -194
#     Distance: -194
#     Distance: -194
# Source stream: 1554
#     Distance: -198
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -196
# Source stream: 1555
#     Distance: -294
#     Distance: -291
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 1556
#     Distance: -294
#     Distance: -294
#     Distance: -293
#     Distance: -292
#     Distance: -194
# Source stream: 1557
#     Distance: -297
#     Distance: -295
#     Distance: -295
#     Distance: -295
#     Distance: -295
# Source stream: 1558
#     Distance: -198
#     Distance: -198
#     Distance: -197
#     Distance: -197
#     Distance: -197
# Source stream: 1559
#     Distance: -294
#     Distance: -294
#     Distance: -294
#     Distance: -293
#     Distance: -195
# Source stream: 1560
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1561
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1562
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1563
#     Distance: -293
#     Distance: -195
#     Distance: -194
#     Distance: -193
#     Distance: -193
# Source stream: 1564
#     Distance: -296
#     Distance: -296
#     Distance: -294
#     Distance: -196
#     Distance: -195
# Source stream: 1565
#     Distance: -297
#     Distance: -295
#     Distance: -294
#     Distance: -294
#     Distance: -293
# Source stream: 1568
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1569
#     Distance: -197
#     Distance: -196
#     Distance: -196
#     Distance: -195
#     Distance: -195
# Source stream: 1571
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1572
#     Distance: -196
#     Distance: -196
#     Distance: -196
#     Distance: -195
#     Distance: -194
# Source stream: 1573
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1574
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1577
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1580
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1581
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1584
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1585
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1586
#     Distance: -195
#     Distance: -193
#     Distance: -193
#     Distance: -191
#     Distance: -191
# Source stream: 1587
#     Distance: -197
#     Distance: -197
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 1588
#     Distance: -295
#     Distance: -294
#     Distance: -195
#     Distance: -195
#     Distance: -195
# Source stream: 1589
#     Distance: -294
#     Distance: -294
#     Distance: -294
#     Distance: -196
#     Distance: -196
# Source stream: 1590
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -195
#     Distance: -195
# Source stream: 1591
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1592
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1593
#     Distance: -295
#     Distance: -295
#     Distance: -293
#     Distance: -195
#     Distance: -194
# Source stream: 1594
#     Distance: -198
#     Distance: -196
#     Distance: -194
#     Distance: -98
#     Distance: -98
# Source stream: 1595
#     Distance: -196
#     Distance: -195
#     Distance: -194
#     Distance: -194
#     Distance: -194
# Source stream: 1596
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1597
#     Distance: -295
#     Distance: -197
#     Distance: -197
#     Distance: -196
#     Distance: -196
# Source stream: 1598
#     Distance: -296
#     Distance: -197
#     Distance: -197
#     Distance: -196
#     Distance: -195
# Source stream: 1599
#     Distance: -293
#     Distance: -293
#     Distance: -293
#     Distance: -292
#     Distance: -292
# Source stream: 1600
#     Distance: -197
#     Distance: -197
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 1601
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1602
#     Distance: -294
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -195
# Source stream: 1603
#     Distance: -195
#     Distance: -195
#     Distance: -195
#     Distance: -195
#     Distance: -194
# Source stream: 1604
#     Distance: -298
#     Distance: -298
#     Distance: -298
#     Distance: -298
#     Distance: -197
# Source stream: 1606
#     Distance: -298
#     Distance: -298
#     Distance: -298
#     Distance: -298
#     Distance: -197
# Source stream: 1607
#     Distance: -400
#     Distance: -298
#     Distance: -298
#     Distance: -298
#     Distance: -197
# Source stream: 1610
#     Distance: -296
#     Distance: -295
#     Distance: -294
#     Distance: -292
#     Distance: -292
# Source stream: 1613
#     Distance: -292
#     Distance: -291
#     Distance: -291
#     Distance: -290
#     Distance: -289
# Source stream: 1615
#     Distance: -294
#     Distance: -294
#     Distance: -292
#     Distance: -194
#     Distance: -193
# Source stream: 1617
#     Distance: -198
#     Distance: -196
#     Distance: -196
#     Distance: -196
#     Distance: -195
# Source stream: 1618
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -197
# Source stream: 1619
#     Distance: -197
#     Distance: -197
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 1620
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1622
#     Distance: -296
#     Distance: -295
#     Distance: -294
#     Distance: -293
#     Distance: -292
# Source stream: 1623
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1624
#     Distance: -198
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -197
# Source stream: 1625
#     Distance: -294
#     Distance: -292
#     Distance: -194
#     Distance: -194
#     Distance: -194
# Source stream: 1627
#     Distance: -396
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -194
# Source stream: 1628
#     Distance: -296
#     Distance: -294
#     Distance: -294
#     Distance: -293
#     Distance: -291
# Source stream: 1629
#     Distance: -292
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -196
# Source stream: 1630
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1631
#     Distance: -293
#     Distance: -293
#     Distance: -292
#     Distance: -292
#     Distance: -289
# Source stream: 1634
#     Distance: -198
#     Distance: -197
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 1637
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1638
#     Distance: -295
#     Distance: -294
#     Distance: -294
#     Distance: -293
#     Distance: -293
# Source stream: 1639
#     Distance: -100
#     Distance: -98
#     Distance: -98
#     Distance: -98
#     Distance: -98
# Source stream: 1641
#     Distance: -295
#     Distance: -196
#     Distance: -196
#     Distance: -195
#     Distance: -195
# Source stream: 1642
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -194
#     Distance: -194
# Source stream: 1646
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1647
#     Distance: -295
#     Distance: -295
#     Distance: -294
#     Distance: -293
#     Distance: -292
# Source stream: 1649
#     Distance: -295
#     Distance: -294
#     Distance: -293
#     Distance: -293
#     Distance: -292
# Source stream: 1650
#     Distance: -296
#     Distance: -195
#     Distance: -195
#     Distance: -193
#     Distance: -193
# Source stream: 1651
#     Distance: -195
#     Distance: -194
#     Distance: -194
#     Distance: -98
#     Distance: -98
# Source stream: 1653
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1654
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1656
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -100
# Source stream: 1663
#     Distance: -98
#     Distance: -98
#     Distance: -96
#     Distance: -96
#     Distance: -96
# Source stream: 1664
#     Distance: -394
#     Distance: -294
#     Distance: -293
#     Distance: -293
#     Distance: -292
# Source stream: 1669
#     Distance: -295
#     Distance: -197
#     Distance: -197
#     Distance: -197
#     Distance: -196
# Source stream: 1672
#     Distance: -195
#     Distance: -195
#     Distance: -98
#     Distance: -98
#     Distance: -96
# Source stream: 1676
#     Distance: -100
#     Distance: -100
#     Distance: -100
#     Distance: -97
#     Distance: -97
# Source stream: 1678
#     Distance: -296
#     Distance: -196
#     Distance: -196
#     Distance: -196
#     Distance: -196
# Source stream: 1679
#     Distance: -196
#     Distance: -195
#     Distance: -195
#     Distance: -194
#     Distance: -194
# Source stream: 1683
#     Distance: -100
#     Distance: -100
#     Distance: -98
#     Distance: -98
#     Distance: -98
# Source stream: 1704
#     Distance: -197
#     Distance: -196
#     Distance: -196
#     Distance: -195
#     Distance: -195
# Source stream: 949
#     Distance: -296
#     Distance: -195
#     Distance: -195
#     Distance: -194
#     Distance: -193
# Source stream: 1540
#     Distance: -294
#     Distance: -194
#     Distance: -194
#     Distance: -194
#     Distance: -194
# Nearest neighbors generated...
