# %%
import nltk
import pandas as pd
import numpy as np
from nltk import word_tokenize
from nltk.util import ngrams
from collections import Counter

# %%
def n_gram_generate():
    print("Generate n-gram...")
    complete_stream_details_df = pd.read_csv("/Users/shriyashekhar/Documents/IWork/Data/tag_generation_content/card_module_details_content_extracted.csv", encoding="ISO-8859-1")
    if complete_stream_details_df is not None:
        complete_stream_details_dict = {}
        _stream_id_stream_title_dict = {}
        for _, row in complete_stream_details_df.iterrows():
            stream_id = str(row["DECKID"])
            stream_title = str(row["DECKNAME"])
            row_content = str(row["HTML_CONTENT"])
            if row_content and "nan" not in row_content:
                print(row_content)
                complete_stream_details_dict[stream_id] = row_content
                token = nltk.word_tokenize(row_content)
                bigrams = ngrams(token,2)
                print(Counter(bigrams))
                print('\n')

# %%
bi_gram = n_gram_generate()
bi_gram
# Out:
# Generate n-gram...
# TXmAk2KZAy4
# Counter()
#
#
# TXmAk2KZAy4
# Counter()
#
#
# NMeUjebo1Ac
# Counter()
#
#
# NMeUjebo1Ac
# Counter()
#
#
# wBYKUgUyGWc
# Counter()
#
#
# A team of world-class drivers, powered by Castrol EDGE boosted with Titanium FST, take on a challenge like no other, in complete darkness, in a race against the lights.
# Counter({(',', 'in'): 2, ('A', 'team'): 1, ('team', 'of'): 1, ('of', 'world-class'): 1, ('world-class', 'drivers'): 1, ('drivers', ','): 1, (',', 'powered'): 1, ('powered', 'by'): 1, ('by', 'Castrol'): 1, ('Castrol', 'EDGE'): 1, ('EDGE', 'boosted'): 1, ('boosted', 'with'): 1, ('with', 'Titanium'): 1, ('Titanium', 'FST\x99'): 1, ('FST\x99', ','): 1, (',', 'take'): 1, ('take', 'on'): 1, ('on', 'a'): 1, ('a', 'challenge'): 1, ('challenge', 'like'): 1, ('like', 'no'): 1, ('no', 'other'): 1, ('other', ','): 1, ('in', 'complete'): 1, ('complete', 'darkness'): 1, ('darkness', ','): 1, ('in', 'a'): 1, ('a', 'race'): 1, ('race', 'against'): 1, ('against', 'the'): 1, ('the', 'lights'): 1, ('lights', '.'): 1})
#
#
# EEuTxFhp3go
# Counter()
#
#
# Castrol has launched its strongest ever oil, using TITANIUM Fluid StrengthTHE SET-UPTodays engines are more efficient and more powerful. This has led to the doubling of pressure in the engine, so the oil has to be stronger.THE REASON TO BUYCastrol ed...
# Counter({('Castrol', 'has'): 1, ('has', 'launched'): 1, ('launched', 'its'): 1, ('its', 'strongest'): 1, ('strongest', 'ever'): 1, ('ever', 'oil'): 1, ('oil', ','): 1, (',', 'using'): 1, ('using', 'TITANIUM'): 1, ('TITANIUM', 'Fluid'): 1, ('Fluid', 'StrengthTHE'): 1, ('StrengthTHE', 'SET-UPToday\x92s'): 1, ('SET-UPToday\x92s', 'engines'): 1, ('engines', 'are'): 1, ('are', 'more'): 1, ('more', 'efficient'): 1, ('efficient', 'and'): 1, ('and', 'more'): 1, ('more', 'powerful'): 1, ('powerful', '.'): 1, ('.', 'This'): 1, ('This', 'has'): 1, ('has', 'led'): 1, ('led', 'to'): 1, ('to', 'the'): 1, ('the', 'doubling'): 1, ('doubling', 'of'): 1, ('of', 'pressure'): 1, ('pressure', 'in'): 1, ('in', 'the'): 1, ('the', 'engine'): 1, ('engine', ','): 1, (',', 'so'): 1, ('so', 'the'): 1, ('the', 'oil'): 1, ('oil', 'has'): 1, ('has', 'to'): 1, ('to', 'be'): 1, ('be', 'stronger.THE'): 1, ('stronger.THE', 'REASON'): 1, ('REASON', 'TO'): 1, ('TO', 'BUYCastrol'): 1, ('BUYCastrol', 'ed'): 1, ('ed', '...'): 1})
#
#
# EEuTxFhp3go
# Counter()
#
#
# Castrol has launched its strongest ever oil, using TITANIUM Fluid StrengthTHE SET-UPTodays engines are more efficient and more powerful. This has led to the doubling of pressure in the engine, so the oil has to be stronger.THE REASON TO BUYCastrol ed...
# Counter({('Castrol', 'has'): 1, ('has', 'launched'): 1, ('launched', 'its'): 1, ('its', 'strongest'): 1, ('strongest', 'ever'): 1, ('ever', 'oil'): 1, ('oil', ','): 1, (',', 'using'): 1, ('using', 'TITANIUM'): 1, ('TITANIUM', 'Fluid'): 1, ('Fluid', 'StrengthTHE'): 1, ('StrengthTHE', 'SET-UPToday\x92s'): 1, ('SET-UPToday\x92s', 'engines'): 1, ('engines', 'are'): 1, ('are', 'more'): 1, ('more', 'efficient'): 1, ('efficient', 'and'): 1, ('and', 'more'): 1, ('more', 'powerful'): 1, ('powerful', '.'): 1, ('.', 'This'): 1, ('This', 'has'): 1, ('has', 'led'): 1, ('led', 'to'): 1, ('to', 'the'): 1, ('the', 'doubling'): 1, ('doubling', 'of'): 1, ('of', 'pressure'): 1, ('pressure', 'in'): 1, ('in', 'the'): 1, ('the', 'engine'): 1, ('engine', ','): 1, (',', 'so'): 1, ('so', 'the'): 1, ('the', 'oil'): 1, ('oil', 'has'): 1, ('has', 'to'): 1, ('to', 'be'): 1, ('be', 'stronger.THE'): 1, ('stronger.THE', 'REASON'): 1, ('REASON', 'TO'): 1, ('TO', 'BUYCastrol'): 1, ('BUYCastrol', 'ed'): 1, ('ed', '...'): 1})
#
#
# KiRnvRuFj3I
# Counter()
#
#
# What does it take to be a world-class driver and race your clone? Join neuroscientist Dr. Jack Lewis as he talks about what you need to achieve maximum performance on and off the track.See this before you go for your next market visit ?
# Counter({('What', 'does'): 1, ('does', 'it'): 1, ('it', 'take'): 1, ('take', 'to'): 1, ('to', 'be'): 1, ('be', 'a'): 1, ('a', 'world-class'): 1, ('world-class', 'driver'): 1, ('driver', 'and'): 1, ('and', 'race'): 1, ('race', 'your'): 1, ('your', 'clone'): 1, ('clone', '?'): 1, ('?', 'Join'): 1, ('Join', 'neuroscientist'): 1, ('neuroscientist', 'Dr.'): 1, ('Dr.', 'Jack'): 1, ('Jack', 'Lewis'): 1, ('Lewis', 'as'): 1, ('as', 'he'): 1, ('he', 'talks'): 1, ('talks', 'about'): 1, ('about', 'what'): 1, ('what', 'you'): 1, ('you', 'need'): 1, ('need', 'to'): 1, ('to', 'achieve'): 1, ('achieve', 'maximum'): 1, ('maximum', 'performance'): 1, ('performance', 'on'): 1, ('on', 'and'): 1, ('and', 'off'): 1, ('off', 'the'): 1, ('the', 'track.See'): 1, ('track.See', 'this'): 1, ('this', 'before'): 1, ('before', 'you'): 1, ('you', 'go'): 1, ('go', 'for'): 1, ('for', 'your'): 1, ('your', 'next'): 1, ('next', 'market'): 1, ('market', 'visit'): 1, ('visit', '?'): 1})
#
#
# KiRnvRuFj3I
# Counter()
#
#
# What does it take to be a world-class driver and race your clone? Join neuroscientist Dr. Jack Lewis as he talks about what you need to achieve maximum performance on and off the track.See this before you go for your next market visit ?
# Counter({('What', 'does'): 1, ('does', 'it'): 1, ('it', 'take'): 1, ('take', 'to'): 1, ('to', 'be'): 1, ('be', 'a'): 1, ('a', 'world-class'): 1, ('world-class', 'driver'): 1, ('driver', 'and'): 1, ('and', 'race'): 1, ('race', 'your'): 1, ('your', 'clone'): 1, ('clone', '?'): 1, ('?', 'Join'): 1, ('Join', 'neuroscientist'): 1, ('neuroscientist', 'Dr.'): 1, ('Dr.', 'Jack'): 1, ('Jack', 'Lewis'): 1, ('Lewis', 'as'): 1, ('as', 'he'): 1, ('he', 'talks'): 1, ('talks', 'about'): 1, ('about', 'what'): 1, ('what', 'you'): 1, ('you', 'need'): 1, ('need', 'to'): 1, ('to', 'achieve'): 1, ('achieve', 'maximum'): 1, ('maximum', 'performance'): 1, ('performance', 'on'): 1, ('on', 'and'): 1, ('and', 'off'): 1, ('off', 'the'): 1, ('the', 'track.See'): 1, ('track.See', 'this'): 1, ('this', 'before'): 1, ('before', 'you'): 1, ('you', 'go'): 1, ('go', 'for'): 1, ('for', 'your'): 1, ('your', 'next'): 1, ('next', 'market'): 1, ('market', 'visit'): 1, ('visit', '?'): 1})
#
#
# AHOMxMBs_No
# Counter()
#
#
# Castrol EDGE Titanium Trials Present: Clone Rival. Watch as we clone Aston Martin Vulcan driver, Darren Turner, and pit him against his ultimate rival: himself. Will he have what it takes to be Titanium Strong?Exciting Video?
# Counter({('Castrol', 'EDGE'): 1, ('EDGE', 'Titanium'): 1, ('Titanium', 'Trials'): 1, ('Trials', 'Present'): 1, ('Present', ':'): 1, (':', 'Clone'): 1, ('Clone', 'Rival'): 1, ('Rival', '.'): 1, ('.', 'Watch'): 1, ('Watch', 'as'): 1, ('as', 'we'): 1, ('we', 'clone'): 1, ('clone', 'Aston'): 1, ('Aston', 'Martin'): 1, ('Martin', 'Vulcan'): 1, ('Vulcan', 'driver'): 1, ('driver', ','): 1, (',', 'Darren'): 1, ('Darren', 'Turner'): 1, ('Turner', ','): 1, (',', 'and'): 1, ('and', 'pit'): 1, ('pit', 'him'): 1, ('him', 'against'): 1, ('against', 'his'): 1, ('his', 'ultimate'): 1, ('ultimate', 'rival'): 1, ('rival', ':'): 1, (':', 'himself'): 1, ('himself', '.'): 1, ('.', 'Will'): 1, ('Will', 'he'): 1, ('he', 'have'): 1, ('have', 'what'): 1, ('what', 'it'): 1, ('it', 'takes'): 1, ('takes', 'to'): 1, ('to', 'be'): 1, ('be', 'Titanium'): 1, ('Titanium', 'Strong'): 1, ('Strong', '?'): 1, ('?', 'Exciting'): 1, ('Exciting', 'Video'): 1, ('Video', '?'): 1})
#
#
# AHOMxMBs_No
# Counter()
#
#
# Castrol EDGE Titanium Trials Present: Clone Rival. Watch as we clone Aston Martin Vulcan driver, Darren Turner, and pit him against his ultimate rival: himself. Will he have what it takes to be Titanium Strong?Exciting Video?
# Counter({('Castrol', 'EDGE'): 1, ('EDGE', 'Titanium'): 1, ('Titanium', 'Trials'): 1, ('Trials', 'Present'): 1, ('Present', ':'): 1, (':', 'Clone'): 1, ('Clone', 'Rival'): 1, ('Rival', '.'): 1, ('.', 'Watch'): 1, ('Watch', 'as'): 1, ('as', 'we'): 1, ('we', 'clone'): 1, ('clone', 'Aston'): 1, ('Aston', 'Martin'): 1, ('Martin', 'Vulcan'): 1, ('Vulcan', 'driver'): 1, ('driver', ','): 1, (',', 'Darren'): 1, ('Darren', 'Turner'): 1, ('Turner', ','): 1, (',', 'and'): 1, ('and', 'pit'): 1, ('pit', 'him'): 1, ('him', 'against'): 1, ('against', 'his'): 1, ('his', 'ultimate'): 1, ('ultimate', 'rival'): 1, ('rival', ':'): 1, (':', 'himself'): 1, ('himself', '.'): 1, ('.', 'Will'): 1, ('Will', 'he'): 1, ('he', 'have'): 1, ('have', 'what'): 1, ('what', 'it'): 1, ('it', 'takes'): 1, ('takes', 'to'): 1, ('to', 'be'): 1, ('be', 'Titanium'): 1, ('Titanium', 'Strong'): 1, ('Strong', '?'): 1, ('?', 'Exciting'): 1, ('Exciting', 'Video'): 1, ('Video', '?'): 1})
#
#
# Castrol EDGE  is Castrols flagship power brand for PCOs and was introduced in 2005.  It is a high performance engine oil for high performing vehicles, approved by major OEMs across the world.
# Counter({('Castrol', 'EDGE'): 1, ('EDGE', 'is'): 1, ('is', 'Castrol\x92s'): 1, ('Castrol\x92s', 'flagship'): 1, ('flagship', 'power'): 1, ('power', 'brand'): 1, ('brand', 'for'): 1, ('for', 'PCOs'): 1, ('PCOs', 'and'): 1, ('and', 'was'): 1, ('was', 'introduced'): 1, ('introduced', 'in'): 1, ('in', '2005'): 1, ('2005', '.'): 1, ('.', 'It'): 1, ('It', 'is'): 1, ('is', 'a'): 1, ('a', 'high'): 1, ('high', 'performance'): 1, ('performance', 'engine'): 1, ('engine', 'oil'): 1, ('oil', 'for'): 1, ('for', 'high'): 1, ('high', 'performing'): 1, ('performing', 'vehicles'): 1, ('vehicles', ','): 1, (',', 'approved'): 1, ('approved', 'by'): 1, ('by', 'major'): 1, ('major', 'OEMs'): 1, ('OEMs', 'across'): 1, ('across', 'the'): 1, ('the', 'world'): 1, ('world', '.'): 1})
#
#
# NMeUjebo1Ac
# Counter()
#
#
# Castrol EDGE  unique  TITANIUM FST   doubles oil strength in oil film protection. This makes the oil most equipped to handle the high pressures of engines today.    Watch this video to see how...
# Counter({('Castrol', 'EDGE'): 1, ('EDGE', 'unique'): 1, ('unique', 'TITANIUM'): 1, ('TITANIUM', 'FST\x99'): 1, ('FST\x99', 'doubles'): 1, ('doubles', 'oil'): 1, ('oil', 'strength'): 1, ('strength', 'in'): 1, ('in', 'oil'): 1, ('oil', 'film'): 1, ('film', 'protection'): 1, ('protection', '.'): 1, ('.', 'This'): 1, ('This', 'makes'): 1, ('makes', 'the'): 1, ('the', 'oil'): 1, ('oil', 'most'): 1, ('most', 'equipped'): 1, ('equipped', 'to'): 1, ('to', 'handle'): 1, ('handle', 'the'): 1, ('the', 'high'): 1, ('high', 'pressures'): 1, ('pressures', 'of'): 1, ('of', 'engines'): 1, ('engines', 'today'): 1, ('today', '.'): 1, ('.', 'Watch'): 1, ('Watch', 'this'): 1, ('this', 'video'): 1, ('video', 'to'): 1, ('to', 'see'): 1, ('see', 'how'): 1, ('how', '...'): 1})
#
#
# Today's engines are more efficient and more powerful, which in-turn makes them subject to more pressure.  In some areas, engine pressures are in excess of 10,000kg per square centimetre - thats like balancing five cars on a stiletto hee...
# Counter({('Today', "'s"): 1, ("'s", 'engines'): 1, ('engines', 'are'): 1, ('are', 'more'): 1, ('more', 'efficient'): 1, ('efficient', 'and'): 1, ('and', 'more'): 1, ('more', 'powerful'): 1, ('powerful', ','): 1, (',', 'which'): 1, ('which', 'in-turn'): 1, ('in-turn', 'makes'): 1, ('makes', 'them'): 1, ('them', 'subject'): 1, ('subject', 'to'): 1, ('to', 'more'): 1, ('more', 'pressure'): 1, ('pressure', '.'): 1, ('.', 'In'): 1, ('In', 'some'): 1, ('some', 'areas'): 1, ('areas', ','): 1, (',', 'engine'): 1, ('engine', 'pressures'): 1, ('pressures', 'are'): 1, ('are', 'in'): 1, ('in', 'excess'): 1, ('excess', 'of'): 1, ('of', '10,000kg'): 1, ('10,000kg', 'per'): 1, ('per', 'square'): 1, ('square', 'centimetre'): 1, ('centimetre', '-'): 1, ('-', 'that\x92s'): 1, ('that\x92s', 'like'): 1, ('like', 'balancing'): 1, ('balancing', 'five'): 1, ('five', 'cars'): 1, ('cars', 'on'): 1, ('on', 'a'): 1, ('a', 'stiletto'): 1, ('stiletto', 'hee'): 1, ('hee', '...'): 1})
#
#
# oyCu07ay5ec
# Counter()
#
#
# Watch this video to understand how  Castrol EDGE  has the strength and the technology to handle the pressures of high-performance engines.
# Counter({('Watch', 'this'): 1, ('this', 'video'): 1, ('video', 'to'): 1, ('to', 'understand'): 1, ('understand', 'how'): 1, ('how', 'Castrol'): 1, ('Castrol', 'EDGE'): 1, ('EDGE', 'has'): 1, ('has', 'the'): 1, ('the', 'strength'): 1, ('strength', 'and'): 1, ('and', 'the'): 1, ('the', 'technology'): 1, ('technology', 'to'): 1, ('to', 'handle'): 1, ('handle', 'the'): 1, ('the', 'pressures'): 1, ('pressures', 'of'): 1, ('of', 'high-performance'): 1, ('high-performance', 'engines'): 1, ('engines', '.'): 1})
#
#
# Castrol EDGE  solves the problem of high engine pressures through its  TITANIUM FST (Fluid Strength Technology).    TITANIUM FST   doubles oil strength preventing oil breakdown and sha...
# Counter({('TITANIUM', 'FST\x99'): 2, ('Castrol', 'EDGE'): 1, ('EDGE', 'solves'): 1, ('solves', 'the'): 1, ('the', 'problem'): 1, ('problem', 'of'): 1, ('of', 'high'): 1, ('high', 'engine'): 1, ('engine', 'pressures'): 1, ('pressures', 'through'): 1, ('through', 'its'): 1, ('its', 'TITANIUM'): 1, ('FST\x99', '('): 1, ('(', 'Fluid'): 1, ('Fluid', 'Strength'): 1, ('Strength', 'Technology'): 1, ('Technology', ')'): 1, (')', '.'): 1, ('.', 'TITANIUM'): 1, ('FST\x99', 'doubles'): 1, ('doubles', 'oil'): 1, ('oil', 'strength'): 1, ('strength', 'preventing'): 1, ('preventing', 'oil'): 1, ('oil', 'breakdown'): 1, ('breakdown', 'and'): 1, ('and', 'sha'): 1, ('sha', '...'): 1})
#
#
# TITANIUM FST   continuously responds and adapts to your engine's every need even under the severest possible pressures.  It's designed to minimise metal-to-metal contact, constantly adapting across a variety of engine spee...
# Counter({('TITANIUM', 'FST\x99'): 1, ('FST\x99', 'continuously'): 1, ('continuously', 'responds'): 1, ('responds', 'and'): 1, ('and', 'adapts'): 1, ('adapts', 'to'): 1, ('to', 'your'): 1, ('your', 'engine'): 1, ('engine', "'s"): 1, ("'s", 'every'): 1, ('every', 'need'): 1, ('need', 'even'): 1, ('even', 'under'): 1, ('under', 'the'): 1, ('the', 'severest'): 1, ('severest', 'possible'): 1, ('possible', 'pressures'): 1, ('pressures', '.'): 1, ('.', 'It'): 1, ('It', "'s"): 1, ("'s", 'designed'): 1, ('designed', 'to'): 1, ('to', 'minimise'): 1, ('minimise', 'metal-to-metal'): 1, ('metal-to-metal', 'contact'): 1, ('contact', ','): 1, (',', 'constantly'): 1, ('constantly', 'adapting'): 1, ('adapting', 'across'): 1, ('across', 'a'): 1, ('a', 'variety'): 1, ('variety', 'of'): 1, ('of', 'engine'): 1, ('engine', 'spee'): 1, ('spee', '...'): 1})
#
#
# 1KGh8D0AwBs
# Counter()
#
#
# The Castrol R&amp;D Technology is amongst the best in the world. The Castrol Stress Test here shows how the double film strength of  Castrol EDGE  reduces metal-to-metal contact, making it the strongest oil in the world.
# Counter({('The', 'Castrol'): 2, ('in', 'the'): 2, ('the', 'world'): 2, ('world', '.'): 2, ('Castrol', 'R'): 1, ('R', '&'): 1, ('&', 'amp'): 1, ('amp', ';'): 1, (';', 'D'): 1, ('D', 'Technology'): 1, ('Technology', 'is'): 1, ('is', 'amongst'): 1, ('amongst', 'the'): 1, ('the', 'best'): 1, ('best', 'in'): 1, ('.', 'The'): 1, ('Castrol', 'Stress'): 1, ('Stress', 'Test'): 1, ('Test', 'here'): 1, ('here', 'shows'): 1, ('shows', 'how'): 1, ('how', 'the'): 1, ('the', 'double'): 1, ('double', 'film'): 1, ('film', 'strength'): 1, ('strength', 'of'): 1, ('of', 'Castrol'): 1, ('Castrol', 'EDGE'): 1, ('EDGE', 'reduces'): 1, ('reduces', 'metal-to-metal'): 1, ('metal-to-metal', 'contact'): 1, ('contact', ','): 1, (',', 'making'): 1, ('making', 'it'): 1, ('it', 'the'): 1, ('the', 'strongest'): 1, ('strongest', 'oil'): 1, ('oil', 'in'): 1})
#
#
# Charles Cheers Wakefield, Castrols founder, was an entrepreneur with a vision. In 1899 he started the lubricant business from Cheapside, London. In 1906, he started Castrol, and took a personal interest in the new motorised contrapt...
# Counter({('.', 'In'): 2, ('he', 'started'): 2, ('Charles', '\x93Cheers\x94'): 1, ('\x93Cheers\x94', 'Wakefield'): 1, ('Wakefield', ','): 1, (',', 'Castrol\x92s'): 1, ('Castrol\x92s', 'founder'): 1, ('founder', ','): 1, (',', 'was'): 1, ('was', 'an'): 1, ('an', 'entrepreneur'): 1, ('entrepreneur', 'with'): 1, ('with', 'a'): 1, ('a', 'vision'): 1, ('vision', '.'): 1, ('In', '1899'): 1, ('1899', 'he'): 1, ('started', 'the'): 1, ('the', 'lubricant'): 1, ('lubricant', 'business'): 1, ('business', 'from'): 1, ('from', 'Cheapside'): 1, ('Cheapside', ','): 1, (',', 'London'): 1, ('London', '.'): 1, ('In', '1906'): 1, ('1906', ','): 1, (',', 'he'): 1, ('started', 'Castrol'): 1, ('Castrol', ','): 1, (',', 'and'): 1, ('and', 'took'): 1, ('took', 'a'): 1, ('a', 'personal'): 1, ('personal', 'interest'): 1, ('interest', 'in'): 1, ('in', 'the'): 1, ('the', 'new'): 1, ('new', 'motorised'): 1, ('motorised', 'contrapt'): 1, ('contrapt', '...'): 1})
#
#
# Charles Cheers Wakefield, Castrols founder, was an entrepreneur with a vision. In 1899 he started the lubricant business from Cheapside, London. In 1906, he started Castrol, and took a personal interest in the new motorised contrapt...
# Counter({('.', 'In'): 2, ('he', 'started'): 2, ('Charles', '\x93Cheers\x94'): 1, ('\x93Cheers\x94', 'Wakefield'): 1, ('Wakefield', ','): 1, (',', 'Castrol\x92s'): 1, ('Castrol\x92s', 'founder'): 1, ('founder', ','): 1, (',', 'was'): 1, ('was', 'an'): 1, ('an', 'entrepreneur'): 1, ('entrepreneur', 'with'): 1, ('with', 'a'): 1, ('a', 'vision'): 1, ('vision', '.'): 1, ('In', '1899'): 1, ('1899', 'he'): 1, ('started', 'the'): 1, ('the', 'lubricant'): 1, ('lubricant', 'business'): 1, ('business', 'from'): 1, ('from', 'Cheapside'): 1, ('Cheapside', ','): 1, (',', 'London'): 1, ('London', '.'): 1, ('In', '1906'): 1, ('1906', ','): 1, (',', 'he'): 1, ('started', 'Castrol'): 1, ('Castrol', ','): 1, (',', 'and'): 1, ('and', 'took'): 1, ('took', 'a'): 1, ('a', 'personal'): 1, ('personal', 'interest'): 1, ('interest', 'in'): 1, ('in', 'the'): 1, ('the', 'new'): 1, ('new', 'motorised'): 1, ('motorised', 'contrapt'): 1, ('contrapt', '...'): 1})
#
#
# rpXAV9ybskA
# Counter()
#
#
# Since the 1980s, Castrol has supplied NASA with lubricants for the space shuttle programme. More recently, when NASA's Curiosity rover began its exciting mission on Mars in 2012, Castrol industrial grease played a central role in the smooth opera...
# Counter({(',', 'Castrol'): 2, ('Since', 'the'): 1, ('the', '1980s'): 1, ('1980s', ','): 1, ('Castrol', 'has'): 1, ('has', 'supplied'): 1, ('supplied', 'NASA'): 1, ('NASA', 'with'): 1, ('with', 'lubricants'): 1, ('lubricants', 'for'): 1, ('for', 'the'): 1, ('the', 'space'): 1, ('space', 'shuttle'): 1, ('shuttle', 'programme'): 1, ('programme', '.'): 1, ('.', 'More'): 1, ('More', 'recently'): 1, ('recently', ','): 1, (',', 'when'): 1, ('when', 'NASA'): 1, ('NASA', "'s"): 1, ("'s", 'Curiosity'): 1, ('Curiosity', 'rover'): 1, ('rover', 'began'): 1, ('began', 'its'): 1, ('its', 'exciting'): 1, ('exciting', 'mission'): 1, ('mission', 'on'): 1, ('on', 'Mars'): 1, ('Mars', 'in'): 1, ('in', '2012'): 1, ('2012', ','): 1, ('Castrol', 'industrial'): 1, ('industrial', 'grease'): 1, ('grease', 'played'): 1, ('played', 'a'): 1, ('a', 'central'): 1, ('central', 'role'): 1, ('role', 'in'): 1, ('in', 'the'): 1, ('the', 'smooth'): 1, ('smooth', 'opera'): 1, ('opera', '...'): 1})
#
#
# rpXAV9ybskA
# Counter()
#
#
# Since the 1980s, Castrol has supplied NASA with lubricants for the space shuttle programme. More recently, when NASA's Curiosity rover began its exciting mission on Mars in 2012, Castrol industrial grease played a central role in the smooth opera...
# Counter({(',', 'Castrol'): 2, ('Since', 'the'): 1, ('the', '1980s'): 1, ('1980s', ','): 1, ('Castrol', 'has'): 1, ('has', 'supplied'): 1, ('supplied', 'NASA'): 1, ('NASA', 'with'): 1, ('with', 'lubricants'): 1, ('lubricants', 'for'): 1, ('for', 'the'): 1, ('the', 'space'): 1, ('space', 'shuttle'): 1, ('shuttle', 'programme'): 1, ('programme', '.'): 1, ('.', 'More'): 1, ('More', 'recently'): 1, ('recently', ','): 1, (',', 'when'): 1, ('when', 'NASA'): 1, ('NASA', "'s"): 1, ("'s", 'Curiosity'): 1, ('Curiosity', 'rover'): 1, ('rover', 'began'): 1, ('began', 'its'): 1, ('its', 'exciting'): 1, ('exciting', 'mission'): 1, ('mission', 'on'): 1, ('on', 'Mars'): 1, ('Mars', 'in'): 1, ('in', '2012'): 1, ('2012', ','): 1, ('Castrol', 'industrial'): 1, ('industrial', 'grease'): 1, ('grease', 'played'): 1, ('played', 'a'): 1, ('a', 'central'): 1, ('central', 'role'): 1, ('role', 'in'): 1, ('in', 'the'): 1, ('the', 'smooth'): 1, ('smooth', 'opera'): 1, ('opera', '...'): 1})
#
#
# 9RSWs44PdkE
# Counter()
#
#
# The journey of oil around a car engine takes as little as 5 secs.In this little time, it protects critical engine parts and prevents damage.This short film takes us through this incredible journey.
# Counter({('The', 'journey'): 1, ('journey', 'of'): 1, ('of', 'oil'): 1, ('oil', 'around'): 1, ('around', 'a'): 1, ('a', 'car'): 1, ('car', 'engine'): 1, ('engine', 'takes'): 1, ('takes', 'as'): 1, ('as', 'little'): 1, ('little', 'as'): 1, ('as', '5'): 1, ('5', 'secs.In'): 1, ('secs.In', 'this'): 1, ('this', 'little'): 1, ('little', 'time'): 1, ('time', ','): 1, (',', 'it'): 1, ('it', 'protects'): 1, ('protects', 'critical'): 1, ('critical', 'engine'): 1, ('engine', 'parts'): 1, ('parts', 'and'): 1, ('and', 'prevents'): 1, ('prevents', 'damage.This'): 1, ('damage.This', 'short'): 1, ('short', 'film'): 1, ('film', 'takes'): 1, ('takes', 'us'): 1, ('us', 'through'): 1, ('through', 'this'): 1, ('this', 'incredible'): 1, ('incredible', 'journey'): 1, ('journey', '.'): 1})
#
#
# 9RSWs44PdkE
# Counter()
#
#
# The journey of oil around a car engine takes as little as 5 secs.In this little time, it protects critical engine parts and prevents damage.This short film takes us through this incredible journey.
# Counter({('The', 'journey'): 1, ('journey', 'of'): 1, ('of', 'oil'): 1, ('oil', 'around'): 1, ('around', 'a'): 1, ('a', 'car'): 1, ('car', 'engine'): 1, ('engine', 'takes'): 1, ('takes', 'as'): 1, ('as', 'little'): 1, ('little', 'as'): 1, ('as', '5'): 1, ('5', 'secs.In'): 1, ('secs.In', 'this'): 1, ('this', 'little'): 1, ('little', 'time'): 1, ('time', ','): 1, (',', 'it'): 1, ('it', 'protects'): 1, ('protects', 'critical'): 1, ('critical', 'engine'): 1, ('engine', 'parts'): 1, ('parts', 'and'): 1, ('and', 'prevents'): 1, ('prevents', 'damage.This'): 1, ('damage.This', 'short'): 1, ('short', 'film'): 1, ('film', 'takes'): 1, ('takes', 'us'): 1, ('us', 'through'): 1, ('through', 'this'): 1, ('this', 'incredible'): 1, ('incredible', 'journey'): 1, ('journey', '.'): 1})
#
#
# Maintained Castrol as a seperate brand owing to our heritage and personality
# Counter({('Maintained', 'Castrol'): 1, ('Castrol', 'as'): 1, ('as', 'a'): 1, ('a', 'seperate'): 1, ('seperate', 'brand'): 1, ('brand', 'owing'): 1, ('owing', 'to'): 1, ('to', 'our'): 1, ('our', 'heritage'): 1, ('heritage', 'and'): 1, ('and', 'personality'): 1})
#
#
# Maintained Castrol as a seperate brand owing to our heritage and personality
# Counter({('Maintained', 'Castrol'): 1, ('Castrol', 'as'): 1, ('as', 'a'): 1, ('a', 'seperate'): 1, ('seperate', 'brand'): 1, ('brand', 'owing'): 1, ('owing', 'to'): 1, ('to', 'our'): 1, ('our', 'heritage'): 1, ('heritage', 'and'): 1, ('and', 'personality'): 1})
#
#
# Castrol lubricated the first transatlantic flight
# Counter({('Castrol', 'lubricated'): 1, ('lubricated', 'the'): 1, ('the', 'first'): 1, ('first', 'transatlantic'): 1, ('transatlantic', 'flight'): 1})
#
#
# Castrol played a central role in NASA'S Curiosity rover on Mars in 2012, in the smooth operation of Curiosity's wheels
# Counter({('Castrol', 'played'): 1, ('played', 'a'): 1, ('a', 'central'): 1, ('central', 'role'): 1, ('role', 'in'): 1, ('in', 'NASA'): 1, ('NASA', "'S"): 1, ("'S", 'Curiosity'): 1, ('Curiosity', 'rover'): 1, ('rover', 'on'): 1, ('on', 'Mars'): 1, ('Mars', 'in'): 1, ('in', '2012'): 1, ('2012', ','): 1, (',', 'in'): 1, ('in', 'the'): 1, ('the', 'smooth'): 1, ('smooth', 'operation'): 1, ('operation', 'of'): 1, ('of', 'Curiosity'): 1, ('Curiosity', "'s"): 1, ("'s", 'wheels'): 1})
#
#
# Castrol lubricated the first transatlantic flight
# Counter({('Castrol', 'lubricated'): 1, ('lubricated', 'the'): 1, ('the', 'first'): 1, ('first', 'transatlantic'): 1, ('transatlantic', 'flight'): 1})
#
#
# Castrol played a central role in NASA'S Curiosity rover on Mars in 2012, in the smooth operation of Curiosity's wheels
# Counter({('Castrol', 'played'): 1, ('played', 'a'): 1, ('a', 'central'): 1, ('central', 'role'): 1, ('role', 'in'): 1, ('in', 'NASA'): 1, ('NASA', "'S"): 1, ("'S", 'Curiosity'): 1, ('Curiosity', 'rover'): 1, ('rover', 'on'): 1, ('on', 'Mars'): 1, ('Mars', 'in'): 1, ('in', '2012'): 1, ('2012', ','): 1, (',', 'in'): 1, ('in', 'the'): 1, ('the', 'smooth'): 1, ('smooth', 'operation'): 1, ('operation', 'of'): 1, ('of', 'Curiosity'): 1, ('Curiosity', "'s"): 1, ("'s", 'wheels'): 1})
#
#
# oYMgytE68jo
# Counter()
#
#
# This Stream has information about the  Castrol EDGE  boosted with  TITANIUM FST  brand story?. You will understand  the value of Castrol EDGE to car owners by:   Understanding the engine ...
# Counter({('Castrol', 'EDGE'): 2, ('This', 'Stream'): 1, ('Stream', 'has'): 1, ('has', 'information'): 1, ('information', 'about'): 1, ('about', 'the'): 1, ('the', 'Castrol'): 1, ('EDGE', 'boosted'): 1, ('boosted', 'with'): 1, ('with', 'TITANIUM'): 1, ('TITANIUM', 'FST\x99'): 1, ('FST\x99', 'brand'): 1, ('brand', 'story'): 1, ('story', '?'): 1, ('?', '.'): 1, ('.', 'You'): 1, ('You', 'will'): 1, ('will', 'understand'): 1, ('understand', 'the'): 1, ('the', 'value'): 1, ('value', 'of'): 1, ('of', 'Castrol'): 1, ('EDGE', 'to'): 1, ('to', 'car'): 1, ('car', 'owners'): 1, ('owners', 'by'): 1, ('by', ':'): 1, (':', 'Understanding'): 1, ('Understanding', 'the'): 1, ('the', 'engine'): 1, ('engine', '...'): 1})
#
#
# castrol
# Counter()
#
#
# castrol
# Counter()
#
#
# castrol
# Counter()
#
#
# In this Stream you will find information about Castrol MAGNATEC. In a clear way you will:   Understand the engine problem it is trying to solve  The reasons to believe how  Castrol MAGNATEC  solves the problem
# Counter({('you', 'will'): 2, ('Castrol', 'MAGNATEC'): 2, ('In', 'this'): 1, ('this', 'Stream'): 1, ('Stream', 'you'): 1, ('will', 'find'): 1, ('find', 'information'): 1, ('information', 'about'): 1, ('about', 'Castrol'): 1, ('MAGNATEC', '.'): 1, ('.', 'In'): 1, ('In', 'a'): 1, ('a', 'clear'): 1, ('clear', 'way'): 1, ('way', 'you'): 1, ('will', ':'): 1, (':', 'Understand'): 1, ('Understand', 'the'): 1, ('the', 'engine'): 1, ('engine', 'problem'): 1, ('problem', 'it'): 1, ('it', 'is'): 1, ('is', 'trying'): 1, ('trying', 'to'): 1, ('to', 'solve'): 1, ('solve', 'The'): 1, ('The', 'reasons'): 1, ('reasons', 'to'): 1, ('to', 'believe'): 1, ('believe', 'how'): 1, ('how', 'Castrol'): 1, ('MAGNATEC', 'solves'): 1, ('solves', 'the'): 1, ('the', 'problem'): 1})
#
#
# Castrol MAGNATEC , offers instant protection to an engine, from the moment the engine is started.  This leading Castrol engine oil brand has been helping motorists protect their car engines for almost 20 years.
# Counter({('Castrol', 'MAGNATEC'): 1, ('MAGNATEC', ','): 1, (',', 'offers'): 1, ('offers', 'instant'): 1, ('instant', 'protection'): 1, ('protection', 'to'): 1, ('to', 'an'): 1, ('an', 'engine'): 1, ('engine', ','): 1, (',', 'from'): 1, ('from', 'the'): 1, ('the', 'moment'): 1, ('moment', 'the'): 1, ('the', 'engine'): 1, ('engine', 'is'): 1, ('is', 'started'): 1, ('started', '.'): 1, ('.', 'This'): 1, ('This', 'leading'): 1, ('leading', 'Castrol'): 1, ('Castrol', 'engine'): 1, ('engine', 'oil'): 1, ('oil', 'brand'): 1, ('brand', 'has'): 1, ('has', 'been'): 1, ('been', 'helping'): 1, ('helping', 'motorists'): 1, ('motorists', 'protect'): 1, ('protect', 'their'): 1, ('their', 'car'): 1, ('car', 'engines'): 1, ('engines', 'for'): 1, ('for', 'almost'): 1, ('almost', '20'): 1, ('20', 'years'): 1, ('years', '.'): 1})
#
#
# PD9jKFjREnI
# Counter()
#
#
# Castrol MAGNATECs  intelligent molecules cling to critical engine parts like a MAGNET, giving the engine an extra layer of protection from the start, and throughout warm-up.  Watch this video to see how it works.
# Counter({('Castrol', 'MAGNATEC\x92s'): 1, ('MAGNATEC\x92s', 'intelligent'): 1, ('intelligent', 'molecules'): 1, ('molecules', 'cling'): 1, ('cling', 'to'): 1, ('to', 'critical'): 1, ('critical', 'engine'): 1, ('engine', 'parts'): 1, ('parts', 'like'): 1, ('like', 'a'): 1, ('a', 'MAGNET'): 1, ('MAGNET', ','): 1, (',', 'giving'): 1, ('giving', 'the'): 1, ('the', 'engine'): 1, ('engine', 'an'): 1, ('an', 'extra'): 1, ('extra', 'layer'): 1, ('layer', 'of'): 1, ('of', 'protection'): 1, ('protection', 'from'): 1, ('from', 'the'): 1, ('the', 'start'): 1, ('start', ','): 1, (',', 'and'): 1, ('and', 'throughout'): 1, ('throughout', 'warm-up'): 1, ('warm-up', '.'): 1, ('.', 'Watch'): 1, ('Watch', 'this'): 1, ('this', 'video'): 1, ('video', 'to'): 1, ('to', 'see'): 1, ('see', 'how'): 1, ('how', 'it'): 1, ('it', 'works'): 1, ('works', '.'): 1})
#
#
# CASTROL MAGNATEC     Instant protection from engine wear during warm-up
# Counter({('CASTROL', 'MAGNATEC'): 1, ('MAGNATEC', 'Instant'): 1, ('Instant', 'protection'): 1, ('protection', 'from'): 1, ('from', 'engine'): 1, ('engine', 'wear'): 1, ('wear', 'during'): 1, ('during', 'warm-up'): 1})
#
#
# CASTROL MAGNATEC STOP START   Instant protection from engine wear due to stop start action in high traffic city driving
# Counter({('CASTROL', 'MAGNATEC'): 1, ('MAGNATEC', 'STOP'): 1, ('STOP', 'START'): 1, ('START', 'Instant'): 1, ('Instant', 'protection'): 1, ('protection', 'from'): 1, ('from', 'engine'): 1, ('engine', 'wear'): 1, ('wear', 'due'): 1, ('due', 'to'): 1, ('to', 'stop'): 1, ('stop', 'start'): 1, ('start', 'action'): 1, ('action', 'in'): 1, ('in', 'high'): 1, ('high', 'traffic'): 1, ('traffic', 'city'): 1, ('city', 'driving'): 1})
#
#
# ggY96Ga0ytg
# Counter()
#
#
# When an engine stops, oil drains back to the sump. The next time it starts, it takes about 20 minutes to come to optimum performance temperature.  This is the time when engine damage can happen as critical parts are left exposed. 75%  of eng...
# Counter({('When', 'an'): 1, ('an', 'engine'): 1, ('engine', 'stops'): 1, ('stops', ','): 1, (',', 'oil'): 1, ('oil', 'drains'): 1, ('drains', 'back'): 1, ('back', 'to'): 1, ('to', 'the'): 1, ('the', 'sump'): 1, ('sump', '.'): 1, ('.', 'The'): 1, ('The', 'next'): 1, ('next', 'time'): 1, ('time', 'it'): 1, ('it', 'starts'): 1, ('starts', ','): 1, (',', 'it'): 1, ('it', 'takes'): 1, ('takes', 'about'): 1, ('about', '20'): 1, ('20', 'minutes'): 1, ('minutes', 'to'): 1, ('to', 'come'): 1, ('come', 'to'): 1, ('to', 'optimum'): 1, ('optimum', 'performance'): 1, ('performance', 'temperature'): 1, ('temperature', '.'): 1, ('.', 'This'): 1, ('This', 'is'): 1, ('is', 'the'): 1, ('the', 'time'): 1, ('time', 'when'): 1, ('when', 'engine'): 1, ('engine', 'damage'): 1, ('damage', 'can'): 1, ('can', 'happen'): 1, ('happen', 'as'): 1, ('as', 'critical'): 1, ('critical', 'parts'): 1, ('parts', 'are'): 1, ('are', 'left'): 1, ('left', 'exposed'): 1, ('exposed', '.'): 1, ('.', '75'): 1, ('75', '%'): 1, ('%', 'of'): 1, ('of', 'eng'): 1, ('eng', '...'): 1})
#
#
# The  INTELLIGENT MOLECULES  are specially formulated to cling to critical engine parts like a magnet, providing an extra layer of protection from the start, and throughout warm-up of the engine.
# Counter({('The', 'INTELLIGENT'): 1, ('INTELLIGENT', 'MOLECULES'): 1, ('MOLECULES', 'are'): 1, ('are', 'specially'): 1, ('specially', 'formulated'): 1, ('formulated', 'to'): 1, ('to', 'cling'): 1, ('cling', 'to'): 1, ('to', 'critical'): 1, ('critical', 'engine'): 1, ('engine', 'parts'): 1, ('parts', 'like'): 1, ('like', 'a'): 1, ('a', 'magnet'): 1, ('magnet', ','): 1, (',', 'providing'): 1, ('providing', 'an'): 1, ('an', 'extra'): 1, ('extra', 'layer'): 1, ('layer', 'of'): 1, ('of', 'protection'): 1, ('protection', 'from'): 1, ('from', 'the'): 1, ('the', 'start'): 1, ('start', ','): 1, (',', 'and'): 1, ('and', 'throughout'): 1, ('throughout', 'warm-up'): 1, ('warm-up', 'of'): 1, ('of', 'the'): 1, ('the', 'engine'): 1, ('engine', '.'): 1})
#
#
# Castrol MAGNATEC provides instant protection for engines, right from the moment you start.   Up to 75% of engine wear happens during warm-up. When the engine stops oil drains off critical engine parts, however Castrol MAGNATEC's I...
# Counter({('Castrol', 'MAGNATEC'): 2, ('MAGNATEC', 'provides'): 1, ('provides', 'instant'): 1, ('instant', 'protection'): 1, ('protection', 'for'): 1, ('for', 'engines'): 1, ('engines', ','): 1, (',', 'right'): 1, ('right', 'from'): 1, ('from', 'the'): 1, ('the', 'moment'): 1, ('moment', 'you'): 1, ('you', 'start'): 1, ('start', '.'): 1, ('.', 'Up'): 1, ('Up', 'to'): 1, ('to', '75'): 1, ('75', '%'): 1, ('%', 'of'): 1, ('of', 'engine'): 1, ('engine', 'wear'): 1, ('wear', 'happens'): 1, ('happens', 'during'): 1, ('during', 'warm-up'): 1, ('warm-up', '.'): 1, ('.', 'When'): 1, ('When', 'the'): 1, ('the', 'engine'): 1, ('engine', 'stops'): 1, ('stops', 'oil'): 1, ('oil', 'drains'): 1, ('drains', 'off'): 1, ('off', 'critical'): 1, ('critical', 'engine'): 1, ('engine', 'parts'): 1, ('parts', ','): 1, (',', 'however'): 1, ('however', 'Castrol'): 1, ('MAGNATEC', "'s"): 1, ("'s", 'I'): 1, ('I', '...'): 1})
#
#
# 8hnkexBfJtQ
# Counter()
#
#
# Intelligent molecules cling and form a self healing layer so that it is always ready to protect at each of the critical stages of  STOP START  driving.  Watch the video on how  Castrol MAGNATEC STOP START  works to p...
# Counter({('STOP', 'START'): 2, ('Intelligent', 'molecules'): 1, ('molecules', 'cling'): 1, ('cling', 'and'): 1, ('and', 'form'): 1, ('form', 'a'): 1, ('a', 'self'): 1, ('self', 'healing'): 1, ('healing', 'layer'): 1, ('layer', 'so'): 1, ('so', 'that'): 1, ('that', 'it'): 1, ('it', 'is'): 1, ('is', 'always'): 1, ('always', 'ready'): 1, ('ready', 'to'): 1, ('to', 'protect'): 1, ('protect', 'at'): 1, ('at', 'each'): 1, ('each', 'of'): 1, ('of', 'the'): 1, ('the', 'critical'): 1, ('critical', 'stages'): 1, ('stages', 'of'): 1, ('of', 'STOP'): 1, ('START', 'driving'): 1, ('driving', '.'): 1, ('.', 'Watch'): 1, ('Watch', 'the'): 1, ('the', 'video'): 1, ('video', 'on'): 1, ('on', 'how'): 1, ('how', 'Castrol'): 1, ('Castrol', 'MAGNATEC'): 1, ('MAGNATEC', 'STOP'): 1, ('START', 'works'): 1, ('works', 'to'): 1, ('to', 'p'): 1, ('p', '...'): 1})
#
#
# The gravity defying action of the oil makes it cling to critical engine parts, when the oil drains down, giving an extra layer of protection against engine wear.  It is  combined with synthetic technology to provide increased protecti...
# Counter({('the', 'oil'): 2, ('The', 'gravity'): 1, ('gravity', 'defying'): 1, ('defying', 'action'): 1, ('action', 'of'): 1, ('of', 'the'): 1, ('oil', 'makes'): 1, ('makes', 'it'): 1, ('it', 'cling'): 1, ('cling', 'to'): 1, ('to', 'critical'): 1, ('critical', 'engine'): 1, ('engine', 'parts'): 1, ('parts', ','): 1, (',', 'when'): 1, ('when', 'the'): 1, ('oil', 'drains'): 1, ('drains', 'down'): 1, ('down', ','): 1, (',', 'giving'): 1, ('giving', 'an'): 1, ('an', 'extra'): 1, ('extra', 'layer'): 1, ('layer', 'of'): 1, ('of', 'protection'): 1, ('protection', 'against'): 1, ('against', 'engine'): 1, ('engine', 'wear'): 1, ('wear', '.'): 1, ('.', 'It'): 1, ('It', 'is'): 1, ('is', 'combined'): 1, ('combined', 'with'): 1, ('with', 'synthetic'): 1, ('synthetic', 'technology'): 1, ('technology', 'to'): 1, ('to', 'provide'): 1, ('provide', 'increased'): 1, ('increased', 'protecti'): 1, ('protecti', '...'): 1})
#
#
# In this Stream you will find information about  Castrol GTX  -  Superior Sludge Protection to help extend engine life .    In a clear way, you will:   Understand the engine problem GTX is trying...
# Counter({('you', 'will'): 2, ('In', 'this'): 1, ('this', 'Stream'): 1, ('Stream', 'you'): 1, ('will', 'find'): 1, ('find', 'information'): 1, ('information', 'about'): 1, ('about', 'Castrol'): 1, ('Castrol', 'GTX'): 1, ('GTX', '-'): 1, ('-', 'Superior'): 1, ('Superior', 'Sludge'): 1, ('Sludge', 'Protection'): 1, ('Protection', 'to'): 1, ('to', 'help'): 1, ('help', 'extend'): 1, ('extend', 'engine'): 1, ('engine', 'life'): 1, ('life', '.'): 1, ('.', 'In'): 1, ('In', 'a'): 1, ('a', 'clear'): 1, ('clear', 'way'): 1, ('way', ','): 1, (',', 'you'): 1, ('will', ':'): 1, (':', 'Understand'): 1, ('Understand', 'the'): 1, ('the', 'engine'): 1, ('engine', 'problem'): 1, ('problem', 'GTX'): 1, ('GTX', 'is'): 1, ('is', 'trying'): 1, ('trying', '...'): 1})
#
#
# Castrol GTX  is one of the world's most trusted motor oils. It is liquid engineering that protects against problems, like sludge.  Severe driving conditions such as every day stop-and-go/stop-start-traffic, harsh weather condition...
# Counter({('Castrol', 'GTX'): 1, ('GTX', 'is'): 1, ('is', 'one'): 1, ('one', 'of'): 1, ('of', 'the'): 1, ('the', 'world'): 1, ('world', "'s"): 1, ("'s", 'most'): 1, ('most', 'trusted'): 1, ('trusted', 'motor'): 1, ('motor', 'oils'): 1, ('oils', '.'): 1, ('.', 'It'): 1, ('It', 'is'): 1, ('is', 'liquid'): 1, ('liquid', 'engineering'): 1, ('engineering', 'that'): 1, ('that', 'protects'): 1, ('protects', 'against'): 1, ('against', 'problems'): 1, ('problems', ','): 1, (',', 'like'): 1, ('like', 'sludge'): 1, ('sludge', '.'): 1, ('.', 'Severe'): 1, ('Severe', 'driving'): 1, ('driving', 'conditions'): 1, ('conditions', 'such'): 1, ('such', 'as'): 1, ('as', 'every'): 1, ('every', 'day'): 1, ('day', 'stop-and-go/stop-start-traffic'): 1, ('stop-and-go/stop-start-traffic', ','): 1, (',', 'harsh'): 1, ('harsh', 'weather'): 1, ('weather', 'condition'): 1, ('condition', '...'): 1})
#
#
# 0outa7euRbg
# Counter()
#
#
# Castrol GTX  has a unique Double Action formula that keeps the engine oilways free of dirt formation.  It clears away the dirt particles and prevents the smaller dirt particles to join together and form sludge in the vital oilways...
# Counter({('dirt', 'particles'): 2, ('Castrol', 'GTX'): 1, ('GTX', 'has'): 1, ('has', 'a'): 1, ('a', 'unique'): 1, ('unique', 'Double'): 1, ('Double', 'Action'): 1, ('Action', 'formula'): 1, ('formula', 'that'): 1, ('that', 'keeps'): 1, ('keeps', 'the'): 1, ('the', 'engine'): 1, ('engine', 'oilways'): 1, ('oilways', 'free'): 1, ('free', 'of'): 1, ('of', 'dirt'): 1, ('dirt', 'formation'): 1, ('formation', '.'): 1, ('.', 'It'): 1, ('It', 'clears'): 1, ('clears', 'away'): 1, ('away', 'the'): 1, ('the', 'dirt'): 1, ('particles', 'and'): 1, ('and', 'prevents'): 1, ('prevents', 'the'): 1, ('the', 'smaller'): 1, ('smaller', 'dirt'): 1, ('particles', 'to'): 1, ('to', 'join'): 1, ('join', 'together'): 1, ('together', 'and'): 1, ('and', 'form'): 1, ('form', 'sludge'): 1, ('sludge', 'in'): 1, ('in', 'the'): 1, ('the', 'vital'): 1, ('vital', 'oilways'): 1, ('oilways', '...'): 1})
#
#
# Just like cholesterol, sludge (a thick, tar-like substance) build-up caused by everyday driving clogs important engine parts, even in well-maintained vehicles.   Sludge can block your engines vital oilways  and if untreated, it can rob an e...
# Counter({('Just', 'like'): 1, ('like', 'cholesterol'): 1, ('cholesterol', ','): 1, (',', 'sludge'): 1, ('sludge', '('): 1, ('(', 'a'): 1, ('a', 'thick'): 1, ('thick', ','): 1, (',', 'tar-like'): 1, ('tar-like', 'substance'): 1, ('substance', ')'): 1, (')', 'build-up'): 1, ('build-up', 'caused'): 1, ('caused', 'by'): 1, ('by', 'everyday'): 1, ('everyday', 'driving'): 1, ('driving', 'clogs'): 1, ('clogs', 'important'): 1, ('important', 'engine'): 1, ('engine', 'parts'): 1, ('parts', ','): 1, (',', 'even'): 1, ('even', 'in'): 1, ('in', 'well-maintained'): 1, ('well-maintained', 'vehicles'): 1, ('vehicles', '.'): 1, ('.', 'Sludge'): 1, ('Sludge', 'can'): 1, ('can', 'block'): 1, ('block', 'your'): 1, ('your', 'engine\x92s'): 1, ('engine\x92s', 'vital'): 1, ('vital', 'oilways'): 1, ('oilways', '\x96'): 1, ('\x96', 'and'): 1, ('and', 'if'): 1, ('if', 'untreated'): 1, ('untreated', ','): 1, (',', 'it'): 1, ('it', 'can'): 1, ('can', 'rob'): 1, ('rob', 'an'): 1, ('an', 'e'): 1, ('e', '...'): 1})
#
#
# Castrol GTX DOUBLE ACTION FORMULA  cleans away old sludge, and protects against new sludge formation  better than industry standards.
# Counter({('Castrol', 'GTX'): 1, ('GTX', 'DOUBLE'): 1, ('DOUBLE', 'ACTION'): 1, ('ACTION', 'FORMULA'): 1, ('FORMULA', 'cleans'): 1, ('cleans', 'away'): 1, ('away', 'old'): 1, ('old', 'sludge'): 1, ('sludge', ','): 1, (',', 'and'): 1, ('and', 'protects'): 1, ('protects', 'against'): 1, ('against', 'new'): 1, ('new', 'sludge'): 1, ('sludge', 'formation'): 1, ('formation', '\x96'): 1, ('\x96', 'better'): 1, ('better', 'than'): 1, ('than', 'industry'): 1, ('industry', 'standards'): 1, ('standards', '.'): 1})
#
#
# CASTROL GTX helps extend the life of your engine
# Counter({('CASTROL', 'GTX'): 1, ('GTX', 'helps'): 1, ('helps', 'extend'): 1, ('extend', 'the'): 1, ('the', 'life'): 1, ('life', 'of'): 1, ('of', 'your'): 1, ('your', 'engine'): 1})
#
#
# GTX DOUBLE ACTION FORMULA  reduces sludge and protects against new sludge. This extends the engines life significantly.  Removing sludge is good for the engine because:   It keeps engines cool and clean  It prov...
# Counter({('GTX', 'DOUBLE'): 1, ('DOUBLE', 'ACTION'): 1, ('ACTION', 'FORMULA'): 1, ('FORMULA', 'reduces'): 1, ('reduces', 'sludge'): 1, ('sludge', 'and'): 1, ('and', 'protects'): 1, ('protects', 'against'): 1, ('against', 'new'): 1, ('new', 'sludge'): 1, ('sludge', '.'): 1, ('.', 'This'): 1, ('This', 'extends'): 1, ('extends', 'the'): 1, ('the', 'engine\x92s'): 1, ('engine\x92s', 'life'): 1, ('life', 'significantly'): 1, ('significantly', '.'): 1, ('.', 'Removing'): 1, ('Removing', 'sludge'): 1, ('sludge', 'is'): 1, ('is', 'good'): 1, ('good', 'for'): 1, ('for', 'the'): 1, ('the', 'engine'): 1, ('engine', 'because'): 1, ('because', ':'): 1, (':', 'It'): 1, ('It', 'keeps'): 1, ('keeps', 'engines'): 1, ('engines', 'cool'): 1, ('cool', 'and'): 1, ('and', 'clean'): 1, ('clean', 'It'): 1, ('It', 'prov'): 1, ('prov', '...'): 1})
#
#
# Irv has driven his Volvo the equivalent distance of every stretch of road in the U.S. at least once as well as in 9 foreign countries.     But, throughout the years and over the course of all these miles and countless stops along the way  ...
# Counter({('Irv', 'has'): 1, ('has', 'driven'): 1, ('driven', 'his'): 1, ('his', 'Volvo'): 1, ('Volvo', 'the'): 1, ('the', 'equivalent'): 1, ('equivalent', 'distance'): 1, ('distance', 'of'): 1, ('of', 'every'): 1, ('every', 'stretch'): 1, ('stretch', 'of'): 1, ('of', 'road'): 1, ('road', 'in'): 1, ('in', 'the'): 1, ('the', 'U.S.'): 1, ('U.S.', 'at'): 1, ('at', 'least'): 1, ('least', 'once'): 1, ('once', 'as'): 1, ('as', 'well'): 1, ('well', 'as'): 1, ('as', 'in'): 1, ('in', '9'): 1, ('9', 'foreign'): 1, ('foreign', 'countries'): 1, ('countries', '.'): 1, ('.', 'But'): 1, ('But', ','): 1, (',', 'throughout'): 1, ('throughout', 'the'): 1, ('the', 'years'): 1, ('years', 'and'): 1, ('and', 'over'): 1, ('over', 'the'): 1, ('the', 'course'): 1, ('course', 'of'): 1, ('of', 'all'): 1, ('all', 'these'): 1, ('these', 'miles'): 1, ('miles', 'and'): 1, ('and', 'countless'): 1, ('countless', 'stops'): 1, ('stops', 'along'): 1, ('along', 'the'): 1, ('the', 'way'): 1, ('way', '\x96'): 1, ('\x96', '...'): 1})
#
#
# Simple customer demonstration devices help bring to life the product brand stories and show how Castrol lubricant technology works. The demo devices are intended to offer a compelling visualisation of our technology and help to shift customers from pr...
# Counter({('Simple', 'customer'): 1, ('customer', 'demonstration'): 1, ('demonstration', 'devices'): 1, ('devices', 'help'): 1, ('help', 'bring'): 1, ('bring', 'to'): 1, ('to', 'life'): 1, ('life', 'the'): 1, ('the', 'product'): 1, ('product', 'brand'): 1, ('brand', 'stories'): 1, ('stories', 'and'): 1, ('and', 'show'): 1, ('show', 'how'): 1, ('how', 'Castrol'): 1, ('Castrol', 'lubricant'): 1, ('lubricant', 'technology'): 1, ('technology', 'works'): 1, ('works', '.'): 1, ('.', 'The'): 1, ('The', 'demo'): 1, ('demo', 'devices'): 1, ('devices', 'are'): 1, ('are', 'intended'): 1, ('intended', 'to'): 1, ('to', 'offer'): 1, ('offer', 'a'): 1, ('a', 'compelling'): 1, ('compelling', 'visualisation'): 1, ('visualisation', 'of'): 1, ('of', 'our'): 1, ('our', 'technology'): 1, ('technology', 'and'): 1, ('and', 'help'): 1, ('help', 'to'): 1, ('to', 'shift'): 1, ('shift', 'customers'): 1, ('customers', 'from'): 1, ('from', 'pr'): 1, ('pr', '...'): 1})
#
#
# Engine pressure has almost doubled over the past 30 years, causing more stress on the oil.  With the engine under such pressure customers need an oil that is proven strong and remains strong.?
# Counter({('Engine', 'pressure'): 1, ('pressure', 'has'): 1, ('has', 'almost'): 1, ('almost', 'doubled'): 1, ('doubled', 'over'): 1, ('over', 'the'): 1, ('the', 'past'): 1, ('past', '30'): 1, ('30', 'years'): 1, ('years', ','): 1, (',', 'causing'): 1, ('causing', 'more'): 1, ('more', 'stress'): 1, ('stress', 'on'): 1, ('on', 'the'): 1, ('the', 'oil'): 1, ('oil', '.'): 1, ('.', 'With'): 1, ('With', 'the'): 1, ('the', 'engine'): 1, ('engine', 'under'): 1, ('under', 'such'): 1, ('such', 'pressure'): 1, ('pressure', 'customers'): 1, ('customers', 'need'): 1, ('need', 'an'): 1, ('an', 'oil'): 1, ('oil', 'that'): 1, ('that', 'is'): 1, ('is', 'proven'): 1, ('proven', 'strong'): 1, ('strong', 'and'): 1, ('and', 'remains'): 1, ('remains', 'strong'): 1, ('strong', '.'): 1, ('.', '?'): 1})
#
#
# Castrol EDGE boosted with TITANIUM FST doubles its film strength, preventing oil film breakdown and reducing friction.
# Counter({('Castrol', 'EDGE'): 1, ('EDGE', 'boosted'): 1, ('boosted', 'with'): 1, ('with', 'TITANIUM'): 1, ('TITANIUM', 'FST\x99'): 1, ('FST\x99', 'doubles'): 1, ('doubles', 'its'): 1, ('its', 'film'): 1, ('film', 'strength'): 1, ('strength', ','): 1, (',', 'preventing'): 1, ('preventing', 'oil'): 1, ('oil', 'film'): 1, ('film', 'breakdown'): 1, ('breakdown', 'and'): 1, ('and', 'reducing'): 1, ('reducing', 'friction'): 1, ('friction', '.'): 1})
#
#
# Downsizing, turbocharging and advanced engine designs have now almost doubled engine pressures, causing more stress on the oil.    These higher pressures mean the oil has to work harder to keep apart the met...
# Counter({('the', 'oil'): 2, ('Downsizing', ','): 1, (',', 'turbocharging'): 1, ('turbocharging', 'and'): 1, ('and', 'advanced'): 1, ('advanced', 'engine'): 1, ('engine', 'designs'): 1, ('designs', 'have'): 1, ('have', 'now'): 1, ('now', 'almost'): 1, ('almost', 'doubled'): 1, ('doubled', 'engine'): 1, ('engine', 'pressures'): 1, ('pressures', ','): 1, (',', 'causing'): 1, ('causing', 'more'): 1, ('more', 'stress'): 1, ('stress', 'on'): 1, ('on', 'the'): 1, ('oil', '.'): 1, ('.', 'These'): 1, ('These', 'higher'): 1, ('higher', 'pressures'): 1, ('pressures', 'mean'): 1, ('mean', 'the'): 1, ('oil', 'has'): 1, ('has', 'to'): 1, ('to', 'work'): 1, ('work', 'harder'): 1, ('harder', 'to'): 1, ('to', 'keep'): 1, ('keep', 'apart'): 1, ('apart', 'the'): 1, ('the', 'met'): 1, ('met', '...'): 1})
#
#
# The central lens on the Castrol EDGE Stress Press represents the metal surfaces in an engine.  When you squeeze the handles you are applying pressure to the lens, simulating the pressure applied to engine surfaces when its running.
# Counter({('The', 'central'): 1, ('central', '\x91lens\x92'): 1, ('\x91lens\x92', 'on'): 1, ('on', 'the'): 1, ('the', 'Castrol'): 1, ('Castrol', 'EDGE'): 1, ('EDGE', 'Stress'): 1, ('Stress', 'Press'): 1, ('Press', 'represents'): 1, ('represents', 'the'): 1, ('the', 'metal'): 1, ('metal', 'surfaces'): 1, ('surfaces', 'in'): 1, ('in', 'an'): 1, ('an', 'engine'): 1, ('engine', '.'): 1, ('.', 'When'): 1, ('When', 'you'): 1, ('you', 'squeeze'): 1, ('squeeze', 'the'): 1, ('the', 'handles'): 1, ('handles', 'you'): 1, ('you', 'are'): 1, ('are', 'applying'): 1, ('applying', 'pressure'): 1, ('pressure', 'to'): 1, ('to', 'the'): 1, ('the', 'lens'): 1, ('lens', ','): 1, (',', 'simulating'): 1, ('simulating', 'the'): 1, ('the', 'pressure'): 1, ('pressure', 'applied'): 1, ('applied', 'to'): 1, ('to', 'engine'): 1, ('engine', 'surfaces'): 1, ('surfaces', 'when'): 1, ('when', 'it\x92s'): 1, ('it\x92s', 'running'): 1, ('running', '.'): 1})
#
#
# Up to 75% of engine wear occurs during warm-up.    CASTROL MAGNATEC's molecules cling and protect during warm-up, when the engine needs it most.
# ...
#
#
# Where to find:   The strength of Castrol EDGE stream
# Counter({('Where', 'to'): 1, ('to', 'find'): 1, ('find', ':'): 1, (':', 'The'): 1, ('The', 'strength'): 1, ('strength', 'of'): 1, ('of', 'Castrol'): 1, ('Castrol', 'EDGE'): 1, ('EDGE', 'stream'): 1})
#
#
# Where to find it:   The strength of Castrol EDGE stream
# Counter({('Where', 'to'): 1, ('to', 'find'): 1, ('find', 'it'): 1, ('it', ':'): 1, (':', 'The'): 1, ('The', 'strength'): 1, ('strength', 'of'): 1, ('of', 'Castrol'): 1, ('Castrol', 'EDGE'): 1, ('EDGE', 'stream'): 1})
#
#
# Where to find it:    The strength of Castrol EDGE stream
# Counter({('Where', 'to'): 1, ('to', 'find'): 1, ('find', 'it'): 1, ('it', ':'): 1, (':', 'The'): 1, ('The', 'strength'): 1, ('strength', 'of'): 1, ('of', 'Castrol'): 1, ('Castrol', 'EDGE'): 1, ('EDGE', 'stream'): 1})
#
#
# Where to find it:      The value of Castrol GTX MAGNATEC stream
# Counter({('Where', 'to'): 1, ('to', 'find'): 1, ('find', 'it'): 1, ('it', ':'): 1, (':', 'The'): 1, ('The', 'value'): 1, ('value', 'of'): 1, ('of', 'Castrol'): 1, ('Castrol', 'GTX'): 1, ('GTX', 'MAGNATEC'): 1, ('MAGNATEC', 'stream'): 1})
#
#
# Where to find it:      The value of Castrol GTX MAGNATEC stream
# Counter({('Where', 'to'): 1, ('to', 'find'): 1, ('find', 'it'): 1, ('it', ':'): 1, (':', 'The'): 1, ('The', 'value'): 1, ('value', 'of'): 1, ('of', 'Castrol'): 1, ('Castrol', 'GTX'): 1, ('GTX', 'MAGNATEC'): 1, ('MAGNATEC', 'stream'): 1})
#
#
# Where to find it:   The value of Castrol GTX
# Counter({('Where', 'to'): 1, ('to', 'find'): 1, ('find', 'it'): 1, ('it', ':'): 1, (':', 'The'): 1, ('The', 'value'): 1, ('value', 'of'): 1, ('of', 'Castrol'): 1, ('Castrol', 'GTX'): 1})
#
#
# Where to find it:      The value of Castrol GTX
# Counter({('Where', 'to'): 1, ('to', 'find'): 1, ('find', 'it'): 1, ('it', ':'): 1, (':', 'The'): 1, ('The', 'value'): 1, ('value', 'of'): 1, ('of', 'Castrol'): 1, ('Castrol', 'GTX'): 1})
#
#
# This stream provides you with a quick reference of all the PDFs that are available as attachments on your Castrol Brand Streams.      The PDFs are available for you to share with your customers to leave back as reference to your conv...
# Counter({('are', 'available'): 2, ('This', 'stream'): 1, ('stream', 'provides'): 1, ('provides', 'you'): 1, ('you', 'with'): 1, ('with', 'a'): 1, ('a', 'quick'): 1, ('quick', 'reference'): 1, ('reference', 'of'): 1, ('of', 'all'): 1, ('all', 'the'): 1, ('the', 'PDFs'): 1, ('PDFs', 'that'): 1, ('that', 'are'): 1, ('available', 'as'): 1, ('as', 'attachments'): 1, ('attachments', 'on'): 1, ('on', 'your'): 1, ('your', 'Castrol'): 1, ('Castrol', 'Brand'): 1, ('Brand', 'Streams'): 1, ('Streams', '.'): 1, ('.', 'The'): 1, ('The', 'PDFs'): 1, ('PDFs', 'are'): 1, ('available', 'for'): 1, ('for', 'you'): 1, ('you', 'to'): 1, ('to', 'share'): 1, ('share', 'with'): 1, ('with', 'your'): 1, ('your', 'customers'): 1, ('customers', 'to'): 1, ('to', 'leave'): 1, ('leave', 'back'): 1, ('back', 'as'): 1, ('as', 'reference'): 1, ('reference', 'to'): 1, ('to', 'your'): 1, ('your', 'conv'): 1, ('conv', '...'): 1})
#
#
# Here's a quick summary of what Castrol GTX offers:    Castrol GTX focuses on making engines last longer   Its Double Action Formula removes sludge from critical oilways   Removing sludge keeps engines cool an...
# Counter({('Castrol', 'GTX'): 2, ('Here', "'s"): 1, ("'s", 'a'): 1, ('a', 'quick'): 1, ('quick', 'summary'): 1, ('summary', 'of'): 1, ('of', 'what'): 1, ('what', 'Castrol'): 1, ('GTX', 'offers'): 1, ('offers', ':'): 1, (':', 'Castrol'): 1, ('GTX', 'focuses'): 1, ('focuses', 'on'): 1, ('on', 'making'): 1, ('making', 'engines'): 1, ('engines', 'last'): 1, ('last', 'longer'): 1, ('longer', 'Its'): 1, ('Its', 'Double'): 1, ('Double', 'Action'): 1, ('Action', 'Formula'): 1, ('Formula', 'removes'): 1, ('removes', 'sludge'): 1, ('sludge', 'from'): 1, ('from', 'critical'): 1, ('critical', 'oilways'): 1, ('oilways', 'Removing'): 1, ('Removing', 'sludge'): 1, ('sludge', 'keeps'): 1, ('keeps', 'engines'): 1, ('engines', 'cool'): 1, ('cool', 'an'): 1, ('an', '...'): 1})
#
#
# 0outa7euRbg
# Counter()
#
#
# Castrol GTX  has a unique Double Action formula that keeps the engine oilways free of dirt formation.  It clears away the dirt particles and prevents the smaller dirt particles to join together and form sludge in the vital oilways...
# Counter({('dirt', 'particles'): 2, ('Castrol', 'GTX'): 1, ('GTX', 'has'): 1, ('has', 'a'): 1, ('a', 'unique'): 1, ('unique', 'Double'): 1, ('Double', 'Action'): 1, ('Action', 'formula'): 1, ('formula', 'that'): 1, ('that', 'keeps'): 1, ('keeps', 'the'): 1, ('the', 'engine'): 1, ('engine', 'oilways'): 1, ('oilways', 'free'): 1, ('free', 'of'): 1, ('of', 'dirt'): 1, ('dirt', 'formation'): 1, ('formation', '.'): 1, ('.', 'It'): 1, ('It', 'clears'): 1, ('clears', 'away'): 1, ('away', 'the'): 1, ('the', 'dirt'): 1, ('particles', 'and'): 1, ('and', 'prevents'): 1, ('prevents', 'the'): 1, ('the', 'smaller'): 1, ('smaller', 'dirt'): 1, ('particles', 'to'): 1, ('to', 'join'): 1, ('join', 'together'): 1, ('together', 'and'): 1, ('and', 'form'): 1, ('form', 'sludge'): 1, ('sludge', 'in'): 1, ('in', 'the'): 1, ('the', 'vital'): 1, ('vital', 'oilways'): 1, ('oilways', '...'): 1})
#
#
# Irv Gordon, drove more than 3 million miles, using only Castrol GTX in his Volvo.    Irv began using Castrol GTX as recommended by his dealer in 1968, and has used it ever since.     Castrol GTX
# Counter({('Castrol', 'GTX'): 3, ('Irv', 'Gordon'): 1, ('Gordon', ','): 1, (',', 'drove'): 1, ('drove', 'more'): 1, ('more', 'than'): 1, ('than', '3'): 1, ('3', 'million'): 1, ('million', 'miles'): 1, ('miles', ','): 1, (',', 'using'): 1, ('using', 'only'): 1, ('only', 'Castrol'): 1, ('GTX', 'in'): 1, ('in', 'his'): 1, ('his', 'Volvo'): 1, ('Volvo', '.'): 1, ('.', 'Irv'): 1, ('Irv', 'began'): 1, ('began', 'using'): 1, ('using', 'Castrol'): 1, ('GTX', 'as'): 1, ('as', 'recommended'): 1, ('recommended', 'by'): 1, ('by', 'his'): 1, ('his', 'dealer'): 1, ('dealer', 'in'): 1, ('in', '1968'): 1, ('1968', ','): 1, (',', 'and'): 1, ('and', 'has'): 1, ('has', 'used'): 1, ('used', 'it'): 1, ('it', 'ever'): 1, ('ever', 'since'): 1, ('since', '.'): 1, ('.', 'Castrol'): 1})
#
#
# The Castrol GTX Sludge Tower represents the vital oilways in an engine.  When you turn the demo over, the coloured balls represent the oil trying to flow through the oilways to protect critical engine parts. Sludge gets in the way, and can cause ...
# Counter({('The', 'Castrol'): 1, ('Castrol', 'GTX'): 1, ('GTX', 'Sludge'): 1, ('Sludge', 'Tower'): 1, ('Tower', 'represents'): 1, ('represents', 'the'): 1, ('the', 'vital'): 1, ('vital', 'oilways'): 1, ('oilways', 'in'): 1, ('in', 'an'): 1, ('an', 'engine'): 1, ('engine', '.'): 1, ('.', 'When'): 1, ('When', 'you'): 1, ('you', 'turn'): 1, ('turn', 'the'): 1, ('the', 'demo'): 1, ('demo', 'over'): 1, ('over', ','): 1, (',', 'the'): 1, ('the', 'coloured'): 1, ('coloured', 'balls'): 1, ('balls', 'represent'): 1, ('represent', 'the'): 1, ('the', 'oil'): 1, ('oil', 'trying'): 1, ('trying', 'to'): 1, ('to', 'flow'): 1, ('flow', 'through'): 1, ('through', 'the'): 1, ('the', 'oilways'): 1, ('oilways', 'to'): 1, ('to', 'protect'): 1, ('protect', 'critical'): 1, ('critical', 'engine'): 1, ('engine', 'parts'): 1, ('parts', '.'): 1, ('.', 'Sludge'): 1, ('Sludge', 'gets'): 1, ('gets', 'in'): 1, ('in', 'the'): 1, ('the', 'way'): 1, ('way', ','): 1, (',', 'and'): 1, ('and', 'can'): 1, ('can', 'cause'): 1, ('cause', '...'): 1})
#
#
# _fMBvrSF4pE
# Counter()
#
#
# Watch what Irv Gordon has to say about hitting world records with Castrol GTX.
# Counter({('Watch', 'what'): 1, ('what', 'Irv'): 1, ('Irv', 'Gordon'): 1, ('Gordon', 'has'): 1, ('has', 'to'): 1, ('to', 'say'): 1, ('say', 'about'): 1, ('about', 'hitting'): 1, ('hitting', 'world'): 1, ('world', 'records'): 1, ('records', 'with'): 1, ('with', 'Castrol'): 1, ('Castrol', 'GTX'): 1, ('GTX', '.'): 1})
#
#
# When an engine starts, it takes time to reach the peak protection temperature.  This leaves the engine exposed to damage during warm-up.   75% of engine damage happens during warm-up!
# Counter({('during', 'warm-up'): 2, ('When', 'an'): 1, ('an', 'engine'): 1, ('engine', 'starts'): 1, ('starts', ','): 1, (',', 'it'): 1, ('it', 'takes'): 1, ('takes', 'time'): 1, ('time', 'to'): 1, ('to', 'reach'): 1, ('reach', 'the'): 1, ('the', 'peak'): 1, ('peak', 'protection'): 1, ('protection', 'temperature'): 1, ('temperature', '.'): 1, ('.', 'This'): 1, ('This', 'leaves'): 1, ('leaves', 'the'): 1, ('the', 'engine'): 1, ('engine', 'exposed'): 1, ('exposed', 'to'): 1, ('to', 'damage'): 1, ('damage', 'during'): 1, ('warm-up', '.'): 1, ('.', '75'): 1, ('75', '%'): 1, ('%', 'of'): 1, ('of', 'engine'): 1, ('engine', 'damage'): 1, ('damage', 'happens'): 1, ('happens', 'during'): 1, ('warm-up', '!'): 1})
#
#
# Intelligent molecules are gravity defying so the oil doesn't drain down to the slump.   Synthetic technology provides increased protection in high and low temperature applications.
# Counter({('Intelligent', 'molecules'): 1, ('molecules', 'are'): 1, ('are', 'gravity'): 1, ('gravity', 'defying'): 1, ('defying', 'so'): 1, ('so', 'the'): 1, ('the', 'oil'): 1, ('oil', 'does'): 1, ('does', "n't"): 1, ("n't", 'drain'): 1, ('drain', 'down'): 1, ('down', 'to'): 1, ('to', 'the'): 1, ('the', 'slump'): 1, ('slump', '.'): 1, ('.', 'Synthetic'): 1, ('Synthetic', 'technology'): 1, ('technology', 'provides'): 1, ('provides', 'increased'): 1, ('increased', 'protection'): 1, ('protection', 'in'): 1, ('in', 'high'): 1, ('high', 'and'): 1, ('and', 'low'): 1, ('low', 'temperature'): 1, ('temperature', 'applications'): 1, ('applications', '.'): 1})
#
#
# 75% OF ENGINE WEAR HAPPENS DURING  WARM-UP !
# Counter({('75', '%'): 1, ('%', 'OF'): 1, ('OF', 'ENGINE'): 1, ('ENGINE', 'WEAR'): 1, ('WEAR', 'HAPPENS'): 1, ('HAPPENS', 'DURING'): 1, ('DURING', 'WARM-UP'): 1, ('WARM-UP', '!'): 1})
#
#
# When the engine stops, oil drains back to the sump, so critical engine parts are exposed and not protected by the oil.   This leads to abrasion and major engine wear!
# Counter({('When', 'the'): 1, ('the', 'engine'): 1, ('engine', 'stops'): 1, ('stops', ','): 1, (',', 'oil'): 1, ('oil', 'drains'): 1, ('drains', 'back'): 1, ('back', 'to'): 1, ('to', 'the'): 1, ('the', 'sump'): 1, ('sump', ','): 1, (',', 'so'): 1, ('so', 'critical'): 1, ('critical', 'engine'): 1, ('engine', 'parts'): 1, ('parts', 'are'): 1, ('are', 'exposed'): 1, ('exposed', 'and'): 1, ('and', 'not'): 1, ('not', 'protected'): 1, ('protected', 'by'): 1, ('by', 'the'): 1, ('the', 'oil'): 1, ('oil', '.'): 1, ('.', 'This'): 1, ('This', 'leads'): 1, ('leads', 'to'): 1, ('to', 'abrasion'): 1, ('abrasion', 'and'): 1, ('and', 'major'): 1, ('major', 'engine'): 1, ('engine', 'wear'): 1, ('wear', '!'): 1})
#
#
# Here is your quick summary on what Castrol EDGE is about:   EDGE is designed for todays smaller, more powerful engines   Its special Fluid Titanium Technology has twice the film strength of our previous formula  Strong...
# Counter({('EDGE', 'is'): 2, ('Here', 'is'): 1, ('is', 'your'): 1, ('your', 'quick'): 1, ('quick', 'summary'): 1, ('summary', 'on'): 1, ('on', 'what'): 1, ('what', 'Castrol'): 1, ('Castrol', 'EDGE'): 1, ('is', 'about'): 1, ('about', ':'): 1, (':', 'EDGE'): 1, ('is', 'designed'): 1, ('designed', 'for'): 1, ('for', 'todays'): 1, ('todays', 'smaller'): 1, ('smaller', ','): 1, (',', 'more'): 1, ('more', 'powerful'): 1, ('powerful', 'engines'): 1, ('engines', 'Its'): 1, ('Its', 'special'): 1, ('special', 'Fluid'): 1, ('Fluid', 'Titanium'): 1, ('Titanium', 'Technology'): 1, ('Technology', 'has'): 1, ('has', 'twice'): 1, ('twice', 'the'): 1, ('the', 'film'): 1, ('film', 'strength'): 1, ('strength', 'of'): 1, ('of', 'our'): 1, ('our', 'previous'): 1, ('previous', 'formula'): 1, ('formula', 'Strong'): 1, ('Strong', '...'): 1})
#
#
# Titanium technology  physically changes the way oil  behaves under pressure.     Doubles oil film strength and  prevents oil from breaking down.     Since oil breakdown is prevented, en...
# Counter({('Titanium', 'technology'): 1, ('technology', 'physically'): 1, ('physically', 'changes'): 1, ('changes', 'the'): 1, ('the', 'way'): 1, ('way', 'oil'): 1, ('oil', 'behaves'): 1, ('behaves', 'under'): 1, ('under', 'pressure'): 1, ('pressure', '.'): 1, ('.', 'Doubles'): 1, ('Doubles', 'oil'): 1, ('oil', 'film'): 1, ('film', 'strength'): 1, ('strength', 'and'): 1, ('and', 'prevents'): 1, ('prevents', 'oil'): 1, ('oil', 'from'): 1, ('from', 'breaking'): 1, ('breaking', 'down'): 1, ('down', '.'): 1, ('.', 'Since'): 1, ('Since', 'oil'): 1, ('oil', 'breakdown'): 1, ('breakdown', 'is'): 1, ('is', 'prevented'): 1, ('prevented', ','): 1, (',', 'en'): 1, ('en', '...'): 1})
#
#
# 5HOFO-gLoqo
# Counter()
#
#
# Titanium FST is the secret behind Castrol EDGE's oil strength.  Check out this video to feel the power of Titanium FST.
# Counter({('Titanium', 'FST'): 2, ('FST', 'is'): 1, ('is', 'the'): 1, ('the', 'secret'): 1, ('secret', 'behind'): 1, ('behind', 'Castrol'): 1, ('Castrol', 'EDGE'): 1, ('EDGE', "'s"): 1, ("'s", 'oil'): 1, ('oil', 'strength'): 1, ('strength', '.'): 1, ('.', 'Check'): 1, ('Check', 'out'): 1, ('out', 'this'): 1, ('this', 'video'): 1, ('video', 'to'): 1, ('to', 'feel'): 1, ('feel', 'the'): 1, ('the', 'power'): 1, ('power', 'of'): 1, ('of', 'Titanium'): 1, ('FST', '.'): 1})
#
#
# When the titanium molecule comes under pressure in the engine, it momentarily  stiffens the oil .    When the pressure is relieved, the oil converts back to its usual liquid state.    This momentary s...
# Counter({('When', 'the'): 2, ('the', 'oil'): 2, ('the', 'titanium'): 1, ('titanium', 'molecule'): 1, ('molecule', 'comes'): 1, ('comes', 'under'): 1, ('under', 'pressure'): 1, ('pressure', 'in'): 1, ('in', 'the'): 1, ('the', 'engine'): 1, ('engine', ','): 1, (',', 'it'): 1, ('it', 'momentarily'): 1, ('momentarily', 'stiffens'): 1, ('stiffens', 'the'): 1, ('oil', '.'): 1, ('.', 'When'): 1, ('the', 'pressure'): 1, ('pressure', 'is'): 1, ('is', 'relieved'): 1, ('relieved', ','): 1, (',', 'the'): 1, ('oil', 'converts'): 1, ('converts', 'back'): 1, ('back', 'to'): 1, ('to', 'its'): 1, ('its', 'usual'): 1, ('usual', 'liquid'): 1, ('liquid', 'state'): 1, ('state', '.'): 1, ('.', 'This'): 1, ('This', 'momentary'): 1, ('momentary', 's'): 1, ('s', '...'): 1})
#
#
# Castrol EDGE is  three times stronger against viscosity breakdown  than leading synthetic and conventional oils.  The new formula has two times the film strength as the previous formula.
# Counter({('Castrol', 'EDGE'): 1, ('EDGE', 'is'): 1, ('is', 'three'): 1, ('three', 'times'): 1, ('times', 'stronger'): 1, ('stronger', 'against'): 1, ('against', 'viscosity'): 1, ('viscosity', 'breakdown'): 1, ('breakdown', 'than'): 1, ('than', 'leading'): 1, ('leading', 'synthetic'): 1, ('synthetic', 'and'): 1, ('and', 'conventional'): 1, ('conventional', 'oils'): 1, ('oils', '.'): 1, ('.', 'The'): 1, ('The', 'new'): 1, ('new', 'formula'): 1, ('formula', 'has'): 1, ('has', 'two'): 1, ('two', 'times'): 1, ('times', 'the'): 1, ('the', 'film'): 1, ('film', 'strength'): 1, ('strength', 'as'): 1, ('as', 'the'): 1, ('the', 'previous'): 1, ('previous', 'formula'): 1, ('formula', '.'): 1})

# %%
from nltk import ngrams
import pandas as pd
def n_gram_generate_another_approach():
    complete_stream_details_df = pd.read_csv("/Users/shriyashekhar/Documents/IWork/Data/tag_generation_content/card_module_details_content_extracted.csv", encoding="ISO-8859-1")
    if complete_stream_details_df is not None:
        complete_stream_details_dict = {}
        _stream_id_stream_title_dict = {}
        for _, row in complete_stream_details_df.iterrows():
            stream_id = str(row["DECKID"])
            stream_title = str(row["DECKNAME"])
            row_content = str(row["HTML_CONTENT"])
            if row_content and "nan" not in row_content:
                print(row_content)
                complete_stream_details_dict[stream_id] = row_content
                n = 3
                n_grams = ngrams(row_content.split(), n)
                for grams in n_grams:
                    print(list(grams))
        return grams

# %%
n_gram_op = n_gram_generate_another_approach()
n_gram_op
# Out:
# TXmAk2KZAy4
# TXmAk2KZAy4
# NMeUjebo1Ac
# NMeUjebo1Ac
# wBYKUgUyGWc
# A team of world-class drivers, powered by Castrol EDGE boosted with Titanium FST, take on a challenge like no other, in complete darkness, in a race against the lights.
# ['A', 'team', 'of']
# ['team', 'of', 'world-class']
# ['of', 'world-class', 'drivers,']
# ['world-class', 'drivers,', 'powered']
# ['drivers,', 'powered', 'by']
# ['powered', 'by', 'Castrol']
# ['by', 'Castrol', 'EDGE']
# ['Castrol', 'EDGE', 'boosted']
# ['EDGE', 'boosted', 'with']
# ['boosted', 'with', 'Titanium']
# ['with', 'Titanium', 'FST\x99,']
# ['Titanium', 'FST\x99,', 'take']
# ['FST\x99,', 'take', 'on']
# ['take', 'on', 'a']
# ['on', 'a', 'challenge']
# ['a', 'challenge', 'like']
# ['challenge', 'like', 'no']
# ['like', 'no', 'other,']
# ['no', 'other,', 'in']
# ['other,', 'in', 'complete']
# ['in', 'complete', 'darkness,']
# ['complete', 'darkness,', 'in']
# ['darkness,', 'in', 'a']
# ['in', 'a', 'race']
# ['a', 'race', 'against']
# ['race', 'against', 'the']
# ['against', 'the', 'lights.']
# EEuTxFhp3go
# Castrol has launched its strongest ever oil, using TITANIUM Fluid StrengthTHE SET-UPTodays engines are more efficient and more powerful. This has led to the doubling of pressure in the engine, so the oil has to be stronger.THE REASON TO BUYCastrol ed...
# ['Castrol', 'has', 'launched']
# ['has', 'launched', 'its']
# ['launched', 'its', 'strongest']
# ['its', 'strongest', 'ever']
# ['strongest', 'ever', 'oil,']
# ['ever', 'oil,', 'using']
# ['oil,', 'using', 'TITANIUM']
# ['using', 'TITANIUM', 'Fluid']
# ['TITANIUM', 'Fluid', 'StrengthTHE']
# ['Fluid', 'StrengthTHE', 'SET-UPToday\x92s']
# ['StrengthTHE', 'SET-UPToday\x92s', 'engines']
# ['SET-UPToday\x92s', 'engines', 'are']
# ['engines', 'are', 'more']
# ['are', 'more', 'efficient']
# ['more', 'efficient', 'and']
# ['efficient', 'and', 'more']
# ['and', 'more', 'powerful.']
# ['more', 'powerful.', 'This']
# ['powerful.', 'This', 'has']
# ['This', 'has', 'led']
# ['has', 'led', 'to']
# ['led', 'to', 'the']
# ['to', 'the', 'doubling']
# ['the', 'doubling', 'of']
# ['doubling', 'of', 'pressure']
# ['of', 'pressure', 'in']
# ['pressure', 'in', 'the']
# ['in', 'the', 'engine,']
# ['the', 'engine,', 'so']
# ['engine,', 'so', 'the']
# ['so', 'the', 'oil']
# ['the', 'oil', 'has']
# ['oil', 'has', 'to']
# ['has', 'to', 'be']
# ['to', 'be', 'stronger.THE']
# ['be', 'stronger.THE', 'REASON']
# ['stronger.THE', 'REASON', 'TO']
# ['REASON', 'TO', 'BUYCastrol']
# ['TO', 'BUYCastrol', 'ed...']
# EEuTxFhp3go
# Castrol has launched its strongest ever oil, using TITANIUM Fluid StrengthTHE SET-UPTodays engines are more efficient and more powerful. This has led to the doubling of pressure in the engine, so the oil has to be stronger.THE REASON TO BUYCastrol ed...
# ['Castrol', 'has', 'launched']
# ['has', 'launched', 'its']
# ['launched', 'its', 'strongest']
# ['its', 'strongest', 'ever']
# ['strongest', 'ever', 'oil,']
# ['ever', 'oil,', 'using']
# ['oil,', 'using', 'TITANIUM']
# ['using', 'TITANIUM', 'Fluid']
# ['TITANIUM', 'Fluid', 'StrengthTHE']
# ['Fluid', 'StrengthTHE', 'SET-UPToday\x92s']
# ['StrengthTHE', 'SET-UPToday\x92s', 'engines']
# ['SET-UPToday\x92s', 'engines', 'are']
# ['engines', 'are', 'more']
# ['are', 'more', 'efficient']
# ['more', 'efficient', 'and']
# ['efficient', 'and', 'more']
# ['and', 'more', 'powerful.']
# ['more', 'powerful.', 'This']
# ['powerful.', 'This', 'has']
# ['This', 'has', 'led']
# ['has', 'led', 'to']
# ['led', 'to', 'the']
# ['to', 'the', 'doubling']
# ['the', 'doubling', 'of']
# ['doubling', 'of', 'pressure']
# ['of', 'pressure', 'in']
# ['pressure', 'in', 'the']
# ['in', 'the', 'engine,']
# ['the', 'engine,', 'so']
# ['engine,', 'so', 'the']
# ['so', 'the', 'oil']
# ['the', 'oil', 'has']
# ['oil', 'has', 'to']
# ['has', 'to', 'be']
# ['to', 'be', 'stronger.THE']
# ['be', 'stronger.THE', 'REASON']
# ['stronger.THE', 'REASON', 'TO']
# ['REASON', 'TO', 'BUYCastrol']
# ['TO', 'BUYCastrol', 'ed...']
# KiRnvRuFj3I
# What does it take to be a world-class driver and race your clone? Join neuroscientist Dr. Jack Lewis as he talks about what you need to achieve maximum performance on and off the track.See this before you go for your next market visit ?
# ['What', 'does', 'it']
# ['does', 'it', 'take']
# ['it', 'take', 'to']
# ['take', 'to', 'be']
# ['to', 'be', 'a']
# ['be', 'a', 'world-class']
# ['a', 'world-class', 'driver']
# ['world-class', 'driver', 'and']
# ['driver', 'and', 'race']
# ['and', 'race', 'your']
# ['race', 'your', 'clone?']
# ['your', 'clone?', 'Join']
# ['clone?', 'Join', 'neuroscientist']
# ['Join', 'neuroscientist', 'Dr.']
# ['neuroscientist', 'Dr.', 'Jack']
# ['Dr.', 'Jack', 'Lewis']
# ['Jack', 'Lewis', 'as']
# ['Lewis', 'as', 'he']
# ['as', 'he', 'talks']
# ['he', 'talks', 'about']
# ['talks', 'about', 'what']
# ['about', 'what', 'you']
# ['what', 'you', 'need']
# ['you', 'need', 'to']
# ['need', 'to', 'achieve']
# ['to', 'achieve', 'maximum']
# ['achieve', 'maximum', 'performance']
# ['maximum', 'performance', 'on']
# ['performance', 'on', 'and']
# ['on', 'and', 'off']
# ['and', 'off', 'the']
# ['off', 'the', 'track.See']
# ['the', 'track.See', 'this']
# ['track.See', 'this', 'before']
# ['this', 'before', 'you']
# ['before', 'you', 'go']
# ['you', 'go', 'for']
# ['go', 'for', 'your']
# ['for', 'your', 'next']
# ['your', 'next', 'market']
# ['next', 'market', 'visit']
# ['market', 'visit', '?']
# KiRnvRuFj3I
# What does it take to be a world-class driver and race your clone? Join neuroscientist Dr. Jack Lewis as he talks about what you need to achieve maximum performance on and off the track.See this before you go for your next market visit ?
# ['What', 'does', 'it']
# ['does', 'it', 'take']
# ['it', 'take', 'to']
# ['take', 'to', 'be']
# ['to', 'be', 'a']
# ['be', 'a', 'world-class']
# ['a', 'world-class', 'driver']
# ['world-class', 'driver', 'and']
# ['driver', 'and', 'race']
# ['and', 'race', 'your']
# ['race', 'your', 'clone?']
# ['your', 'clone?', 'Join']
# ['clone?', 'Join', 'neuroscientist']
# ['Join', 'neuroscientist', 'Dr.']
# ['neuroscientist', 'Dr.', 'Jack']
# ['Dr.', 'Jack', 'Lewis']
# ['Jack', 'Lewis', 'as']
# ['Lewis', 'as', 'he']
# ['as', 'he', 'talks']
# ['he', 'talks', 'about']
# ['talks', 'about', 'what']
# ['about', 'what', 'you']
# ['what', 'you', 'need']
# ['you', 'need', 'to']
# ['need', 'to', 'achieve']
# ['to', 'achieve', 'maximum']
# ['achieve', 'maximum', 'performance']
# ['maximum', 'performance', 'on']
# ['performance', 'on', 'and']
# ['on', 'and', 'off']
# ['and', 'off', 'the']
# ['off', 'the', 'track.See']
# ['the', 'track.See', 'this']
# ['track.See', 'this', 'before']
# ['this', 'before', 'you']
# ['before', 'you', 'go']
# ['you', 'go', 'for']
# ['go', 'for', 'your']
# ['for', 'your', 'next']
# ['your', 'next', 'market']
# ['next', 'market', 'visit']
# ['market', 'visit', '?']
# AHOMxMBs_No
# Castrol EDGE Titanium Trials Present: Clone Rival. Watch as we clone Aston Martin Vulcan driver, Darren Turner, and pit him against his ultimate rival: himself. Will he have what it takes to be Titanium Strong?Exciting Video?
# ['Castrol', 'EDGE', 'Titanium']
# ['EDGE', 'Titanium', 'Trials']
# ['Titanium', 'Trials', 'Present:']
# ['Trials', 'Present:', 'Clone']
# ['Present:', 'Clone', 'Rival.']
# ['Clone', 'Rival.', 'Watch']
# ['Rival.', 'Watch', 'as']
# ['Watch', 'as', 'we']
# ['as', 'we', 'clone']
# ['we', 'clone', 'Aston']
# ['clone', 'Aston', 'Martin']
# ['Aston', 'Martin', 'Vulcan']
# ['Martin', 'Vulcan', 'driver,']
# ['Vulcan', 'driver,', 'Darren']
# ['driver,', 'Darren', 'Turner,']
# ['Darren', 'Turner,', 'and']
# ['Turner,', 'and', 'pit']
# ['and', 'pit', 'him']
# ['pit', 'him', 'against']
# ['him', 'against', 'his']
# ['against', 'his', 'ultimate']
# ['his', 'ultimate', 'rival:']
# ['ultimate', 'rival:', 'himself.']
# ['rival:', 'himself.', 'Will']
# ['himself.', 'Will', 'he']
# ['Will', 'he', 'have']
# ['he', 'have', 'what']
# ['have', 'what', 'it']
# ['what', 'it', 'takes']
# ['it', 'takes', 'to']
# ['takes', 'to', 'be']
# ['to', 'be', 'Titanium']
# ['be', 'Titanium', 'Strong?Exciting']
# ['Titanium', 'Strong?Exciting', 'Video?']
# AHOMxMBs_No
# Castrol EDGE Titanium Trials Present: Clone Rival. Watch as we clone Aston Martin Vulcan driver, Darren Turner, and pit him against his ultimate rival: himself. Will he have what it takes to be Titanium Strong?Exciting Video?
# ['Castrol', 'EDGE', 'Titanium']
# ['EDGE', 'Titanium', 'Trials']
# ['Titanium', 'Trials', 'Present:']
# ['Trials', 'Present:', 'Clone']
# ['Present:', 'Clone', 'Rival.']
# ['Clone', 'Rival.', 'Watch']
# ['Rival.', 'Watch', 'as']
# ['Watch', 'as', 'we']
# ['as', 'we', 'clone']
# ['we', 'clone', 'Aston']
# ['clone', 'Aston', 'Martin']
# ['Aston', 'Martin', 'Vulcan']
# ['Martin', 'Vulcan', 'driver,']
# ['Vulcan', 'driver,', 'Darren']
# ['driver,', 'Darren', 'Turner,']
# ['Darren', 'Turner,', 'and']
# ['Turner,', 'and', 'pit']
# ['and', 'pit', 'him']
# ['pit', 'him', 'against']
# ['him', 'against', 'his']
# ['against', 'his', 'ultimate']
# ['his', 'ultimate', 'rival:']
# ['ultimate', 'rival:', 'himself.']
# ['rival:', 'himself.', 'Will']
# ['himself.', 'Will', 'he']
# ['Will', 'he', 'have']
# ['he', 'have', 'what']
# ['have', 'what', 'it']
# ['what', 'it', 'takes']
# ['it', 'takes', 'to']
# ['takes', 'to', 'be']
# ['to', 'be', 'Titanium']
# ['be', 'Titanium', 'Strong?Exciting']
# ['Titanium', 'Strong?Exciting', 'Video?']
# Castrol EDGE  is Castrols flagship power brand for PCOs and was introduced in 2005.  It is a high performance engine oil for high performing vehicles, approved by major OEMs across the world.
# ['Castrol', 'EDGE', 'is']
# ['EDGE', 'is', 'Castrol\x92s']
# ['is', 'Castrol\x92s', 'flagship']
# ['Castrol\x92s', 'flagship', 'power']
# ['flagship', 'power', 'brand']
# ['power', 'brand', 'for']
# ['brand', 'for', 'PCOs']
# ['for', 'PCOs', 'and']
# ['PCOs', 'and', 'was']
# ['and', 'was', 'introduced']
# ['was', 'introduced', 'in']
# ['introduced', 'in', '2005.']
# ['in', '2005.', 'It']
# ['2005.', 'It', 'is']
# ['It', 'is', 'a']
# ['is', 'a', 'high']
# ['a', 'high', 'performance']
# ['high', 'performance', 'engine']
# ['performance', 'engine', 'oil']
# ['engine', 'oil', 'for']
# ['oil', 'for', 'high']
# ['for', 'high', 'performing']
# ['high', 'performing', 'vehicles,']
# ['performing', 'vehicles,', 'approved']
# ['vehicles,', 'approved', 'by']
# ['approved', 'by', 'major']
# ['by', 'major', 'OEMs']
# ['major', 'OEMs', 'across']
# ['OEMs', 'across', 'the']
# ['across', 'the', 'world.']
# NMeUjebo1Ac
# Castrol EDGE  unique  TITANIUM FST   doubles oil strength in oil film protection. This makes the oil most equipped to handle the high pressures of engines today.    Watch this video to see how...
# ['Castrol', 'EDGE', 'unique']
# ['EDGE', 'unique', 'TITANIUM']
# ['unique', 'TITANIUM', 'FST\x99']
# ['TITANIUM', 'FST\x99', 'doubles']
# ['FST\x99', 'doubles', 'oil']
# ['doubles', 'oil', 'strength']
# ['oil', 'strength', 'in']
# ['strength', 'in', 'oil']
# ['in', 'oil', 'film']
# ['oil', 'film', 'protection.']
# ['film', 'protection.', 'This']
# ['protection.', 'This', 'makes']
# ['This', 'makes', 'the']
# ['makes', 'the', 'oil']
# ['the', 'oil', 'most']
# ['oil', 'most', 'equipped']
# ['most', 'equipped', 'to']
# ['equipped', 'to', 'handle']
# ['to', 'handle', 'the']
# ['handle', 'the', 'high']
# ['the', 'high', 'pressures']
# ['high', 'pressures', 'of']
# ['pressures', 'of', 'engines']
# ['of', 'engines', 'today.']
# ['engines', 'today.', 'Watch']
# ['today.', 'Watch', 'this']
# ['Watch', 'this', 'video']
# ['this', 'video', 'to']
# ['video', 'to', 'see']
# ['to', 'see', 'how...']
# Today's engines are more efficient and more powerful, which in-turn makes them subject to more pressure.  In some areas, engine pressures are in excess of 10,000kg per square centimetre - thats like balancing five cars on a stiletto hee...
# ["Today's", 'engines', 'are']
# ['engines', 'are', 'more']
# ['are', 'more', 'efficient']
# ['more', 'efficient', 'and']
# ['efficient', 'and', 'more']
# ['and', 'more', 'powerful,']
# ['more', 'powerful,', 'which']
# ['powerful,', 'which', 'in-turn']
# ['which', 'in-turn', 'makes']
# ['in-turn', 'makes', 'them']
# ['makes', 'them', 'subject']
# ['them', 'subject', 'to']
# ['subject', 'to', 'more']
# ['to', 'more', 'pressure.']
# ['more', 'pressure.', 'In']
# ['pressure.', 'In', 'some']
# ['In', 'some', 'areas,']
# ['some', 'areas,', 'engine']
# ['areas,', 'engine', 'pressures']
# ['engine', 'pressures', 'are']
# ['pressures', 'are', 'in']
# ['are', 'in', 'excess']
# ['in', 'excess', 'of']
# ['excess', 'of', '10,000kg']
# ['of', '10,000kg', 'per']
# ['10,000kg', 'per', 'square']
# ['per', 'square', 'centimetre']
# ['square', 'centimetre', '-']
# ['centimetre', '-', 'that\x92s']
# ['-', 'that\x92s', 'like']
# ['that\x92s', 'like', 'balancing']
# ['like', 'balancing', 'five']
# ['balancing', 'five', 'cars']
# ['five', 'cars', 'on']
# ['cars', 'on', 'a']
# ['on', 'a', 'stiletto']
# ['a', 'stiletto', 'hee...']
# oyCu07ay5ec
# Watch this video to understand how  Castrol EDGE  has the strength and the technology to handle the pressures of high-performance engines.
# ['Watch', 'this', 'video']
# ['this', 'video', 'to']
# ['video', 'to', 'understand']
# ['to', 'understand', 'how']
# ['understand', 'how', 'Castrol']
# ['how', 'Castrol', 'EDGE']
# ['Castrol', 'EDGE', 'has']
# ['EDGE', 'has', 'the']
# ['has', 'the', 'strength']
# ['the', 'strength', 'and']
# ['strength', 'and', 'the']
# ['and', 'the', 'technology']
# ['the', 'technology', 'to']
# ['technology', 'to', 'handle']
# ['to', 'handle', 'the']
# ['handle', 'the', 'pressures']
# ['the', 'pressures', 'of']
# ['pressures', 'of', 'high-performance']
# ['of', 'high-performance', 'engines.']
# Castrol EDGE  solves the problem of high engine pressures through its  TITANIUM FST (Fluid Strength Technology).    TITANIUM FST   doubles oil strength preventing oil breakdown and sha...
# ['Castrol', 'EDGE', 'solves']
# ['EDGE', 'solves', 'the']
# ['solves', 'the', 'problem']
# ['the', 'problem', 'of']
# ['problem', 'of', 'high']
# ['of', 'high', 'engine']
# ['high', 'engine', 'pressures']
# ['engine', 'pressures', 'through']
# ['pressures', 'through', 'its']
# ['through', 'its', 'TITANIUM']
# ['its', 'TITANIUM', 'FST\x99']
# ['TITANIUM', 'FST\x99', '(Fluid']
# ['FST\x99', '(Fluid', 'Strength']
# ['(Fluid', 'Strength', 'Technology).']
# ['Strength', 'Technology).', 'TITANIUM']
# ['Technology).', 'TITANIUM', 'FST\x99']
# ['TITANIUM', 'FST\x99', 'doubles']
# ['FST\x99', 'doubles', 'oil']
# ['doubles', 'oil', 'strength']
# ['oil', 'strength', 'preventing']
# ['strength', 'preventing', 'oil']
# ['preventing', 'oil', 'breakdown']
# ['oil', 'breakdown', 'and']
# ['breakdown', 'and', 'sha...']
# TITANIUM FST   continuously responds and adapts to your engine's every need even under the severest possible pressures.  It's designed to minimise metal-to-metal contact, constantly adapting across a variety of engine spee...
# ['TITANIUM', 'FST\x99', 'continuously']
# ['FST\x99', 'continuously', 'responds']
# ['continuously', 'responds', 'and']
# ['responds', 'and', 'adapts']
# ['and', 'adapts', 'to']
# ['adapts', 'to', 'your']
# ['to', 'your', "engine's"]
# ['your', "engine's", 'every']
# ["engine's", 'every', 'need']
# ['every', 'need', 'even']
# ['need', 'even', 'under']
# ['even', 'under', 'the']
# ['under', 'the', 'severest']
# ['the', 'severest', 'possible']
# ['severest', 'possible', 'pressures.']
# ['possible', 'pressures.', "It's"]
# ['pressures.', "It's", 'designed']
# ["It's", 'designed', 'to']
# ['designed', 'to', 'minimise']
# ['to', 'minimise', 'metal-to-metal']
# ['minimise', 'metal-to-metal', 'contact,']
# ['metal-to-metal', 'contact,', 'constantly']
# ['contact,', 'constantly', 'adapting']
# ['constantly', 'adapting', 'across']
# ['adapting', 'across', 'a']
# ['across', 'a', 'variety']
# ['a', 'variety', 'of']
# ['variety', 'of', 'engine']
# ['of', 'engine', 'spee...']
# 1KGh8D0AwBs
# The Castrol R&amp;D Technology is amongst the best in the world. The Castrol Stress Test here shows how the double film strength of  Castrol EDGE  reduces metal-to-metal contact, making it the strongest oil in the world.
# ['The', 'Castrol', 'R&amp;D']
# ['Castrol', 'R&amp;D', 'Technology']
# ['R&amp;D', 'Technology', 'is']
# ['Technology', 'is', 'amongst']
# ['is', 'amongst', 'the']
# ['amongst', 'the', 'best']
# ['the', 'best', 'in']
# ['best', 'in', 'the']
# ['in', 'the', 'world.']
# ['the', 'world.', 'The']
# ['world.', 'The', 'Castrol']
# ['The', 'Castrol', 'Stress']
# ['Castrol', 'Stress', 'Test']
# ['Stress', 'Test', 'here']
# ['Test', 'here', 'shows']
# ['here', 'shows', 'how']
# ['shows', 'how', 'the']
# ['how', 'the', 'double']
# ['the', 'double', 'film']
# ['double', 'film', 'strength']
# ['film', 'strength', 'of']
# ['strength', 'of', 'Castrol']
# ['of', 'Castrol', 'EDGE']
# ['Castrol', 'EDGE', 'reduces']
# ['EDGE', 'reduces', 'metal-to-metal']
# ['reduces', 'metal-to-metal', 'contact,']
# ['metal-to-metal', 'contact,', 'making']
# ['contact,', 'making', 'it']
# ['making', 'it', 'the']
# ['it', 'the', 'strongest']
# ['the', 'strongest', 'oil']
# ['strongest', 'oil', 'in']
# ['oil', 'in', 'the']
# ['in', 'the', 'world.']
# Charles Cheers Wakefield, Castrols founder, was an entrepreneur with a vision. In 1899 he started the lubricant business from Cheapside, London. In 1906, he started Castrol, and took a personal interest in the new motorised contrapt...
# ['Charles', '\x93Cheers\x94', 'Wakefield,']
# ['\x93Cheers\x94', 'Wakefield,', 'Castrol\x92s']
# ['Wakefield,', 'Castrol\x92s', 'founder,']
# ['Castrol\x92s', 'founder,', 'was']
# ['founder,', 'was', 'an']
# ['was', 'an', 'entrepreneur']
# ['an', 'entrepreneur', 'with']
# ['entrepreneur', 'with', 'a']
# ['with', 'a', 'vision.']
# ['a', 'vision.', 'In']
# ['vision.', 'In', '1899']
# ['In', '1899', 'he']
# ['1899', 'he', 'started']
# ['he', 'started', 'the']
# ['started', 'the', 'lubricant']
# ['the', 'lubricant', 'business']
# ['lubricant', 'business', 'from']
# ['business', 'from', 'Cheapside,']
# ['from', 'Cheapside,', 'London.']
# ['Cheapside,', 'London.', 'In']
# ['London.', 'In', '1906,']
# ['In', '1906,', 'he']
# ['1906,', 'he', 'started']
# ['he', 'started', 'Castrol,']
# ['started', 'Castrol,', 'and']
# ['Castrol,', 'and', 'took']
# ['and', 'took', 'a']
# ['took', 'a', 'personal']
# ['a', 'personal', 'interest']
# ['personal', 'interest', 'in']
# ['interest', 'in', 'the']
# ['in', 'the', 'new']
# ['the', 'new', 'motorised']
# ['new', 'motorised', 'contrapt...']
# Charles Cheers Wakefield, Castrols founder, was an entrepreneur with a vision. In 1899 he started the lubricant business from Cheapside, London. In 1906, he started Castrol, and took a personal interest in the new motorised contrapt...
# ['Charles', '\x93Cheers\x94', 'Wakefield,']
# ['\x93Cheers\x94', 'Wakefield,', 'Castrol\x92s']
# ['Wakefield,', 'Castrol\x92s', 'founder,']
# ['Castrol\x92s', 'founder,', 'was']
# ['founder,', 'was', 'an']
# ['was', 'an', 'entrepreneur']
# ['an', 'entrepreneur', 'with']
# ['entrepreneur', 'with', 'a']
# ['with', 'a', 'vision.']
# ['a', 'vision.', 'In']
# ['vision.', 'In', '1899']
# ['In', '1899', 'he']
# ['1899', 'he', 'started']
# ['he', 'started', 'the']
# ['started', 'the', 'lubricant']
# ['the', 'lubricant', 'business']
# ['lubricant', 'business', 'from']
# ['business', 'from', 'Cheapside,']
# ['from', 'Cheapside,', 'London.']
# ['Cheapside,', 'London.', 'In']
# ['London.', 'In', '1906,']
# ['In', '1906,', 'he']
# ['1906,', 'he', 'started']
# ['he', 'started', 'Castrol,']
# ['started', 'Castrol,', 'and']
# ['Castrol,', 'and', 'took']
# ['and', 'took', 'a']
# ['took', 'a', 'personal']
# ['a', 'personal', 'interest']
# ['personal', 'interest', 'in']
# ['interest', 'in', 'the']
# ['in', 'the', 'new']
# ['the', 'new', 'motorised']
# ['new', 'motorised', 'contrapt...']
# rpXAV9ybskA
# Since the 1980s, Castrol has supplied NASA with lubricants for the space shuttle programme. More recently, when NASA's Curiosity rover began its exciting mission on Mars in 2012, Castrol industrial grease played a central role in the smooth opera...
# ['Since', 'the', '1980s,']
# ['the', '1980s,', 'Castrol']
# ['1980s,', 'Castrol', 'has']
# ['Castrol', 'has', 'supplied']
# ['has', 'supplied', 'NASA']
# ['supplied', 'NASA', 'with']
# ['NASA', 'with', 'lubricants']
# ['with', 'lubricants', 'for']
# ['lubricants', 'for', 'the']
# ['for', 'the', 'space']
# ['the', 'space', 'shuttle']
# ['space', 'shuttle', 'programme.']
# ['shuttle', 'programme.', 'More']
# ['programme.', 'More', 'recently,']
# ['More', 'recently,', 'when']
# ['recently,', 'when', "NASA's"]
# ['when', "NASA's", 'Curiosity']
# ["NASA's", 'Curiosity', 'rover']
# ['Curiosity', 'rover', 'began']
# ['rover', 'began', 'its']
# ['began', 'its', 'exciting']
# ['its', 'exciting', 'mission']
# ['exciting', 'mission', 'on']
# ['mission', 'on', 'Mars']
# ['on', 'Mars', 'in']
# ['Mars', 'in', '2012,']
# ['in', '2012,', 'Castrol']
# ['2012,', 'Castrol', 'industrial']
# ['Castrol', 'industrial', 'grease']
# ['industrial', 'grease', 'played']
# ['grease', 'played', 'a']
# ['played', 'a', 'central']
# ['a', 'central', 'role']
# ['central', 'role', 'in']
# ['role', 'in', 'the']
# ['in', 'the', 'smooth']
# ['the', 'smooth', 'opera...']
# rpXAV9ybskA
# Since the 1980s, Castrol has supplied NASA with lubricants for the space shuttle programme. More recently, when NASA's Curiosity rover began its exciting mission on Mars in 2012, Castrol industrial grease played a central role in the smooth opera...
# ['Since', 'the', '1980s,']
# ['the', '1980s,', 'Castrol']
# ['1980s,', 'Castrol', 'has']
# ['Castrol', 'has', 'supplied']
# ['has', 'supplied', 'NASA']
# ['supplied', 'NASA', 'with']
# ['NASA', 'with', 'lubricants']
# ['with', 'lubricants', 'for']
# ['lubricants', 'for', 'the']
# ['for', 'the', 'space']
# ['the', 'space', 'shuttle']
# ['space', 'shuttle', 'programme.']
# ['shuttle', 'programme.', 'More']
# ['programme.', 'More', 'recently,']
# ['More', 'recently,', 'when']
# ['recently,', 'when', "NASA's"]
# ['when', "NASA's", 'Curiosity']
# ["NASA's", 'Curiosity', 'rover']
# ['Curiosity', 'rover', 'began']
# ['rover', 'began', 'its']
# ['began', 'its', 'exciting']
# ['its', 'exciting', 'mission']
# ['exciting', 'mission', 'on']
# ['mission', 'on', 'Mars']
# ['on', 'Mars', 'in']
# ['Mars', 'in', '2012,']
# ['in', '2012,', 'Castrol']
# ['2012,', 'Castrol', 'industrial']
# ['Castrol', 'industrial', 'grease']
# ['industrial', 'grease', 'played']
# ['grease', 'played', 'a']
# ['played', 'a', 'central']
# ['a', 'central', 'role']
# ['central', 'role', 'in']
# ['role', 'in', 'the']
# ['in', 'the', 'smooth']
# ['the', 'smooth', 'opera...']
# 9RSWs44PdkE
# The journey of oil around a car engine takes as little as 5 secs.In this little time, it protects critical engine parts and prevents damage.This short film takes us through this incredible journey.
# ['The', 'journey', 'of']
# ['journey', 'of', 'oil']
# ['of', 'oil', 'around']
# ['oil', 'around', 'a']
# ['around', 'a', 'car']
# ['a', 'car', 'engine']
# ['car', 'engine', 'takes']
# ['engine', 'takes', 'as']
# ['takes', 'as', 'little']
# ['as', 'little', 'as']
# ['little', 'as', '5']
# ['as', '5', 'secs.In']
# ['5', 'secs.In', 'this']
# ['secs.In', 'this', 'little']
# ['this', 'little', 'time,']
# ['little', 'time,', 'it']
# ['time,', 'it', 'protects']
# ['it', 'protects', 'critical']
# ['protects', 'critical', 'engine']
# ['critical', 'engine', 'parts']
# ['engine', 'parts', 'and']
# ['parts', 'and', 'prevents']
# ['and', 'prevents', 'damage.This']
# ['prevents', 'damage.This', 'short']
# ['damage.This', 'short', 'film']
# ['short', 'film', 'takes']
# ['film', 'takes', 'us']
# ['takes', 'us', 'through']
# ['us', 'through', 'this']
# ['through', 'this', 'incredible']
# ['this', 'incredible', 'journey.']
# 9RSWs44PdkE
# The journey of oil around a car engine takes as little as 5 secs.In this little time, it protects critical engine parts and prevents damage.This short film takes us through this incredible journey.
# ['The', 'journey', 'of']
# ['journey', 'of', 'oil']
# ['of', 'oil', 'around']
# ['oil', 'around', 'a']
# ['around', 'a', 'car']
# ['a', 'car', 'engine']
# ['car', 'engine', 'takes']
# ['engine', 'takes', 'as']
# ['takes', 'as', 'little']
# ['as', 'little', 'as']
# ['little', 'as', '5']
# ['as', '5', 'secs.In']
# ['5', 'secs.In', 'this']
# ['secs.In', 'this', 'little']
# ['this', 'little', 'time,']
# ['little', 'time,', 'it']
# ['time,', 'it', 'protects']
# ['it', 'protects', 'critical']
# ['protects', 'critical', 'engine']
# ['critical', 'engine', 'parts']
# ['engine', 'parts', 'and']
# ['parts', 'and', 'prevents']
# ['and', 'prevents', 'damage.This']
# ['prevents', 'damage.This', 'short']
# ['damage.This', 'short', 'film']
# ['short', 'film', 'takes']
# ['film', 'takes', 'us']
# ['takes', 'us', 'through']
# ['us', 'through', 'this']
# ['through', 'this', 'incredible']
# ['this', 'incredible', 'journey.']
# Maintained Castrol as a seperate brand owing to our heritage and personality
# ['Maintained', 'Castrol', 'as']
# ['Castrol', 'as', 'a']
# ['as', 'a', 'seperate']
# ['a', 'seperate', 'brand']
# ['seperate', 'brand', 'owing']
# ['brand', 'owing', 'to']
# ['owing', 'to', 'our']
# ['to', 'our', 'heritage']
# ['our', 'heritage', 'and']
# ['heritage', 'and', 'personality']
# Maintained Castrol as a seperate brand owing to our heritage and personality
# ['Maintained', 'Castrol', 'as']
# ['Castrol', 'as', 'a']
# ['as', 'a', 'seperate']
# ['a', 'seperate', 'brand']
# ['seperate', 'brand', 'owing']
# ['brand', 'owing', 'to']
# ['owing', 'to', 'our']
# ['to', 'our', 'heritage']
# ['our', 'heritage', 'and']
# ['heritage', 'and', 'personality']
# Castrol lubricated the first transatlantic flight
# ['Castrol', 'lubricated', 'the']
# ['lubricated', 'the', 'first']
# ['the', 'first', 'transatlantic']
# ['first', 'transatlantic', 'flight']
# Castrol played a central role in NASA'S Curiosity rover on Mars in 2012, in the smooth operation of Curiosity's wheels
# ['Castrol', 'played', 'a']
# ['played', 'a', 'central']
# ['a', 'central', 'role']
# ['central', 'role', 'in']
# ['role', 'in', "NASA'S"]
# ['in', "NASA'S", 'Curiosity']
# ["NASA'S", 'Curiosity', 'rover']
# ['Curiosity', 'rover', 'on']
# ['rover', 'on', 'Mars']
# ['on', 'Mars', 'in']
# ['Mars', 'in', '2012,']
# ['in', '2012,', 'in']
# ['2012,', 'in', 'the']
# ['in', 'the', 'smooth']
# ['the', 'smooth', 'operation']
# ['smooth', 'operation', 'of']
# ['operation', 'of', "Curiosity's"]
# ['of', "Curiosity's", 'wheels']
# Castrol lubricated the first transatlantic flight
# ['Castrol', 'lubricated', 'the']
# ['lubricated', 'the', 'first']
# ['the', 'first', 'transatlantic']
# ['first', 'transatlantic', 'flight']
# Castrol played a central role in NASA'S Curiosity rover on Mars in 2012, in the smooth operation of Curiosity's wheels
# ['Castrol', 'played', 'a']
# ['played', 'a', 'central']
# ['a', 'central', 'role']
# ['central', 'role', 'in']
# ['role', 'in', "NASA'S"]
# ['in', "NASA'S", 'Curiosity']
# ["NASA'S", 'Curiosity', 'rover']
# ['Curiosity', 'rover', 'on']
# ['rover', 'on', 'Mars']
# ['on', 'Mars', 'in']
# ['Mars', 'in', '2012,']
# ['in', '2012,', 'in']
# ['2012,', 'in', 'the']
# ['in', 'the', 'smooth']
# ['the', 'smooth', 'operation']
# ['smooth', 'operation', 'of']
# ['operation', 'of', "Curiosity's"]
# ['of', "Curiosity's", 'wheels']
# oYMgytE68jo
# This Stream has information about the  Castrol EDGE  boosted with  TITANIUM FST  brand story?. You will understand  the value of Castrol EDGE to car owners by:   Understanding the engine ...
# ['This', 'Stream', 'has']
# ['Stream', 'has', 'information']
# ['has', 'information', 'about']
# ['information', 'about', 'the']
# ['about', 'the', 'Castrol']
# ['the', 'Castrol', 'EDGE']
# ['Castrol', 'EDGE', 'boosted']
# ['EDGE', 'boosted', 'with']
# ['boosted', 'with', 'TITANIUM']
# ['with', 'TITANIUM', 'FST\x99']
# ['TITANIUM', 'FST\x99', 'brand']
# ['FST\x99', 'brand', 'story?.']
# ['brand', 'story?.', 'You']
# ['story?.', 'You', 'will']
# ['You', 'will', 'understand']
# ['will', 'understand', 'the']
# ['understand', 'the', 'value']
# ['the', 'value', 'of']
# ['value', 'of', 'Castrol']
# ['of', 'Castrol', 'EDGE']
# ['Castrol', 'EDGE', 'to']
# ['EDGE', 'to', 'car']
# ['to', 'car', 'owners']
# ['car', 'owners', 'by:']
# ['owners', 'by:', 'Understanding']
# ['by:', 'Understanding', 'the']
# ['Understanding', 'the', 'engine']
# ['the', 'engine', '...']
# castrol
# castrol
# castrol
# In this Stream you will find information about Castrol MAGNATEC. In a clear way you will:   Understand the engine problem it is trying to solve  The reasons to believe how  Castrol MAGNATEC  solves the problem
# ['In', 'this', 'Stream']
# ['this', 'Stream', 'you']
# ['Stream', 'you', 'will']
# ['you', 'will', 'find']
# ['will', 'find', 'information']
# ['find', 'information', 'about']
# ['information', 'about', 'Castrol']
# ['about', 'Castrol', 'MAGNATEC.']
# ['Castrol', 'MAGNATEC.', 'In']
# ['MAGNATEC.', 'In', 'a']
# ['In', 'a', 'clear']
# ['a', 'clear', 'way']
# ['clear', 'way', 'you']
# ['way', 'you', 'will:']
# ['you', 'will:', 'Understand']
# ['will:', 'Understand', 'the']
# ['Understand', 'the', 'engine']
# ['the', 'engine', 'problem']
# ['engine', 'problem', 'it']
# ['problem', 'it', 'is']
# ['it', 'is', 'trying']
# ['is', 'trying', 'to']
# ['trying', 'to', 'solve']
# ['to', 'solve', 'The']
# ['solve', 'The', 'reasons']
# ['The', 'reasons', 'to']
# ['reasons', 'to', 'believe']
# ['to', 'believe', 'how']
# ['believe', 'how', 'Castrol']
# ['how', 'Castrol', 'MAGNATEC']
# ['Castrol', 'MAGNATEC', 'solves']
# ['MAGNATEC', 'solves', 'the']
# ['solves', 'the', 'problem']
# Castrol MAGNATEC , offers instant protection to an engine, from the moment the engine is started.  This leading Castrol engine oil brand has been helping motorists protect their car engines for almost 20 years.
# ['Castrol', 'MAGNATEC', ',']
# ['MAGNATEC', ',', 'offers']
# [',', 'offers', 'instant']
# ['offers', 'instant', 'protection']
# ['instant', 'protection', 'to']
# ['protection', 'to', 'an']
# ['to', 'an', 'engine,']
# ['an', 'engine,', 'from']
# ['engine,', 'from', 'the']
# ['from', 'the', 'moment']
# ['the', 'moment', 'the']
# ['moment', 'the', 'engine']
# ['the', 'engine', 'is']
# ['engine', 'is', 'started.']
# ['is', 'started.', 'This']
# ['started.', 'This', 'leading']
# ['This', 'leading', 'Castrol']
# ['leading', 'Castrol', 'engine']
# ['Castrol', 'engine', 'oil']
# ['engine', 'oil', 'brand']
# ['oil', 'brand', 'has']
# ['brand', 'has', 'been']
# ['has', 'been', 'helping']
# ['been', 'helping', 'motorists']
# ['helping', 'motorists', 'protect']
# ['motorists', 'protect', 'their']
# ['protect', 'their', 'car']
# ['their', 'car', 'engines']
# ['car', 'engines', 'for']
# ['engines', 'for', 'almost']
# ['for', 'almost', '20']
# ['almost', '20', 'years.']
# PD9jKFjREnI
# Castrol MAGNATECs  intelligent molecules cling to critical engine parts like a MAGNET, giving the engine an extra layer of protection from the start, and throughout warm-up.  Watch this video to see how it works.
# ['Castrol', 'MAGNATEC\x92s', 'intelligent']
# ['MAGNATEC\x92s', 'intelligent', 'molecules']
# ['intelligent', 'molecules', 'cling']
# ['molecules', 'cling', 'to']
# ['cling', 'to', 'critical']
# ['to', 'critical', 'engine']
# ['critical', 'engine', 'parts']
# ['engine', 'parts', 'like']
# ['parts', 'like', 'a']
# ['like', 'a', 'MAGNET,']
# ['a', 'MAGNET,', 'giving']
# ['MAGNET,', 'giving', 'the']
# ['giving', 'the', 'engine']
# ['the', 'engine', 'an']
# ['engine', 'an', 'extra']
# ['an', 'extra', 'layer']
# ['extra', 'layer', 'of']
# ['layer', 'of', 'protection']
# ['of', 'protection', 'from']
# ['protection', 'from', 'the']
# ['from', 'the', 'start,']
# ['the', 'start,', 'and']
# ['start,', 'and', 'throughout']
# ['and', 'throughout', 'warm-up.']
# ['throughout', 'warm-up.', 'Watch']
# ['warm-up.', 'Watch', 'this']
# ['Watch', 'this', 'video']
# ['this', 'video', 'to']
# ['video', 'to', 'see']
# ['to', 'see', 'how']
# ['see', 'how', 'it']
# ['how', 'it', 'works.']
# CASTROL MAGNATEC     Instant protection from engine wear during warm-up
# ['CASTROL', 'MAGNATEC', 'Instant']
# ['MAGNATEC', 'Instant', 'protection']
# ['Instant', 'protection', 'from']
# ['protection', 'from', 'engine']
# ['from', 'engine', 'wear']
# ['engine', 'wear', 'during']
# ['wear', 'during', 'warm-up']
# CASTROL MAGNATEC STOP START   Instant protection from engine wear due to stop start action in high traffic city driving
# ['CASTROL', 'MAGNATEC', 'STOP']
# ['MAGNATEC', 'STOP', 'START']
# ['STOP', 'START', 'Instant']
# ['START', 'Instant', 'protection']
# ['Instant', 'protection', 'from']
# ['protection', 'from', 'engine']
# ['from', 'engine', 'wear']
# ['engine', 'wear', 'due']
# ['wear', 'due', 'to']
# ['due', 'to', 'stop']
# ['to', 'stop', 'start']
# ['stop', 'start', 'action']
# ['start', 'action', 'in']
# ['action', 'in', 'high']
# ['in', 'high', 'traffic']
# ['high', 'traffic', 'city']
# ['traffic', 'city', 'driving']
# ggY96Ga0ytg
# When an engine stops, oil drains back to the sump. The next time it starts, it takes about 20 minutes to come to optimum performance temperature.  This is the time when engine damage can happen as critical parts are left exposed. 75%  of eng...
# ['When', 'an', 'engine']
# ['an', 'engine', 'stops,']
# ['engine', 'stops,', 'oil']
# ['stops,', 'oil', 'drains']
# ['oil', 'drains', 'back']
# ['drains', 'back', 'to']
# ['back', 'to', 'the']
# ['to', 'the', 'sump.']
# ['the', 'sump.', 'The']
# ['sump.', 'The', 'next']
# ['The', 'next', 'time']
# ['next', 'time', 'it']
# ['time', 'it', 'starts,']
# ['it', 'starts,', 'it']
# ['starts,', 'it', 'takes']
# ['it', 'takes', 'about']
# ['takes', 'about', '20']
# ['about', '20', 'minutes']
# ['20', 'minutes', 'to']
# ['minutes', 'to', 'come']
# ['to', 'come', 'to']
# ['come', 'to', 'optimum']
# ['to', 'optimum', 'performance']
# ['optimum', 'performance', 'temperature.']
# ['performance', 'temperature.', 'This']
# ['temperature.', 'This', 'is']
# ['This', 'is', 'the']
# ['is', 'the', 'time']
# ['the', 'time', 'when']
# ['time', 'when', 'engine']
# ['when', 'engine', 'damage']
# ['engine', 'damage', 'can']
# ['damage', 'can', 'happen']
# ['can', 'happen', 'as']
# ['happen', 'as', 'critical']
# ['as', 'critical', 'parts']
# ['critical', 'parts', 'are']
# ['parts', 'are', 'left']
# ['are', 'left', 'exposed.']
# ['left', 'exposed.', '75%']
# ['exposed.', '75%', 'of']
# ['75%', 'of', 'eng...']
# The  INTELLIGENT MOLECULES  are specially formulated to cling to critical engine parts like a magnet, providing an extra layer of protection from the start, and throughout warm-up of the engine.
# ['The', 'INTELLIGENT', 'MOLECULES']
# ['INTELLIGENT', 'MOLECULES', 'are']
# ['MOLECULES', 'are', 'specially']
# ['are', 'specially', 'formulated']
# ['specially', 'formulated', 'to']
# ['formulated', 'to', 'cling']
# ['to', 'cling', 'to']
# ['cling', 'to', 'critical']
# ['to', 'critical', 'engine']
# ['critical', 'engine', 'parts']
# ['engine', 'parts', 'like']
# ['parts', 'like', 'a']
# ['like', 'a', 'magnet,']
# ['a', 'magnet,', 'providing']
# ['magnet,', 'providing', 'an']
# ['providing', 'an', 'extra']
# ['an', 'extra', 'layer']
# ['extra', 'layer', 'of']
# ['layer', 'of', 'protection']
# ['of', 'protection', 'from']
# ['protection', 'from', 'the']
# ['from', 'the', 'start,']
# ['the', 'start,', 'and']
# ['start,', 'and', 'throughout']
# ['and', 'throughout', 'warm-up']
# ['throughout', 'warm-up', 'of']
# ['warm-up', 'of', 'the']
# ['of', 'the', 'engine.']
# Castrol MAGNATEC provides instant protection for engines, right from the moment you start.   Up to 75% of engine wear happens during warm-up. When the engine stops oil drains off critical engine parts, however Castrol MAGNATEC's I...
# ['Castrol', 'MAGNATEC', 'provides']
# ['MAGNATEC', 'provides', 'instant']
# ['provides', 'instant', 'protection']
# ['instant', 'protection', 'for']
# ['protection', 'for', 'engines,']
# ['for', 'engines,', 'right']
# ['engines,', 'right', 'from']
# ['right', 'from', 'the']
# ['from', 'the', 'moment']
# ['the', 'moment', 'you']
# ['moment', 'you', 'start.']
# ['you', 'start.', 'Up']
# ['start.', 'Up', 'to']
# ['Up', 'to', '75%']
# ['to', '75%', 'of']
# ['75%', 'of', 'engine']
# ['of', 'engine', 'wear']
# ['engine', 'wear', 'happens']
# ['wear', 'happens', 'during']
# ['happens', 'during', 'warm-up.']
# ['during', 'warm-up.', 'When']
# ['warm-up.', 'When', 'the']
# ['When', 'the', 'engine']
# ['the', 'engine', 'stops']
# ['engine', 'stops', 'oil']
# ['stops', 'oil', 'drains']
# ['oil', 'drains', 'off']
# ['drains', 'off', 'critical']
# ['off', 'critical', 'engine']
# ['critical', 'engine', 'parts,']
# ['engine', 'parts,', 'however']
# ['parts,', 'however', 'Castrol']
# ['however', 'Castrol', "MAGNATEC's"]
# ['Castrol', "MAGNATEC's", 'I...']
# 8hnkexBfJtQ
# Intelligent molecules cling and form a self healing layer so that it is always ready to protect at each of the critical stages of  STOP START  driving.  Watch the video on how  Castrol MAGNATEC STOP START  works to p...
# ['Intelligent', 'molecules', 'cling']
# ['molecules', 'cling', 'and']
# ['cling', 'and', 'form']
# ['and', 'form', 'a']
# ['form', 'a', 'self']
# ['a', 'self', 'healing']
# ['self', 'healing', 'layer']
# ['healing', 'layer', 'so']
# ['layer', 'so', 'that']
# ['so', 'that', 'it']
# ['that', 'it', 'is']
# ['it', 'is', 'always']
# ['is', 'always', 'ready']
# ['always', 'ready', 'to']
# ['ready', 'to', 'protect']
# ['to', 'protect', 'at']
# ['protect', 'at', 'each']
# ['at', 'each', 'of']
# ['each', 'of', 'the']
# ['of', 'the', 'critical']
# ['the', 'critical', 'stages']
# ['critical', 'stages', 'of']
# ['stages', 'of', 'STOP']
# ['of', 'STOP', 'START']
# ['STOP', 'START', 'driving.']
# ['START', 'driving.', 'Watch']
# ['driving.', 'Watch', 'the']
# ['Watch', 'the', 'video']
# ['the', 'video', 'on']
# ['video', 'on', 'how']
# ['on', 'how', 'Castrol']
# ['how', 'Castrol', 'MAGNATEC']
# ['Castrol', 'MAGNATEC', 'STOP']
# ['MAGNATEC', 'STOP', 'START']
# ['STOP', 'START', 'works']
# ['START', 'works', 'to']
# ['works', 'to', 'p...']
# The gravity defying action of the oil makes it cling to critical engine parts, when the oil drains down, giving an extra layer of protection against engine wear.  It is  combined with synthetic technology to provide increased protecti...
# ['The', 'gravity', 'defying']
# ['gravity', 'defying', 'action']
# ['defying', 'action', 'of']
# ['action', 'of', 'the']
# ['of', 'the', 'oil']
# ['the', 'oil', 'makes']
# ['oil', 'makes', 'it']
# ['makes', 'it', 'cling']
# ['it', 'cling', 'to']
# ['cling', 'to', 'critical']
# ['to', 'critical', 'engine']
# ['critical', 'engine', 'parts,']
# ['engine', 'parts,', 'when']
# ['parts,', 'when', 'the']
# ['when', 'the', 'oil']
# ['the', 'oil', 'drains']
# ['oil', 'drains', 'down,']
# ['drains', 'down,', 'giving']
# ['down,', 'giving', 'an']
# ['giving', 'an', 'extra']
# ['an', 'extra', 'layer']
# ['extra', 'layer', 'of']
# ['layer', 'of', 'protection']
# ['of', 'protection', 'against']
# ['protection', 'against', 'engine']
# ['against', 'engine', 'wear.']
# ['engine', 'wear.', 'It']
# ['wear.', 'It', 'is']
# ['It', 'is', 'combined']
# ['is', 'combined', 'with']
# ['combined', 'with', 'synthetic']
# ['with', 'synthetic', 'technology']
# ['synthetic', 'technology', 'to']
# ['technology', 'to', 'provide']
# ['to', 'provide', 'increased']
# ['provide', 'increased', 'protecti...']
# In this Stream you will find information about  Castrol GTX  -  Superior Sludge Protection to help extend engine life .    In a clear way, you will:   Understand the engine problem GTX is trying...
# ['In', 'this', 'Stream']
# ['this', 'Stream', 'you']
# ['Stream', 'you', 'will']
# ['you', 'will', 'find']
# ['will', 'find', 'information']
# ['find', 'information', 'about']
# ['information', 'about', 'Castrol']
# ['about', 'Castrol', 'GTX']
# ['Castrol', 'GTX', '-']
# ['GTX', '-', 'Superior']
# ['-', 'Superior', 'Sludge']
# ['Superior', 'Sludge', 'Protection']
# ['Sludge', 'Protection', 'to']
# ['Protection', 'to', 'help']
# ['to', 'help', 'extend']
# ['help', 'extend', 'engine']
# ['extend', 'engine', 'life']
# ['engine', 'life', '.']
# ['life', '.', 'In']
# ['.', 'In', 'a']
# ['In', 'a', 'clear']
# ['a', 'clear', 'way,']
# ['clear', 'way,', 'you']
# ['way,', 'you', 'will:']
# ['you', 'will:', 'Understand']
# ['will:', 'Understand', 'the']
# ['Understand', 'the', 'engine']
# ['the', 'engine', 'problem']
# ['engine', 'problem', 'GTX']
# ['problem', 'GTX', 'is']
# ['GTX', 'is', 'trying...']
# Castrol GTX  is one of the world's most trusted motor oils. It is liquid engineering that protects against problems, like sludge.  Severe driving conditions such as every day stop-and-go/stop-start-traffic, harsh weather condition...
# ['Castrol', 'GTX', 'is']
# ['GTX', 'is', 'one']
# ['is', 'one', 'of']
# ['one', 'of', 'the']
# ['of', 'the', "world's"]
# ['the', "world's", 'most']
# ["world's", 'most', 'trusted']
# ['most', 'trusted', 'motor']
# ['trusted', 'motor', 'oils.']
# ['motor', 'oils.', 'It']
# ['oils.', 'It', 'is']
# ['It', 'is', 'liquid']
# ['is', 'liquid', 'engineering']
# ['liquid', 'engineering', 'that']
# ['engineering', 'that', 'protects']
# ['that', 'protects', 'against']
# ['protects', 'against', 'problems,']
# ['against', 'problems,', 'like']
# ['problems,', 'like', 'sludge.']
# ['like', 'sludge.', 'Severe']
# ['sludge.', 'Severe', 'driving']
# ['Severe', 'driving', 'conditions']
# ['driving', 'conditions', 'such']
# ['conditions', 'such', 'as']
# ['such', 'as', 'every']
# ['as', 'every', 'day']
# ['every', 'day', 'stop-and-go/stop-start-traffic,']
# ['day', 'stop-and-go/stop-start-traffic,', 'harsh']
# ['stop-and-go/stop-start-traffic,', 'harsh', 'weather']
# ['harsh', 'weather', 'condition...']
# 0outa7euRbg
# Castrol GTX  has a unique Double Action formula that keeps the engine oilways free of dirt formation.  It clears away the dirt particles and prevents the smaller dirt particles to join together and form sludge in the vital oilways...
# ['Castrol', 'GTX', 'has']
# ['GTX', 'has', 'a']
# ['has', 'a', 'unique']
# ['a', 'unique', 'Double']
# ['unique', 'Double', 'Action']
# ['Double', 'Action', 'formula']
# ['Action', 'formula', 'that']
# ['formula', 'that', 'keeps']
# ['that', 'keeps', 'the']
# ['keeps', 'the', 'engine']
# ['the', 'engine', 'oilways']
# ['engine', 'oilways', 'free']
# ['oilways', 'free', 'of']
# ['free', 'of', 'dirt']
# ['of', 'dirt', 'formation.']
# ['dirt', 'formation.', 'It']
# ['formation.', 'It', 'clears']
# ['It', 'clears', 'away']
# ['clears', 'away', 'the']
# ['away', 'the', 'dirt']
# ['the', 'dirt', 'particles']
# ['dirt', 'particles', 'and']
# ['particles', 'and', 'prevents']
# ['and', 'prevents', 'the']
# ['prevents', 'the', 'smaller']
# ['the', 'smaller', 'dirt']
# ['smaller', 'dirt', 'particles']
# ['dirt', 'particles', 'to']
# ['particles', 'to', 'join']
# ['to', 'join', 'together']
# ['join', 'together', 'and']
# ['together', 'and', 'form']
# ['and', 'form', 'sludge']
# ['form', 'sludge', 'in']
# ['sludge', 'in', 'the']
# ['in', 'the', 'vital']
# ['the', 'vital', 'oilways...']
# Just like cholesterol, sludge (a thick, tar-like substance) build-up caused by everyday driving clogs important engine parts, even in well-maintained vehicles.   Sludge can block your engines vital oilways  and if untreated, it can rob an e...
# ['Just', 'like', 'cholesterol,']
# ['like', 'cholesterol,', 'sludge']
# ['cholesterol,', 'sludge', '(a']
# ['sludge', '(a', 'thick,']
# ['(a', 'thick,', 'tar-like']
# ['thick,', 'tar-like', 'substance)']
# ['tar-like', 'substance)', 'build-up']
# ['substance)', 'build-up', 'caused']
# ['build-up', 'caused', 'by']
# ['caused', 'by', 'everyday']
# ['by', 'everyday', 'driving']
# ['everyday', 'driving', 'clogs']
# ['driving', 'clogs', 'important']
# ['clogs', 'important', 'engine']
# ['important', 'engine', 'parts,']
# ['engine', 'parts,', 'even']
# ['parts,', 'even', 'in']
# ['even', 'in', 'well-maintained']
# ['in', 'well-maintained', 'vehicles.']
# ['well-maintained', 'vehicles.', 'Sludge']
# ['vehicles.', 'Sludge', 'can']
# ['Sludge', 'can', 'block']
# ['can', 'block', 'your']
# ['block', 'your', 'engine\x92s']
# ['your', 'engine\x92s', 'vital']
# ['engine\x92s', 'vital', 'oilways']
# ['vital', 'oilways', '\x96']
# ['oilways', '\x96', 'and']
# ['\x96', 'and', 'if']
# ['and', 'if', 'untreated,']
# ['if', 'untreated,', 'it']
# ['untreated,', 'it', 'can']
# ['it', 'can', 'rob']
# ['can', 'rob', 'an']
# ['rob', 'an', 'e...']
# Castrol GTX DOUBLE ACTION FORMULA  cleans away old sludge, and protects against new sludge formation  better than industry standards.
# ['Castrol', 'GTX', 'DOUBLE']
# ['GTX', 'DOUBLE', 'ACTION']
# ['DOUBLE', 'ACTION', 'FORMULA']
# ['ACTION', 'FORMULA', 'cleans']
# ['FORMULA', 'cleans', 'away']
# ['cleans', 'away', 'old']
# ['away', 'old', 'sludge,']
# ['old', 'sludge,', 'and']
# ['sludge,', 'and', 'protects']
# ['and', 'protects', 'against']
# ['protects', 'against', 'new']
# ['against', 'new', 'sludge']
# ['new', 'sludge', 'formation']
# ['sludge', 'formation', '\x96']
# ['formation', '\x96', 'better']
# ['\x96', 'better', 'than']
# ['better', 'than', 'industry']
# ['than', 'industry', 'standards.']
# CASTROL GTX helps extend the life of your engine
# ['CASTROL', 'GTX', 'helps']
# ['GTX', 'helps', 'extend']
# ['helps', 'extend', 'the']
# ['extend', 'the', 'life']
# ['the', 'life', 'of']
# ['life', 'of', 'your']
# ['of', 'your', 'engine']
# GTX DOUBLE ACTION FORMULA  reduces sludge and protects against new sludge. This extends the engines life significantly.  Removing sludge is good for the engine because:   It keeps engines cool and clean  It prov...
# ['GTX', 'DOUBLE', 'ACTION']
# ['DOUBLE', 'ACTION', 'FORMULA']
# ['ACTION', 'FORMULA', 'reduces']
# ['FORMULA', 'reduces', 'sludge']
# ['reduces', 'sludge', 'and']
# ['sludge', 'and', 'protects']
# ['and', 'protects', 'against']
# ['protects', 'against', 'new']
# ['against', 'new', 'sludge.']
# ['new', 'sludge.', 'This']
# ['sludge.', 'This', 'extends']
# ['This', 'extends', 'the']
# ['extends', 'the', 'engine\x92s']
# ['the', 'engine\x92s', 'life']
# ['engine\x92s', 'life', 'significantly.']
# ['life', 'significantly.', 'Removing']
# ['significantly.', 'Removing', 'sludge']
# ['Removing', 'sludge', 'is']
# ['sludge', 'is', 'good']
# ['is', 'good', 'for']
# ['good', 'for', 'the']
# ['for', 'the', 'engine']
# ['the', 'engine', 'because:']
# ['engine', 'because:', 'It']
# ['because:', 'It', 'keeps']
# ['It', 'keeps', 'engines']
# ['keeps', 'engines', 'cool']
# ['engines', 'cool', 'and']
# ['cool', 'and', 'clean']
# ['and', 'clean', 'It']
# ['clean', 'It', 'prov...']
# Irv has driven his Volvo the equivalent distance of every stretch of road in the U.S. at least once as well as in 9 foreign countries.     But, throughout the years and over the course of all these miles and countless stops along the way  ...
# ['Irv', 'has', 'driven']
# ['has', 'driven', 'his']
# ['driven', 'his', 'Volvo']
# ['his', 'Volvo', 'the']
# ['Volvo', 'the', 'equivalent']
# ['the', 'equivalent', 'distance']
# ['equivalent', 'distance', 'of']
# ['distance', 'of', 'every']
# ['of', 'every', 'stretch']
# ['every', 'stretch', 'of']
# ['stretch', 'of', 'road']
# ['of', 'road', 'in']
# ['road', 'in', 'the']
# ['in', 'the', 'U.S.']
# ['the', 'U.S.', 'at']
# ['U.S.', 'at', 'least']
# ['at', 'least', 'once']
# ['least', 'once', 'as']
# ['once', 'as', 'well']
# ['as', 'well', 'as']
# ['well', 'as', 'in']
# ['as', 'in', '9']
# ['in', '9', 'foreign']
# ['9', 'foreign', 'countries.']
# ['foreign', 'countries.', 'But,']
# ['countries.', 'But,', 'throughout']
# ['But,', 'throughout', 'the']
# ['throughout', 'the', 'years']
# ['the', 'years', 'and']
# ['years', 'and', 'over']
# ['and', 'over', 'the']
# ['over', 'the', 'course']
# ['the', 'course', 'of']
# ['course', 'of', 'all']
# ['of', 'all', 'these']
# ['all', 'these', 'miles']
# ['these', 'miles', 'and']
# ['miles', 'and', 'countless']
# ['and', 'countless', 'stops']
# ['countless', 'stops', 'along']
# ['stops', 'along', 'the']
# ['along', 'the', 'way']
# ['the', 'way', '\x96']
# ['way', '\x96', '...']
# Simple customer demonstration devices help bring to life the product brand stories and show how Castrol lubricant technology works. The demo devices are intended to offer a compelling visualisation of our technology and help to shift customers from pr...
# ['Simple', 'customer', 'demonstration']
# ['customer', 'demonstration', 'devices']
# ['demonstration', 'devices', 'help']
# ['devices', 'help', 'bring']
# ['help', 'bring', 'to']
# ['bring', 'to', 'life']
# ['to', 'life', 'the']
# ['life', 'the', 'product']
# ['the', 'product', 'brand']
# ['product', 'brand', 'stories']
# ['brand', 'stories', 'and']
# ['stories', 'and', 'show']
# ['and', 'show', 'how']
# ['show', 'how', 'Castrol']
# ['how', 'Castrol', 'lubricant']
# ['Castrol', 'lubricant', 'technology']
# ['lubricant', 'technology', 'works.']
# ['technology', 'works.', 'The']
# ['works.', 'The', 'demo']
# ['The', 'demo', 'devices']
# ['demo', 'devices', 'are']
# ['devices', 'are', 'intended']
# ['are', 'intended', 'to']
# ['intended', 'to', 'offer']
# ['to', 'offer', 'a']
# ['offer', 'a', 'compelling']
# ['a', 'compelling', 'visualisation']
# ['compelling', 'visualisation', 'of']
# ['visualisation', 'of', 'our']
# ['of', 'our', 'technology']
# ['our', 'technology', 'and']
# ['technology', 'and', 'help']
# ['and', 'help', 'to']
# ['help', 'to', 'shift']
# ['to', 'shift', 'customers']
# ['shift', 'customers', 'from']
# ['customers', 'from', 'pr...']
# Engine pressure has almost doubled over the past 30 years, causing more stress on the oil.  With the engine under such pressure customers need an oil that is proven strong and remains strong.?
# ['Engine', 'pressure', 'has']
# ['pressure', 'has', 'almost']
# ['has', 'almost', 'doubled']
# ['almost', 'doubled', 'over']
# ['doubled', 'over', 'the']
# ['over', 'the', 'past']
# ['the', 'past', '30']
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: DeprecationWarning: generator 'ngrams' raised StopIteration
# ['past', '30', 'years,']
# ['30', 'years,', 'causing']
# ['years,', 'causing', 'more']
# ['causing', 'more', 'stress']
# ['more', 'stress', 'on']
# ['stress', 'on', 'the']
# ['on', 'the', 'oil.']
# ['the', 'oil.', 'With']
# ['oil.', 'With', 'the']
# ['With', 'the', 'engine']
# ['the', 'engine', 'under']
# ['engine', 'under', 'such']
# ['under', 'such', 'pressure']
# ['such', 'pressure', 'customers']
# ['pressure', 'customers', 'need']
# ['customers', 'need', 'an']
# ['need', 'an', 'oil']
# ['an', 'oil', 'that']
# ['oil', 'that', 'is']
# ['that', 'is', 'proven']
# ['is', 'proven', 'strong']
# ['proven', 'strong', 'and']
# ['strong', 'and', 'remains']
# ...
# ['Where', 'to', 'find:']
# ['to', 'find:', 'The']
# ['find:', 'The', 'strength']
# ['The', 'strength', 'of']
# ['strength', 'of', 'Castrol']
# ['of', 'Castrol', 'EDGE']
# ['Castrol', 'EDGE', 'stream']
# Where to find it:   The strength of Castrol EDGE stream
# ['Where', 'to', 'find']
# ['to', 'find', 'it:']
# ['find', 'it:', 'The']
# ['it:', 'The', 'strength']
# ['The', 'strength', 'of']
# ['strength', 'of', 'Castrol']
# ['of', 'Castrol', 'EDGE']
# ['Castrol', 'EDGE', 'stream']
# Where to find it:    The strength of Castrol EDGE stream
# ['Where', 'to', 'find']
# ['to', 'find', 'it:']
# ['find', 'it:', 'The']
# ['it:', 'The', 'strength']
# ['The', 'strength', 'of']
# ['strength', 'of', 'Castrol']
# ['of', 'Castrol', 'EDGE']
# ['Castrol', 'EDGE', 'stream']
# Where to find it:      The value of Castrol GTX MAGNATEC stream
# ['Where', 'to', 'find']
# ['to', 'find', 'it:']
# ['find', 'it:', 'The']
# ['it:', 'The', 'value']
# ['The', 'value', 'of']
# ['value', 'of', 'Castrol']
# ['of', 'Castrol', 'GTX']
# ['Castrol', 'GTX', 'MAGNATEC']
# ['GTX', 'MAGNATEC', 'stream']
# Where to find it:      The value of Castrol GTX MAGNATEC stream
# ['Where', 'to', 'find']
# ['to', 'find', 'it:']
# ['find', 'it:', 'The']
# ['it:', 'The', 'value']
# ['The', 'value', 'of']
# ['value', 'of', 'Castrol']
# ['of', 'Castrol', 'GTX']
# ['Castrol', 'GTX', 'MAGNATEC']
# ['GTX', 'MAGNATEC', 'stream']
# Where to find it:   The value of Castrol GTX
# ['Where', 'to', 'find']
# ['to', 'find', 'it:']
# ['find', 'it:', 'The']
# ['it:', 'The', 'value']
# ['The', 'value', 'of']
# ['value', 'of', 'Castrol']
# ['of', 'Castrol', 'GTX']
# Where to find it:      The value of Castrol GTX
# ['Where', 'to', 'find']
# ['to', 'find', 'it:']
# ['find', 'it:', 'The']
# ['it:', 'The', 'value']
# ['The', 'value', 'of']
# ['value', 'of', 'Castrol']
# ['of', 'Castrol', 'GTX']
# This stream provides you with a quick reference of all the PDFs that are available as attachments on your Castrol Brand Streams.      The PDFs are available for you to share with your customers to leave back as reference to your conv...
# ['This', 'stream', 'provides']
# ['stream', 'provides', 'you']
# ['provides', 'you', 'with']
# ['you', 'with', 'a']
# ['with', 'a', 'quick']
# ['a', 'quick', 'reference']
# ['quick', 'reference', 'of']
# ['reference', 'of', 'all']
# ['of', 'all', 'the']
# ['all', 'the', 'PDFs']
# ['the', 'PDFs', 'that']
# ['PDFs', 'that', 'are']
# ['that', 'are', 'available']
# ['are', 'available', 'as']
# ['available', 'as', 'attachments']
# ['as', 'attachments', 'on']
# ['attachments', 'on', 'your']
# ['on', 'your', 'Castrol']
# ['your', 'Castrol', 'Brand']
# ['Castrol', 'Brand', 'Streams.']
# ['Brand', 'Streams.', 'The']
# ['Streams.', 'The', 'PDFs']
# ['The', 'PDFs', 'are']
# ['PDFs', 'are', 'available']
# ['are', 'available', 'for']
# ['available', 'for', 'you']
# ['for', 'you', 'to']
# ['you', 'to', 'share']
# ['to', 'share', 'with']
# ['share', 'with', 'your']
# ['with', 'your', 'customers']
# ['your', 'customers', 'to']
# ['customers', 'to', 'leave']
# ['to', 'leave', 'back']
# ['leave', 'back', 'as']
# ['back', 'as', 'reference']
# ['as', 'reference', 'to']
# ['reference', 'to', 'your']
# ['to', 'your', 'conv...']
# Here's a quick summary of what Castrol GTX offers:    Castrol GTX focuses on making engines last longer   Its Double Action Formula removes sludge from critical oilways   Removing sludge keeps engines cool an...
# ["Here's", 'a', 'quick']
# ['a', 'quick', 'summary']
# ['quick', 'summary', 'of']
# ['summary', 'of', 'what']
# ['of', 'what', 'Castrol']
# ['what', 'Castrol', 'GTX']
# ['Castrol', 'GTX', 'offers:']
# ['GTX', 'offers:', 'Castrol']
# ['offers:', 'Castrol', 'GTX']
# ['Castrol', 'GTX', 'focuses']
# ['GTX', 'focuses', 'on']
# ['focuses', 'on', 'making']
# ['on', 'making', 'engines']
# ['making', 'engines', 'last']
# ['engines', 'last', 'longer']
# ['last', 'longer', 'Its']
# ['longer', 'Its', 'Double']
# ['Its', 'Double', 'Action']
# ['Double', 'Action', 'Formula']
# ['Action', 'Formula', 'removes']
# ['Formula', 'removes', 'sludge']
# ['removes', 'sludge', 'from']
# ['sludge', 'from', 'critical']
# ['from', 'critical', 'oilways']
# ['critical', 'oilways', 'Removing']
# ['oilways', 'Removing', 'sludge']
# ['Removing', 'sludge', 'keeps']
# ['sludge', 'keeps', 'engines']
# ['keeps', 'engines', 'cool']
# ['engines', 'cool', 'an...']
# 0outa7euRbg
# Castrol GTX  has a unique Double Action formula that keeps the engine oilways free of dirt formation.  It clears away the dirt particles and prevents the smaller dirt particles to join together and form sludge in the vital oilways...
# ['Castrol', 'GTX', 'has']
# ['GTX', 'has', 'a']
# ['has', 'a', 'unique']
# ['a', 'unique', 'Double']
# ['unique', 'Double', 'Action']
# ['Double', 'Action', 'formula']
# ['Action', 'formula', 'that']
# ['formula', 'that', 'keeps']
# ['that', 'keeps', 'the']
# ['keeps', 'the', 'engine']
# ['the', 'engine', 'oilways']
# ['engine', 'oilways', 'free']
# ['oilways', 'free', 'of']
# ['free', 'of', 'dirt']
# ['of', 'dirt', 'formation.']
# ['dirt', 'formation.', 'It']
# ['formation.', 'It', 'clears']
# ['It', 'clears', 'away']
# ['clears', 'away', 'the']
# ['away', 'the', 'dirt']
# ['the', 'dirt', 'particles']
# ['dirt', 'particles', 'and']
# ['particles', 'and', 'prevents']
# ['and', 'prevents', 'the']
# ['prevents', 'the', 'smaller']
# ['the', 'smaller', 'dirt']
# ['smaller', 'dirt', 'particles']
# ['dirt', 'particles', 'to']
# ['particles', 'to', 'join']
# ['to', 'join', 'together']
# ['join', 'together', 'and']
# ['together', 'and', 'form']
# ['and', 'form', 'sludge']
# ['form', 'sludge', 'in']
# ['sludge', 'in', 'the']
# ['in', 'the', 'vital']
# ['the', 'vital', 'oilways...']
# Irv Gordon, drove more than 3 million miles, using only Castrol GTX in his Volvo.    Irv began using Castrol GTX as recommended by his dealer in 1968, and has used it ever since.     Castrol GTX
# ['Irv', 'Gordon,', 'drove']
# ['Gordon,', 'drove', 'more']
# ['drove', 'more', 'than']
# ['more', 'than', '3']
# ['than', '3', 'million']
# ['3', 'million', 'miles,']
# ['million', 'miles,', 'using']
# ['miles,', 'using', 'only']
# ['using', 'only', 'Castrol']
# ['only', 'Castrol', 'GTX']
# ['Castrol', 'GTX', 'in']
# ['GTX', 'in', 'his']
# ['in', 'his', 'Volvo.']
# ['his', 'Volvo.', 'Irv']
# ['Volvo.', 'Irv', 'began']
# ['Irv', 'began', 'using']
# ['began', 'using', 'Castrol']
# ['using', 'Castrol', 'GTX']
# ['Castrol', 'GTX', 'as']
# ['GTX', 'as', 'recommended']
# ['as', 'recommended', 'by']
# ['recommended', 'by', 'his']
# ['by', 'his', 'dealer']
# ['his', 'dealer', 'in']
# ['dealer', 'in', '1968,']
# ['in', '1968,', 'and']
# ['1968,', 'and', 'has']
# ['and', 'has', 'used']
# ['has', 'used', 'it']
# ['used', 'it', 'ever']
# ['it', 'ever', 'since.']
# ['ever', 'since.', 'Castrol']
# ['since.', 'Castrol', 'GTX']
# The Castrol GTX Sludge Tower represents the vital oilways in an engine.  When you turn the demo over, the coloured balls represent the oil trying to flow through the oilways to protect critical engine parts. Sludge gets in the way, and can cause ...
# ['The', 'Castrol', 'GTX']
# ['Castrol', 'GTX', 'Sludge']
# ['GTX', 'Sludge', 'Tower']
# ['Sludge', 'Tower', 'represents']
# ['Tower', 'represents', 'the']
# ['represents', 'the', 'vital']
# ['the', 'vital', 'oilways']
# ['vital', 'oilways', 'in']
# ['oilways', 'in', 'an']
# ['in', 'an', 'engine.']
# ['an', 'engine.', 'When']
# ['engine.', 'When', 'you']
# ['When', 'you', 'turn']
# ['you', 'turn', 'the']
# ['turn', 'the', 'demo']
# ['the', 'demo', 'over,']
# ['demo', 'over,', 'the']
# ['over,', 'the', 'coloured']
# ['the', 'coloured', 'balls']
# ['coloured', 'balls', 'represent']
# ['balls', 'represent', 'the']
# ['represent', 'the', 'oil']
# ['the', 'oil', 'trying']
# ['oil', 'trying', 'to']
# ['trying', 'to', 'flow']
# ['to', 'flow', 'through']
# ['flow', 'through', 'the']
# ['through', 'the', 'oilways']
# ['the', 'oilways', 'to']
# ['oilways', 'to', 'protect']
# ['to', 'protect', 'critical']
# ['protect', 'critical', 'engine']
# ['critical', 'engine', 'parts.']
# ['engine', 'parts.', 'Sludge']
# ['parts.', 'Sludge', 'gets']
# ['Sludge', 'gets', 'in']
# ['gets', 'in', 'the']
# ['in', 'the', 'way,']
# ['the', 'way,', 'and']
# ['way,', 'and', 'can']
# ['and', 'can', 'cause']
# ['can', 'cause', '...']
# _fMBvrSF4pE
# Watch what Irv Gordon has to say about hitting world records with Castrol GTX.
# ['Watch', 'what', 'Irv']
# ['what', 'Irv', 'Gordon']
# ['Irv', 'Gordon', 'has']
# ['Gordon', 'has', 'to']
# ['has', 'to', 'say']
# ['to', 'say', 'about']
# ['say', 'about', 'hitting']
# ['about', 'hitting', 'world']
# ['hitting', 'world', 'records']
# ['world', 'records', 'with']
# ['records', 'with', 'Castrol']
# ['with', 'Castrol', 'GTX.']
# When an engine starts, it takes time to reach the peak protection temperature.  This leaves the engine exposed to damage during warm-up.   75% of engine damage happens during warm-up!
# ['When', 'an', 'engine']
# ['an', 'engine', 'starts,']
# ['engine', 'starts,', 'it']
# ['starts,', 'it', 'takes']
# ['it', 'takes', 'time']
# ['takes', 'time', 'to']
# ['time', 'to', 'reach']
# ['to', 'reach', 'the']
# ['reach', 'the', 'peak']
# ['the', 'peak', 'protection']
# ['peak', 'protection', 'temperature.']
# ['protection', 'temperature.', 'This']
# ['temperature.', 'This', 'leaves']
# ['This', 'leaves', 'the']
# ['leaves', 'the', 'engine']
# ['the', 'engine', 'exposed']
# ['engine', 'exposed', 'to']
# ['exposed', 'to', 'damage']
# ['to', 'damage', 'during']
# ['damage', 'during', 'warm-up.']
# ['during', 'warm-up.', '75%']
# ['warm-up.', '75%', 'of']
# ['75%', 'of', 'engine']
# ['of', 'engine', 'damage']
# ['engine', 'damage', 'happens']
# ['damage', 'happens', 'during']
# ['happens', 'during', 'warm-up!']
# Intelligent molecules are gravity defying so the oil doesn't drain down to the slump.   Synthetic technology provides increased protection in high and low temperature applications.
# ['Intelligent', 'molecules', 'are']
# ['molecules', 'are', 'gravity']
# ['are', 'gravity', 'defying']
# ['gravity', 'defying', 'so']
# ['defying', 'so', 'the']
# ['so', 'the', 'oil']
# ['the', 'oil', "doesn't"]
# ['oil', "doesn't", 'drain']
# ["doesn't", 'drain', 'down']
# ['drain', 'down', 'to']
# ['down', 'to', 'the']
# ['to', 'the', 'slump.']
# ['the', 'slump.', 'Synthetic']
# ['slump.', 'Synthetic', 'technology']
# ['Synthetic', 'technology', 'provides']
# ['technology', 'provides', 'increased']
# ['provides', 'increased', 'protection']
# ['increased', 'protection', 'in']
# ['protection', 'in', 'high']
# ['in', 'high', 'and']
# ['high', 'and', 'low']
# ['and', 'low', 'temperature']
# ['low', 'temperature', 'applications.']
# 75% OF ENGINE WEAR HAPPENS DURING  WARM-UP !
# ['75%', 'OF', 'ENGINE']
# ['OF', 'ENGINE', 'WEAR']
# ['ENGINE', 'WEAR', 'HAPPENS']
# ['WEAR', 'HAPPENS', 'DURING']
# ['HAPPENS', 'DURING', 'WARM-UP']
# ['DURING', 'WARM-UP', '!']
# When the engine stops, oil drains back to the sump, so critical engine parts are exposed and not protected by the oil.   This leads to abrasion and major engine wear!
# ['When', 'the', 'engine']
# ['the', 'engine', 'stops,']
# ['engine', 'stops,', 'oil']
# ['stops,', 'oil', 'drains']
# ['oil', 'drains', 'back']
# ['drains', 'back', 'to']
# ['back', 'to', 'the']
# ['to', 'the', 'sump,']
# ['the', 'sump,', 'so']
# ['sump,', 'so', 'critical']
# ['so', 'critical', 'engine']
# ['critical', 'engine', 'parts']
# ['engine', 'parts', 'are']
# ['parts', 'are', 'exposed']
# ['are', 'exposed', 'and']
# ['exposed', 'and', 'not']
# ['and', 'not', 'protected']
# ['not', 'protected', 'by']
# ['protected', 'by', 'the']
# ['by', 'the', 'oil.']
# ['the', 'oil.', 'This']
# ['oil.', 'This', 'leads']
# ['This', 'leads', 'to']
# ['leads', 'to', 'abrasion']
# ['to', 'abrasion', 'and']
# ['abrasion', 'and', 'major']
# ['and', 'major', 'engine']
# ['major', 'engine', 'wear!']
# Here is your quick summary on what Castrol EDGE is about:   EDGE is designed for todays smaller, more powerful engines   Its special Fluid Titanium Technology has twice the film strength of our previous formula  Strong...
# ['Here', 'is', 'your']
# ['is', 'your', 'quick']
# ['your', 'quick', 'summary']
# ['quick', 'summary', 'on']
# ['summary', 'on', 'what']
# ['on', 'what', 'Castrol']
# ['what', 'Castrol', 'EDGE']
# ['Castrol', 'EDGE', 'is']
# ['EDGE', 'is', 'about:']
# ['is', 'about:', 'EDGE']
# ['about:', 'EDGE', 'is']
# ['EDGE', 'is', 'designed']
# ['is', 'designed', 'for']
# ['designed', 'for', 'todays']
# ['for', 'todays', 'smaller,']
# ['todays', 'smaller,', 'more']
# ['smaller,', 'more', 'powerful']
# ['more', 'powerful', 'engines']
# ['powerful', 'engines', 'Its']
# ['engines', 'Its', 'special']
# ['Its', 'special', 'Fluid']
# ['special', 'Fluid', 'Titanium']
# ['Fluid', 'Titanium', 'Technology']
# ['Titanium', 'Technology', 'has']
# ['Technology', 'has', 'twice']
# ['has', 'twice', 'the']
# ['twice', 'the', 'film']
# ['the', 'film', 'strength']
# ['film', 'strength', 'of']
# ['strength', 'of', 'our']
# ['of', 'our', 'previous']
# ['our', 'previous', 'formula']
# ['previous', 'formula', 'Strong...']
# Titanium technology  physically changes the way oil  behaves under pressure.     Doubles oil film strength and  prevents oil from breaking down.     Since oil breakdown is prevented, en...
# ['Titanium', 'technology', 'physically']
# ['technology', 'physically', 'changes']
# ['physically', 'changes', 'the']
# ['changes', 'the', 'way']
# ['the', 'way', 'oil']
# ['way', 'oil', 'behaves']
# ['oil', 'behaves', 'under']
# ['behaves', 'under', 'pressure.']
# ['under', 'pressure.', 'Doubles']
# ['pressure.', 'Doubles', 'oil']
# ['Doubles', 'oil', 'film']
# ['oil', 'film', 'strength']
# ['film', 'strength', 'and']
# ['strength', 'and', 'prevents']
# ['and', 'prevents', 'oil']
# ['prevents', 'oil', 'from']
# ['oil', 'from', 'breaking']
# ['from', 'breaking', 'down.']
# ['breaking', 'down.', 'Since']
# ['down.', 'Since', 'oil']
# ['Since', 'oil', 'breakdown']
# ['oil', 'breakdown', 'is']
# ['breakdown', 'is', 'prevented,']
# ['is', 'prevented,', 'en...']
# 5HOFO-gLoqo
# Titanium FST is the secret behind Castrol EDGE's oil strength.  Check out this video to feel the power of Titanium FST.
# ['Titanium', 'FST', 'is']
# ['FST', 'is', 'the']
# ['is', 'the', 'secret']
# ['the', 'secret', 'behind']
# ['secret', 'behind', 'Castrol']
# ['behind', 'Castrol', "EDGE's"]
# ['Castrol', "EDGE's", 'oil']
# ["EDGE's", 'oil', 'strength.']
# ['oil', 'strength.', 'Check']
# ['strength.', 'Check', 'out']
# ['Check', 'out', 'this']
# ['out', 'this', 'video']
# ['this', 'video', 'to']
# ['video', 'to', 'feel']
# ['to', 'feel', 'the']
# ['feel', 'the', 'power']
# ['the', 'power', 'of']
# ['power', 'of', 'Titanium']
# ['of', 'Titanium', 'FST.']
# When the titanium molecule comes under pressure in the engine, it momentarily  stiffens the oil .    When the pressure is relieved, the oil converts back to its usual liquid state.    This momentary s...
# ['When', 'the', 'titanium']
# ['the', 'titanium', 'molecule']
# ['titanium', 'molecule', 'comes']
# ['molecule', 'comes', 'under']
# ['comes', 'under', 'pressure']
# ['under', 'pressure', 'in']
# ['pressure', 'in', 'the']
# ['in', 'the', 'engine,']
# ['the', 'engine,', 'it']
# ['engine,', 'it', 'momentarily']
# ['it', 'momentarily', 'stiffens']
# ['momentarily', 'stiffens', 'the']
# ['stiffens', 'the', 'oil']
# ['the', 'oil', '.']
# ['oil', '.', 'When']
# ['.', 'When', 'the']
# ['When', 'the', 'pressure']
# ['the', 'pressure', 'is']
# ['pressure', 'is', 'relieved,']
# ['is', 'relieved,', 'the']
# ['relieved,', 'the', 'oil']
# ['the', 'oil', 'converts']
# ['oil', 'converts', 'back']
# ['converts', 'back', 'to']
# ['back', 'to', 'its']
# ['to', 'its', 'usual']
# ['its', 'usual', 'liquid']
# ['usual', 'liquid', 'state.']
# ['liquid', 'state.', 'This']
# ['state.', 'This', 'momentary']
# ['This', 'momentary', 's...']
# Castrol EDGE is  three times stronger against viscosity breakdown  than leading synthetic and conventional oils.  The new formula has two times the film strength as the previous formula.
# ['Castrol', 'EDGE', 'is']
# ['EDGE', 'is', 'three']
# ['is', 'three', 'times']
# ['three', 'times', 'stronger']
# ['times', 'stronger', 'against']
# ['stronger', 'against', 'viscosity']
# ['against', 'viscosity', 'breakdown']
# ['viscosity', 'breakdown', 'than']
# ['breakdown', 'than', 'leading']
# ['than', 'leading', 'synthetic']
# ['leading', 'synthetic', 'and']
# ['synthetic', 'and', 'conventional']
# ['and', 'conventional', 'oils.']
# ['conventional', 'oils.', 'The']
# ['oils.', 'The', 'new']
# ['The', 'new', 'formula']
# ['new', 'formula', 'has']
# ['formula', 'has', 'two']
# ['has', 'two', 'times']
# ['two', 'times', 'the']
# ['times', 'the', 'film']
# ['the', 'film', 'strength']
# ['film', 'strength', 'as']
# ['strength', 'as', 'the']
# ['as', 'the', 'previous']
# ['the', 'previous', 'formula.']
# ('the', 'previous', 'formula.')

# %%
a = ['Castrol', 'EDGE', 'and']
combined = "_".join(a)
combined
# Out:
# 'Castrol_EDGE_and'
