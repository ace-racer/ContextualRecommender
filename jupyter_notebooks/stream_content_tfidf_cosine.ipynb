# %%
import nltk
from nltk import FreqDist
import string
from nltk.corpus import stopwords
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from sklearn.metrics.pairwise import cosine_similarity
# %matplotlib inline

# %%
def get_stream_details():
    print("Reading the stream details...")
    complete_stream_details_df = pd.read_csv("H:\\TeamStreamz_IW\\code\\data\\card_module_details_content_extracted.csv", encoding="ISO-8859-1")
    if complete_stream_details_df is not None:
        complete_stream_details_dict = {}
        _stream_id_stream_title_dict = {}
        for _, row in complete_stream_details_df.iterrows():
            
            stream_id = str(row["DECKID"])
            stream_title = str(row["DECKNAME"])
            row_content = str(row["HTML_CONTENT"])

            # TODO: add the card title and the module name to the content on which the tags can be generated
            card_title =str(row["CARDTITLE"])
            module_name = str(row["MODULENAME"])
            
            if row_content and "nan" not in row_content:
                # if the stream ID already exists in the dictionary
                if complete_stream_details_dict.get(stream_id):
                    existing_content = complete_stream_details_dict[stream_id]
                    new_content = existing_content + "\n" + row_content.strip()
                    complete_stream_details_dict[stream_id] = new_content
                else:
                    complete_stream_details_dict[stream_id] = row_content.strip()
                    _stream_id_stream_title_dict[stream_id] = stream_title
        
        return complete_stream_details_dict

# %%
stream_details_dict = get_stream_details()
stream_details_dict
# Out:
# Reading the stream details...
# {'1089': 'Welcome Team! We\x92re really glad you are part of this journey!  In this stream you will find out more about the program and its fantastic benefits.   But first, scroll to the next card to complete a small survey, to help us guide your ...\nThis tool is used to capture the brand survey information.       "On a scale of 1-10, how likely are you to recommend a Castrol brand to a customer?"         You cannot edit this c...\n\n\n{"title": "Brand Survey", "primaryField": "field1", "page1": {"header": "{CARD_DESCRIPTION}", "field1": {"type": "Text", "name": "NPS Score", "sequence": 1}, "sequence": 1}, "maxSubmissions": 1}\nThis 123 App is your portal to stay  connected and up-to-date  with Castrol brands and promos.   You will be refreshed with the right information, to enable the best sales conversations.   By interacting wit...\nUp-to-date   knowledge on Castrol Brand 123 messaging\nInteractive quizzes to let you   track your progress   and growth\nBadges and Competitions that entitle you to   great gifts and rewards!\nThe Castrol Zoom App provides interactive information, competitions and rewards on all things Castrol!      Enjoy the journey!',
#  '1090': 'Consumers purchase a qualifying Castrol® oil change service  between September 1, 2017 and January 31, 2018   They  submit  the required information and service receipt to receive a FREE Castrol NFL Team Flee...',
#  '1095': 'In this Stream you will understand the value of  Castrol TRANSMAX , a specialty Automation Transmition Fluid that ensures car transmission operates in the best way.   In a clear way, you will understand:   1. Th...\nAn automatic car on average can make upto  88,000 gear changes  and  18,000 stop-starts  each year.   Continuous engaging of clutches and bands results in glazing of surfaces and poor shift feel...\nCastrol TRANSMAX variants have  Smooth Drive Technology , which automatically adjusts friction levels to changing pressures on critical transmission parts.    This provides better protection, and a smoother...\nAs automatic transmissions become more complex, there\x92s a need for more technologically advanced fluids to ensure vehicle reliability.   Getting the right oil for your car is key to ensuring your transmission operates as designed  ...\nAutomatic transmission is a combination of electronic and mechanical systems, hydraulics and computer processors.      All of these work together to ensure that engine power and gear shifts move to the wheels.\nWith all the gear shifts and changes, it is important to provide the transmission a high quality Automatic Transmission Fluid (ATF).      An ATF ensures smooth gear shifts and smooth driving.\nsHMAQq7W01Y\nCastrol TRANSMAX has Smooth Drive Technology that ensures the automatic transmission of the car is performing at its best.      Watch this video to see how it works.',
#  '1128': 'This tool is used to capture the brand survey information.       "On a scale of 1-10, how likely are you to recommend a Castrol brand to a customer?"         You cannot edit this c...\n\n\n{"title": "Brand Survey", "primaryField": "field1", "page1": {"header": "{CARD_DESCRIPTION}", "field1": {"type": "Text", "name": "NPS Score", "sequence": 1}, "sequence": 1}, "maxSubmissions": 1}',
#  '1267': "Charles \x93Cheers\x94 Wakefield, Castrol\x92s founder, was an entrepreneur with a vision. In 1899 he started the lubricant business from Cheapside, London. In 1906, he started Castrol, and took a personal interest in the new motorised contrapt...\nrpXAV9ybskA\nSince the 1980s, Castrol has supplied NASA with lubricants for the space shuttle programme. More recently, when NASA's Curiosity rover began its exciting mission on Mars in 2012, Castrol industrial grease played a central role in the smooth opera...\n9RSWs44PdkE\nThe journey of oil around a car engine takes as little as 5 secs.In this little time, it protects critical engine parts and prevents damage.This short film takes us through this incredible journey.\nMaintained Castrol as a seperate brand owing to our heritage and personality\nCastrol lubricated the first transatlantic flight\nCastrol played a central role in NASA'S Curiosity rover on Mars in 2012, in the smooth operation of Curiosity's wheels\nCharles \x93Cheers\x94 Wakefield, Castrol\x92s founder, was an entrepreneur with a vision. In 1899 he started the lubricant business from Cheapside, London.  He took a personal interest in the new motorised contraptions of the automobile and th...\nHaving helped pioneer a new kind of motor oil, now CC Wakefield pioneered a new method of getting customers to notice the product:  sponsorship .    The Castrol name appeared on banners and flags at competitive aviation events, ...\nBritish Petroleum (BP) acquired Castrol in 2002.   Castrol is maintained as its own brand, owing to its heritage and personality.   This acquisition allowed Castrol to garner an association with one of the world's leading internati...\nTest for Notification",
#  '1347': 'We at Castrol would like to wish you and your loved ones a very Merry Christmas and Happy New Year!',
#  '1498': "This Stream has information about the  Castrol EDGE  boosted with  TITANIUM FST\x99  brand story?. You will understand  the value of Castrol EDGE to car owners by:   Under...\nToday's engines are subject to more pressure.  Engine pressures are in excess of 10,000kg per square centimetre - that\x92s like balancing five cars on a stiletto heel!  The only thing standing between metal surfaces is the oil....\noyCu07ay5ec\nWatch this video to understand how  Castrol EDGE  has the strength and the technology to handle the pressures of high-performance engines.\nCastrol EDGE  is Castrol\x92s flagship power brand for PCOs and was introduced in 2005.  It is a high performance engine oil for high performing vehicles, approved by major OEMs across the world.\nCastrol EDGE  solves the problem of high engine pressures through its  TITANIUM FST\x99 (Titanium Fluid Strength Technology).    TITANIUM FST\x99   doubles oil strength preventing oil breakdow...\nNMeUjebo1Ac\nCastrol EDGE\x92s  unique  TITANIUM FST\x99  Technology more than doubles oil strength.   Watch this video to see how  Castrol EDGE  works.\nTITANIUM FST\x99   continuously responds and adapts to your engine's every need  It's designed to minimise metal-to-metal contact,  adapting across a variety of engine speeds    This keeps the oil&nb...\nWhen the titanium molecule comes under pressure in the engine, it momentarily  stiffens the oil .    When the pressure is relieved, the oil converts back to its usual liquid state.    This momentary s...\n5HOFO-gLoqo\nTitanium FST is the secret behind Castrol EDGE's oil strength.  Check out this video to feel the power of Titanium FST.\nTitanium technology  physically changes the way oil  behaves under pressure.     Doubles oil film strength and  prevents oil from breaking down.     Since oil breakdown is prevented, en...\nCastrol EDGE is  three times stronger against viscosity breakdown  than leading synthetic and conventional oils.  The new formula has two times the film strength as the previous formula.\nHere is your quick summary on what Castrol EDGE is about:   EDGE is designed for todays smaller, more powerful engines   Its special Fluid Titanium Technology has twice the film strength of our previous formula  Strong...\nTechnological advancements have allowed today\x92s engines to become smaller, yet more powerful and efficient.  The need for engines to deliver increased fuel economy, reduced emissions and high performance means they must work harder than ...\n1  2  3",
#  '1499': "In this Stream you will find information about Castrol MAGNATEC. In a clear way you will:   Understand the engine problem it is trying to solve  The reasons to believe how  Castrol MAGNATEC  solves the pro...\nSgr2uEVmFgM\nWhen an engine stops, oil drains back to the sump.  The next time it starts, it takes about  20 minutes  to come to optimum performance temperature.  This is the time when engine damage can happen as  critical ...\nThe  INTELLIGENT MOLECULES  are specially formulated to cling to critical engine parts like a magnet. This provides an extra layer of protection from the start.\nCastrol MAGNATEC provides instant protection for engines, right from the moment you start.   Intelligent molecules cling to critical engine parts like a magnet, providing an extra layer of protection.  This redu...\n2SaFhLj0FGg\nOur car engines are made of high quality precision parts.  These parts rub against each other very fast, and with great force.  This leads to  ABRASION  in your car engine parts\nHere is a quick summary of Castrol GTX MAGNATEC and its key proposition:    Castrol GTX MAGNATEC focusses on  protecting  car engines at all times   It has  intelligent molecules  that cling to c...\nWelcome to the new year!     We are so happy to see you back and want to share a few exciting things to look forward to on the App.\nWe'd like to give you the chance to win deserving prizes from Castrol, for your knowledge and expertise on our brands.   I'd get an early start on those quizzes and brand streams if I were you!\nWe will be releasing a short survey to get to know your thoughts on the App and what you would like to see more of.    Your feedback is important to us.",
#  '1512': "Welcome to the new year!     We are so happy to see you back and want to share a few exciting things to look forward to on the App.\nWe'd like to give you the chance to win deserving prizes from Castrol, for your knowledge and expertise on our brands.   I'd get an early start on those quizzes and brand streams if I were you!\nWe will be releasing a short survey to get to know your thoughts on the App and what you would like to see more of.    Your feedback is important to us.",
#  '163': 'TXmAk2KZAy4\nNMeUjebo1Ac\nEEuTxFhp3go\nCastrol has launched its strongest ever oil, using TITANIUM Fluid StrengthTHE SET-UPToday\x92s engines are more efficient and more powerful. This has led to the doubling of pressure in the engine, so the oil has to be stronger.THE REASON TO BUYCastrol ed...\nKiRnvRuFj3I\nWhat does it take to be a world-class driver and race your clone? Join neuroscientist Dr. Jack Lewis as he talks about what you need to achieve maximum performance on and off the track.See this before you go for your next market visit ?\nAHOMxMBs_No\nCastrol EDGE Titanium Trials Present: Clone Rival. Watch as we clone Aston Martin Vulcan driver, Darren Turner, and pit him against his ultimate rival: himself. Will he have what it takes to be Titanium Strong?Exciting Video?\n0outa7euRbg\nVP2-ceNdpT4',
#  '1644': 'Survey Card Test\n{"title":"Survey Form","primaryField":"field1","page1":{"header":"{CARD_DESCRIPTION}","field1":{"type":"Text","name":"How long have you been working with Castrol products?","sequence":1},"field2":{"type":"Text","name":"On a scale of 1-10, to what extent ...\n\n',
#  '1655': 'We at Castrol would like to wish you and your loved ones a very Merry Christmas and Happy New Year!\nCastrol',
#  '1658': "This Stream has information about the  Castrol EDGE  boosted with  TITANIUM FST\x99  brand story?.\nToday's engines are subject to more pressure.  The only thing standing between metal surfaces is the oil.     Castrol created EDGE to solve for these new-age advanced engines.\noyCu07ay5ec\nWatch this video to understand how  Castrol EDGE  has the strength and the technology to handle the pressures of high-performance engines.\nCastrol EDGE  solves the problem through its  Titanium Fluid Strength Technology.    TITANIUM FST\x99  doubles oil strength preventing oil breakdown and sharply reduces friction b...\nNMeUjebo1Ac\nCastrol EDGE\x92s  unique  TITANIUM FST\x99  Technology more than doubles oil strength.   Watch this video to see how  Castrol EDGE  works.",
#  '1659': "In this Stream you will find information about Castrol GTX MAGNATEC. In a clear way you will:   Understand the engine problem it is trying to solve  The reasons to believe how  Castrol GTX MAGNATEC  solves...\nSgr2uEVmFgM\nWhen an engine stops, oil drains back to the sump.  The next time it starts, it takes about  20 minutes  to come to optimum performance temperature.  This is the time when engine damage can happen as  critical ...\nThe  INTELLIGENT MOLECULES  are specially formulated to cling to critical engine parts like a magnet. This provides an extra layer of protection from the start.\nCastrol MAGNATEC provides instant protection for engines, right from the moment you start.   Intelligent molecules cling to critical engine parts like a magnet, providing an extra layer of protection.  This redu...\nWhen an engine starts, it takes time to reach the peak protection temperature.  This leaves the engine exposed to damage during warm-up.   75% of engine damage happens during warm-up!\nIntelligent molecules are gravity defying so the oil doesn't drain down to the slump.   Synthetic technology provides increased protection in high and low temperature applications.",
#  '1660': 'In this Stream you will find information about  Castrol GTX  -  Superior Sludge Protection to help extend engine life .  In a clear way, you will:   Understand the engine problem  GTX\nJust like cholesterol,  sludge  (a thick, tar-like substance) build-up is  caused by everyday driving   Sludge clogs up important oilways and engine parts, even in well-maintained vehicles.  If unt...\nCastrol GTX DOUBLE ACTION FORMULA  cleans away old sludge, and protects against new sludge formation \x96 better than industry standards.\n0outa7euRbg\nCastrol GTX  has a unique Double Action formula that keeps the engine oilways free of dirt formation.  Watch this video to see how it works.\nCH_2I9DXdsY\nGTX DOUBLE ACTION FORMULA  reduces sludge and protects against new sludge.   Removing sludge is good for the engine because:   This extends the engine\x92s life significantly.   It keeps engines cool and clean\nGTX DOUBLE ACTION FORMULA  reduces sludge and protects against new sludge. This extends the engine\x92s life significantly.  Removing sludge is good for the engine because:   It keeps engines cool and clean  It prov...',
#  '1661': "Charles \x93Cheers\x94 Wakefield, Castrol\x92s founder, was an entrepreneur with a vision. In 1899 he started the lubricant business from Cheapside, London.  He took a personal interest in the new motorised vehicles, mainly automobiles and aero...\nCC Wakefield pioneered sponsorship as a new method of getting customers to notice the product.  The Castrol name appeared on banners and flags at competitive aviation events and auto races.  Wakefield  extended  the company\x92...\nCastrol lubricated the first transatlantic flight\nCastrol played a central role in NASA'S Curiosity rover on Mars in 2012, in the smooth operation of Curiosity's wheels\nBritish Petroleum (BP) acquired Castrol in 2002.   Castrol is maintained as its own brand, owing to its heritage and personality.   This acquisition allowed Castrol to garner an association with one of the world's leading internati...",
#  '1662': 'HOW WELL DO YOU KNOW YOUR CASTROL BRANDS?   Here is a chance for you to find out - and stand a chance to win prizes at the same time!       HOW TO WIN:      Participants who col...\nEach of the BrandCheck winners can collect an exclusive Castrol Victorinox TA4.0 Packable Back Pack as their prize. Please collect your prize from your respective team managers.',
#  '1670': "In this Stream you will find information about  Castrol GTX  -  Superior Sludge Protection to help extend engine life .  In a clear way, you will:   Understand the engine problem  GTX\nJust like cholesterol,  sludge  (a thick, tar-like substance) build-up is  caused by everyday driving   Sludge clogs up important oilways and engine parts, even in well-maintained vehicles.  If unt...\nCastrol GTX  is one of the world's most trusted motor oils.   Severe driving conditions such as every day stop-and-go/stop-start-traffic, harsh weather conditions and extended drain intervals, can all cause the build-u...\nCastrol GTX DOUBLE ACTION FORMULA  cleans away old sludge, and protects against new sludge formation \x96 better than industry standards.\n0outa7euRbg\nCastrol GTX  has a unique Double Action formula that keeps the engine oilways free of dirt formation.  Watch this video to see how it works.\nCASTROL GTX helps extend the life of your engine\nGTX DOUBLE ACTION FORMULA  reduces sludge and protects against new sludge. This extends the engine\x92s life significantly.  Removing sludge is good for the engine because:   It keeps engines cool and clean  It prov...\nCH_2I9DXdsY\nGTX DOUBLE ACTION FORMULA  reduces sludge and protects against new sludge.   Removing sludge is good for the engine because:   This extends the engine\x92s life significantly.   It keeps engines cool and clean\nHere's a quick summary of what Castrol GTX offers:    Castrol GTX focuses on making engines last longer   Its Double Action Formula removes sludge from critical oilways   Removing sludge keeps engines cool an...\n0outa7euRbg\nCastrol GTX  has a unique Double Action formula that keeps the engine oilways free of dirt formation.  It clears away the dirt particles and prevents the smaller dirt particles to join together and form sludge in the vital oilways...\nIrv Gordon, drove more than 3 million miles, using only Castrol GTX in his Volvo.    Irv began using Castrol GTX as recommended by his dealer in 1968, and has used it ever since.     Castrol GTX\nThe Castrol GTX Sludge Tower represents the vital oilways in an engine.  When you turn the demo over, the coloured balls represent the oil trying to flow through the oilways to protect critical engine parts. Sludge gets in the way, and can cause ...\n_fMBvrSF4pE\nWatch what Irv Gordon has to say about hitting world records with Castrol GTX.",
#  '1857': 'MqK0BQ1NKy8\nWatch this video to see how the new and improved Castrol Activ works!\nyWM8HTx9O5c\nPanoorin ang video na ito para malaman kung paano gumagana ang new and improved Castrol Activ!',
#  '199': "Castrol EDGE  is Castrol\x92s flagship power brand for PCOs and was introduced in 2005.  It is a high performance engine oil for high performing vehicles, approved by major OEMs across the world.\nNMeUjebo1Ac\nCastrol EDGE  unique  TITANIUM FST\x99   doubles oil strength in oil film protection. This makes the oil most equipped to handle the high pressures of engines today.    Watch this video to see how...\nToday's engines are more efficient and more powerful, which in-turn makes them subject to more pressure.  In some areas, engine pressures are in excess of 10,000kg per square centimetre - that\x92s like balancing five cars on a stiletto hee...\noyCu07ay5ec\nWatch this video to understand how  Castrol EDGE  has the strength and the technology to handle the pressures of high-performance engines.\nCastrol EDGE  solves the problem of high engine pressures through its  TITANIUM FST\x99 (Fluid Strength Technology).    TITANIUM FST\x99   doubles oil strength preventing oil breakdown and sha...\nTITANIUM FST\x99   continuously responds and adapts to your engine's every need even under the severest possible pressures.  It's designed to minimise metal-to-metal contact, constantly adapting across a variety of engine spee...\n1KGh8D0AwBs\nThe Castrol R&amp;D Technology is amongst the best in the world. The Castrol Stress Test here shows how the double film strength of  Castrol EDGE  reduces metal-to-metal contact, making it the strongest oil in the world.\nThis Stream has information about the  Castrol EDGE  boosted with  TITANIUM FST\x99  brand story?. You will understand  the value of Castrol EDGE to car owners by:   Understanding the engine ...\nTitanium technology  physically changes the way oil  behaves under pressure.     Doubles oil film strength and  prevents oil from breaking down\n5HOFO-gLoqo\nTitanium FST is the secret behind Castrol EDGE's oil strength.  Check out this video to feel the power of Titanium FST.\nWhen the titanium molecule comes under pressure in the engine, it momentarily  stiffens the oil .    When the pressure is relieved, the oil converts back to its usual liquid state.    This momentary s...\nCastrol EDGE is  3X stronger against viscosity breakdown  than leading oils  Titanium technology  physically changes the way oil behaves  under extreme pressures  Friction is reduced and  en...\nTechnological advancements have allowed today\x92s engines to become smaller, yet more powerful and efficient.  The need for engines to deliver increased fuel economy, reduced emissions and high performance means they must work harder than ...",
#  '2003': 'GTX 4 L \x96 4 Points  MAGNATEC 4L \x96 12 Points  EDGE 4L \x96 20 Points\nStart date \x96  End date \x96 31st Dec 2018     Incentive applicable to \x96 Saudi Arabia, UAE, Oman, Bahrain and Kuwait  Mechanics     We have the right to change or terminate the program, at incentive provider\x92s d...\nCongratulations on becoming a participant in our incentive program. We hope this association is mutually beneficial.     In case of any inquiry please ask the Castrol merchandiser or a Castrol sales team member     Please rea...\nWho defines the incentive points &amp; criteria?   Incentives will be defined by local markets in accordance with Castrol policies as well as local legislation.      What are the Incentive ...\nWill I also get rewarded for completing E Learnings or points earned by the Castrol Zoom App?       I tried to claim a Code and the Castrol Zoom App does not validate the Code \x96 what is the reason for this?\nHow do I see the redemption catalog?  Check with Castrol Sales Rep  Can I make multiple redemption requests?  Redemption request should be set at a minimum number of points (100 points) upon request submission mechanic should wait for r...\nStep 1: Click on Enter the product code  Step 2: Enter the Foil Code for the product you are selling  Step 3: Click on Submit  Step 4: You will see message that your sale has been submitted\nOptional: You can upload the proof of sale as an attachment to the incentive screen   Click on upload arrow at the top right corner after submitting sale for incentive  You can either take a picture/upload from your Gallery.\nProduct Submission:  As you submit your sale for Incentive, notice the successful submission message. The first stage will be submission.      Product Code Validation:  Submitted foil code go through mu...\nYou can track your incentive transactions from user center:  Navigate to User center -&gt; Transactions\nAll the incentive transactions are listed under the transactions section.     Click and open any of the transaction to view the detailed flow of the transaction\nWhat happens when you claim a product already submiited by other Mechanic  Your incentive get failed in second stage "Product code validation" displaying error message "Duplicate Product code".   Incase, your claim is genuine, please reac...\nWhere to check the points earned through incentive:  User Center -&gt; Incentive Summary\nWhat can you read from incentive Summary:   Incentive Program:  Under the points heading you will find the Incentive campaign name.(BK Program for Redemption)   Earned So far : The number of points earned by you...\nHere you can see the list of products which are part of active Incentive scheme and the points you can earn per foil!   This is the total amount you have after redemption(if any)  Name of the product which is applicable for the In...\nWhat   are   the permission required by the Tribe app?      Camera \x96 App requires the camera permission to enable user to take profile pictures.     Storage \x96 Storage permissi...\nYou can Redeem your points for gift/vouchers.  How can you Redeem points:   Navigate to user center -&gt; Incentive Summary -&gt; Click on Redeem  In the pop up enter the number of points you want to redeem and comments(optional)\nRedemption Submission : As you submit the redemption request, points get deducted from your balance and request will be in submission state   Redemption Validation : The balanace avaiability and other criteria are v...\nAs DSR approves the redemption, you will be notified on the status  Navigate to user center -&gt; Redemptions  Open transaction with "Redemption Payout"  Click on + mark  Click on Receive and the OK\nYour transaction gets completed and the reaches Redemption payout phase\nAs the DSR rejects your redemption request, the transaction will be moved to failed redemption acceptance state.   The points deducted for the request will be credited back to your total score.\nIf you get notified that redemption ...
#  '2006': 'Now with  Castrol Zoom  you will be  rewarded  on your Castrol product sales!      Enter the code under the pack foil and earn points and redeem!   Answer brand questions and earn points and redeem\nYou will get notified as the Mechanic opens redemption request  Steps to Navigate to request:   Open user center -&gt; Redemptions  You notice the transactions pending approval with state "Redemption Acceptance"\nThe request has details like who raised request, on which date and no.of points they want to redeem.  click on transaction to open it and check the status\nTo approve the transaction, click on "+" icon and then click on "Accept"  Click on yes when prompted if you are sure  The redemption approval request will be submitted\nThe redemption request is fulfilled either through gift/voucher/cash by you manually  While you deliver the gift in hand to mechanic, you will have to open the user center -&gt; redemption  Open the transaction which is approved\nOpen user center -&gt; Redemptions  Click open the redemption request  Click on "+" symbol at the right bottom of the screen  Select reject and click OK   The mechanic gets notified that the redemption request ...\nThe situation arises when mechanic acknowledge that they have not recieved the gift for a delivered redemption  When mechanic says the redemption is not received, admin user gets notified and will be handled manually by admin\nEllK3pOGVds',
#  '201': "Charles \x93Cheers\x94 Wakefield, Castrol\x92s founder, was an entrepreneur with a vision. In 1899 he started the lubricant business from Cheapside, London. In 1906, he started Castrol, and took a personal interest in the new motorised contrapt...\nrpXAV9ybskA\nSince the 1980s, Castrol has supplied NASA with lubricants for the space shuttle programme. More recently, when NASA's Curiosity rover began its exciting mission on Mars in 2012, Castrol industrial grease played a central role in the smooth opera...\n9RSWs44PdkE\nThe journey of oil around a car engine takes as little as 5 secs.In this little time, it protects critical engine parts and prevents damage.This short film takes us through this incredible journey.\nMaintained Castrol as a seperate brand owing to our heritage and personality\nCastrol lubricated the first transatlantic flight\nCastrol played a central role in NASA'S Curiosity rover on Mars in 2012, in the smooth operation of Curiosity's wheels\nCharles \x93Cheers\x94 Wakefield, Castrol\x92s founder, was an entrepreneur with a vision. In 1899 he started the lubricant business from Cheapside, London.  He took a personal interest in the new motorised contraptions of the automobile and th...\nHaving helped pioneer a new kind of motor oil, now CC Wakefield pioneered a new method of getting customers to notice the product:  sponsorship .    The Castrol name appeared on banners and flags at competitive aviation events, ...\nBritish Petroleum (BP) acquired Castrol in 2002.   Castrol is maintained as its own brand, owing to its heritage and personality.   This acquisition allowed Castrol to garner an association with one of the world's leading internati...",
#  '2010': 'Up-to-date   knowledge on Castrol Brand 123 messaging\nInteractive quizzes to let you   track your progress   and growth\nSales incentives   and brand points rewarded immediately.\nBadges and Competitions that entitle you to   great gifts and rewards!\nEllK3pOGVds\nWelcome Team! We\x92re really glad you are part of this journey!  Castrol Zoom is your mobile app for all information and tools about Castrol.    Earn points &amp; redeem rewards by interacting with the co...',
#  '202': 'castrol',
#  '203': "In this Stream you will find information about Castrol MAGNATEC. In a clear way you will:   Understand the engine problem it is trying to solve  The reasons to believe how  Castrol MAGNATEC  solves the problem\nCastrol MAGNATEC , offers instant protection to an engine, from the moment the engine is started.  This leading Castrol engine oil brand has been helping motorists protect their car engines for almost 20 years.\nPD9jKFjREnI\nCastrol MAGNATEC\x92s  intelligent molecules cling to critical engine parts like a MAGNET, giving the engine an extra layer of protection from the start, and throughout warm-up.  Watch this video to see how it works.\nCASTROL MAGNATEC     Instant protection from engine wear during warm-up\nCASTROL MAGNATEC STOP START   Instant protection from engine wear due to stop start action in high traffic city driving\nggY96Ga0ytg\nWhen an engine stops, oil drains back to the sump. The next time it starts, it takes about 20 minutes to come to optimum performance temperature.  This is the time when engine damage can happen as critical parts are left exposed. 75%  of eng...\nThe  INTELLIGENT MOLECULES  are specially formulated to cling to critical engine parts like a magnet, providing an extra layer of protection from the start, and throughout warm-up of the engine.\nCastrol MAGNATEC provides instant protection for engines, right from the moment you start.   Up to 75% of engine wear happens during warm-up. When the engine stops oil drains off critical engine parts, however Castrol MAGNATEC's I...\n8hnkexBfJtQ\nIntelligent molecules cling and form a self healing layer so that it is always ready to protect at each of the critical stages of  STOP START  driving.  Watch the video on how  Castrol MAGNATEC STOP START  works to p...\nThe gravity defying action of the oil makes it cling to critical engine parts, when the oil drains down, giving an extra layer of protection against engine wear.  It is  combined with synthetic technology to provide increased protecti...\nQF9sB6LE8So\nWhen cars are subjected to very high frequency of stop and start in a congested city drive.  It is estimated that even a normal driver can stop and start as many as 18,000 times in a year.  All that idling in traffic and waiting at junctions...\nCastrol MAGNATEC STOP START provides instant Protection from the moment you start. Every time you start.   Intelligent molecules that cling and form a self healing layer so that it is always ready to protect at each of the critica...\nCastrol MAGNATEC protects engines during warm-up because of its  intelligent molecules\nWhen an engine starts, it takes 20 minutes for the oil to reach an optimal temperature   This leaves the engine exposed to damage during warm-up.  75% of engine damage happens during warm-up!\nCastrol MAGNATEC  offers protection during start and warm-up.   Castrol MAGNATEC STOP-START  specially helps in protecting engines in stop-start activity in congestions, etc.",
#  '2030': "In this stream, you will receive updated information about Castrol EDGE and its 123 proposition.      But first, take a chance to refresh your knowledge on Castrol, and get started.\nCastrol EDGE  is a power brand for passenger cars, introduced in 2005.    It is for  high performing  cars, that need  strong  oils in their engines.\nNew-age advanced engines are smaller, and stronger.    This means the engine, and the oil protecting it, faces more pressure.\noyCu07ay5ec\nWatch this video to understand how  Castrol EDGE  has the strength and the technology to handle the pressures of high-performance engines.\nCastrol EDGE has  Titanium Fluid Strength Technology (FST)  that d oubles the oil strength  at points of pressure.     FREEDOM TO DRIVE - STRENGTH TO PERFORM\nNMeUjebo1Ac\nWatch this video for a full overview of why Castrol EDGE is the right oil for high performance cars today.\nHere is your quick summary on what Castrol EDGE is about:   EDGE is designed for todays smaller, more powerful engines   Its special Fluid Titanium Technology has twice the film strength of our previous formula  Strong...\nTitanium technology  physically changes the way oil  behaves under pressure.     Doubles oil film strength and  prevents oil from breaking down.     Since oil breakdown is prevented, en...\n5HOFO-gLoqo\nTitanium FST is the secret behind Castrol EDGE's oil strength.  Check out this video to feel the power of Titanium FST.\nWhen the titanium molecule comes under pressure in the engine, it momentarily  stiffens the oil .    When the pressure is relieved, the oil converts back to its usual liquid state.    This momentary s...\nCastrol EDGE is  three times stronger against viscosity breakdown  than leading synthetic and conventional oils.  The new formula has two times the film strength as the previous formula.",
#  '2031': "In this stream you will see all the updated information about Castrol MAGNATEC.\nWhen an engine starts, it takes 20 minutes for the oil to reach an optimal temperature   This leaves the engine exposed to damage during warm-up.  75% of engine damage happens during warm-up!\nWhen the engine stops, oil drains back to the sump, so critical engine parts are exposed and not protected by the oil.   This leads to abrasion and major engine wear!\nCastrol MAGNATEC protects engines during warm-up because of its  intelligent molecules\nThe  INTELLIGENT MOLECULES  are specially formulated to cling to critical engine parts like a magnet. This provides an extra layer of protection from the start.\nCastrol MAGNATEC  offers protection during start and warm-up.   Castrol MAGNATEC STOP-START  specially helps in protecting engines in stop-start activity in congestions, etc.\nCastrol MAGNATEC STOP-START specifically protects the engine in busy traffic conditions, offering 20%* more protection from damaging stop-start wear.\nCastrol MAGNATEC provides instant protection for engines, right from the moment you start.   Intelligent molecules cling to critical engine parts like a magnet, providing an extra layer of protection.  This redu...\nggY96Ga0ytg\nOur car engines are made of high quality precision parts.  These parts rub against each other very fast, and with great force.  This leads to  ABRASION  in your car engine parts\nWhen an engine starts, it takes time to reach the peak protection temperature.  This leaves the engine exposed to damage during warm-up.   75% of engine damage happens during warm-up!\nWhen an engine starts, it takes time to reach the peak protection temperature.  This leaves the engine exposed to damage during warm-up.   75% of engine damage happens during warm-up!\nIntelligent molecules are gravity defying so the oil doesn't drain down to the slump.   Synthetic technology provides increased protection in high and low temperature applications.\n75% OF ENGINE WEAR HAPPENS DURING  WARM-UP !\nWhen the engine stops, oil drains back to the sump, so critical engine parts are exposed and not protected by the oil.   This leads to abrasion and major engine wear!",
#  '2032': "In this stream, you will find all the information you need about Castrol GTX.      Let's get started on your easy 1-2-3 refresh of Castrol GTX.\nJust like cholesterol,  sludge  (a thick, tar-like substance) build-up is  caused by everyday driving   Sludge clogs up important oilways and engine parts, even in well-maintained vehicles.  If unt...\nCastrol GTX DOUBLE ACTION FORMULA  cleans away old sludge, and protects against new sludge formation \x96 better than industry standards.\n0outa7euRbg\nCastrol GTX  has a unique Double Action formula that keeps the engine oilways free of dirt formation.  Watch this video to see how it works.\nCASTROL GTX helps extend the life of your engine\nHere's a quick summary of what Castrol GTX offers:    Castrol GTX focuses on making engines last longer   Its Double Action Formula removes sludge from critical oilways   Removing sludge keeps engines cool an...\n0outa7euRbg\nCastrol GTX  has a unique Double Action formula that keeps the engine oilways free of dirt formation.  It clears away the dirt particles and prevents the smaller dirt particles to join together and form sludge in the vital oilways...\nIrv Gordon, drove more than 3 million miles, using only Castrol GTX in his Volvo.    Irv began using Castrol GTX as recommended by his dealer in 1968, and has used it ever since.     Castrol GTX\nThe Castrol GTX Sludge Tower represents the vital oilways in an engine.  When you turn the demo over, the coloured balls represent the oil trying to flow through the oilways to protect critical engine parts. Sludge gets in the way, and can cause ...\n_fMBvrSF4pE\nWatch what Irv Gordon has to say about hitting world records with Castrol GTX.",
#  '2033': "Castrol has been a brand of firsts all throughout history.     This stream will show you the historic innovations and ambitions of the company.\nIn 1899, Charles \x93Cheers\x94 Wakefield, Castrol\x92s founder, started the lubricant business from Cheapside, London.  Created oils for new motor vehicles, that were runny enough to work from cold at start-up and thick enough to keep workin...\nWakefield  extended  the company\x92s increasingly profitable  product line  to include oils developed especially for car manufacturer\x92s individual engines.\nCastrol lubricated the first transatlantic flight\nCastrol played a central role in NASA'S Curiosity rover on Mars in 2012, in the smooth operation of Curiosity's wheels",
#  '2034': 'EllK3pOGVds\nWelcome Team! We\x92re really glad you are part of this journey!  Castrol Zoom is your mobile app for all information and tools about Castrol.    Earn points &amp; redeem rewards by interacting with the co...\nWelcome Team! We\x92re really glad you are part of this journey!  Castrol Zoom is your mobile app for all information and tools about Castrol.    Earn points &amp; redeem rewards by interacting with the co...\nUp-to-date   knowledge on Castrol Brand 123 messaging\nInteractive quizzes to let you   track your progress   and growth\nSales incentives   and brand points rewarded immediately.\nBadges and Competitions that entitle you to   great gifts and rewards!',
#  '2035': 'EllK3pOGVds\nWelcome Team! We\x92re really glad you are part of this journey!  Castrol Zoom is your mobile app for all information and tools about Castrol.    Earn points &amp; redeem rewards by interacting with the co...\nWelcome Team! We\x92re really glad you are part of this journey!  Castrol Zoom is your mobile app for all information and tools about Castrol.    Earn points &amp; redeem rewards by interacting with the co...\nUp-to-date   knowledge on Castrol Brand 123 messaging\nInteractive quizzes to let you   track your progress   and growth\nSales incentives   and brand points rewarded immediately.\nBadges and Competitions that entitle you to   great gifts and rewards!',
#  '2036': "In this stream, you will receive updated information about Castrol EDGE and its 123 proposition.      But first, take a chance to refresh your knowledge on Castrol, and get started.\nCastrol EDGE  is a power brand for passenger cars, introduced in 2005.    It is for  high performing  cars, that need  strong  oils in their engines.\nNew-age advanced engines are smaller, and stronger.    This means the engine, and the oil protecting it, faces more pressure.\nCastrol EDGE has  Titanium Fluid Strength Technology (FST)  that d oubles the oil strength  at points of pressure.     FREEDOM TO DRIVE - STRENGTH TO PERFORM\nNMeUjebo1Ac\nWatch this video for a full overview of why Castrol EDGE is the right oil for high performance cars today.\nHere is your quick summary on what Castrol EDGE is about:   EDGE is designed for todays smaller, more powerful engines   Its special Fluid Titanium Technology has twice the film strength of our previous formula  Strong...\nTitanium technology  physically changes the way oil  behaves under pressure.     Doubles oil film strength and  prevents oil from breaking down.     Since oil breakdown is prevented, en...\n5HOFO-gLoqo\nTitanium FST is the secret behind Castrol EDGE's oil strength.  Check out this video to feel the power of Titanium FST.\nWhen the titanium molecule comes under pressure in the engine, it momentarily  stiffens the oil .    When the pressure is relieved, the oil converts back to its usual liquid state.    This momentary s...\nCastrol EDGE is  three times stronger against viscosity breakdown  than leading synthetic and conventional oils.  The new formula has two times the film strength as the previous formula.",
#  '2037': "In this stream you will see all the updated information about Castrol MAGNATEC.\nWhen an engine starts, it takes 20 minutes for the oil to reach an optimal temperature   This leaves the engine exposed to damage during warm-up.  75% of engine damage happens during warm-up!\nWhen the engine stops, oil drains back to the sump, so critical engine parts are exposed and not protected by the oil.   This leads to abrasion and major engine wear!\nCastrol MAGNATEC protects engines during warm-up because of its  intelligent molecules\nThe  INTELLIGENT MOLECULES  are specially formulated to cling to critical engine parts like a magnet. This provides an extra layer of protection from the start.\nCastrol MAGNATEC  offers protection during start and warm-up.   Castrol MAGNATEC STOP-START  specially helps in protecting engines in stop-start activity in congestions, etc.\nCastrol MAGNATEC STOP-START specifically protects the engine in busy traffic conditions, offering 20%* more protection from damaging stop-start wear.\nCastrol MAGNATEC provides instant protection for engines, right from the moment you start.   Intelligent molecules cling to critical engine parts like a magnet, providing an extra layer of protection.  This redu...\nggY96Ga0ytg\nOur car engines are made of high quality precision parts.  These parts rub against each other very fast, and with great force.  This leads to  ABRASION  in your car engine parts\n2SaFhLj0FGg\nOur car engines are made of high quality precision parts.  These parts rub against each other very fast, and with great force.  This leads to  ABRASION  in your car engine parts\nWhen an engine starts, it takes time to reach the peak protection temperature.  This leaves the engine exposed to damage during warm-up.   75% of engine damage happens during warm-up!        ...\nIntelligent molecules are gravity defying so the oil doesn't drain down to the slump.   Synthetic technology provides increased protection in high and low temperature applications.\n75% OF ENGINE WEAR HAPPENS DURING  WARM-UP !\nWhen the engine stops, oil drains back to the sump, so critical engine parts are exposed and not protected by the oil.     This leads to abrasion and major engine wear!\nThis is why engine parts need to be  protected at ALL TIMES .  Castrol  GTX MAGNATEC  has  INTELLIGENT MOLECULES  that cling to critical engine parts like a magnet.   This provides a...\nIntelligent molecules are gravity defying   They cling to critical engine parts   They add a layer of protection during warm-up and beyond  They dramatically reduce engine wear and leaves critical engine parts",
#  '2038': "In this stream, you will find all the information you need about Castrol GTX.      Let's get started on your easy 1-2-3 refresh of Castrol GTX.\nJust like cholesterol,  sludge  (a thick, tar-like substance) build-up is  caused by everyday driving   Sludge clogs up important oilways and engine parts, even in well-maintained vehicles.  If unt...\nCastrol GTX DOUBLE ACTION FORMULA  cleans away old sludge, and protects against new sludge formation \x96 better than industry standards.\n0outa7euRbg\nCastrol GTX  has a unique Double Action formula that keeps the engine oilways free of dirt formation.  Watch this video to see how it works.\nHere's a quick summary of what Castrol GTX offers:    Castrol GTX focuses on making engines last longer   Its Double Action Formula removes sludge from critical oilways   Removing sludge keeps engines cool an...\n0outa7euRbg\nCastrol GTX  has a unique Double Action formula that keeps the engine oilways free of dirt formation.  It clears away the dirt particles and prevents the smaller dirt particles to join together and form sludge in the vital oilways...\nIrv Gordon, drove more than 3 million miles, using only Castrol GTX in his Volvo.  Irv began using Castrol GTX as recommended by his dealer in 1968, and has used it ever since.    Castrol GTX\nThe Castrol GTX Sludge Tower represents the vital oilways in an engine.  When you turn the demo over, the coloured balls represent the oil trying to flow through the oilways to protect critical engine parts. Sludge gets in the way, and can cause ...\n_fMBvrSF4pE\nWatch what Irv Gordon has to say about hitting world records with Castrol GTX.",
#  '2039': "Castrol has been a brand of firsts all throughout history.     This stream will show you the historic innovations and ambitions of the company.\nIn 1899, Charles \x93Cheers\x94 Wakefield, Castrol\x92s founder, started the lubricant business from Cheapside, London.  Created oils for new motor vehicles, that were runny enough to work from cold at start-up and thick enough to keep workin...\nWakefield  extended  the company\x92s increasingly profitable  product line  to include oils developed especially for car manufacturer\x92s individual engines.\nCastrol lubricated the first transatlantic flight\nCastrol played a central role in NASA'S Curiosity rover on Mars in 2012, in the smooth operation of Curiosity's wheels\nIt is the  world's leading  manufacturer, distributor and marketer of premium lubricating oils.    2.  It is headquartered in UK.     3. Castrol is represented in more than  120 countri...\nCastrol has 7 R&amp;D centers globally, working to develop and test hundreds of new products every year.\nCastrol has held long-term partnership with major brands such as Audi, Ford, Renaut and Volkswagen, securing major world records and racing wins!",
# ...
#  '522': "Oil specifications define what type of engine a particular oil is suitable for and describe its qualities, such as   endurance, strength and fuel efficiency .     ?Using the correct oil ...\nACEA (association des constructeurs européens d'automobiles)  governs oil specifications in Europe  ACEA sets the standards for European engine lubricant specification. All oils have to pass a sequence of tests, which are updated...\nEach of the   categories A, B C and E   is further sub-divided. Each sub-category has a number and offers a different level of oil performance.   ?Catalyst compatibility oils . Categ...\nOEM (Original Equipment Manufacturer)    specifications are developed by the  car manufacturers   ?Most OEMs have their own specific set of requirements for their car\x92s engines and these are defined...\nAll oils are created for a specific use and tested to guarantee their performance.   For example, some are designed to keep high-mileage vehicles operating for longer, whilst others are meant for high-performance engines.",
#  '523': "Did you know that changing the oil regularly is probably the single most important thing that your customers can do to ensure proper engine function, reduce engine repairs and maintain their engine\x92s performance.  The next set of cards will rev...\nChanging a vehicle's engine oil on a regular basis ensures   proper engine oil lubrication   and   reduces friction  .    This prevents metal pa...\nOld, worn-out engine oil cannot effectively absorb engine heat.   Replacing a vehicle's engine oil with new, high-quality engine oil will help to regulate engine operating temperatures.\nAs oil moves around an engine it picks up tiny, microscopic contaminates and engine wear particles.    These particles are transported to the oil filter, which sieves them out.   Fresh oil is better able to ...\nEngine sludge  is a combination of degraded engine oil, engine wear particles and dirt. It can be highly damaging to an engine.      Changing the oil removes engine sludge and helps maintain ...\nThe length of time, or distance travelled, between oil changes depends on lots of factors such as the type of car, the driving style and environment.  To reduce repairs and maintain performance, it\x92s essential to follow the manufacturer\x92s rec...\nYes it is normal. Every time you start the car it will burn off a tiny amount of oil.   Over time, this can cause the oil levels to drop, particularly if you do a lot of short journeys.  However ...\nThe warning light will come on when the oil pressure drops and by this time the engine could have been damaged.    It\x92s best to use the dipstick to check the oil levels a couple of times a month and top up wit...\nNew oil has a yellowish brown colour, which will naturally get darker as the oil gets older and dirtier.     Diesel engine oil goes black very quickly but is still OK for the length of the oil service interval.\n9RSWs44PdkE\nThe journey of oil around a car engine takes as little as 5 secs.In this little time, it protects critical engine parts and prevents damage.This short film takes us through this incredible journey.",
#  '524': 'Since the first cars, the demands of automotive engines have evolved and engine oils have evolved alongside them    At Castrol, we have been pioneering advances in the motor oil industry for over 100 years\nGovernments and legislative bodies impose emissions limits on harmful gasses.    Modern cars use catalytic converts and filters to trap the noxious emissions and clean the exhaust.  ?Unfortunately, some of the components of engine oil ...\nIn the past, most cars needed an oil change every 5,000 km.?   Over the years, advances in lubricant technology allow the same oil to be used for longer without loss of performance.  This saves the consumer money and time and reduces the...\nThere are a number of factors driving the need to increase fuel efficiency, including:  Legislators use taxation, fines and other incentive schemes to encourage car manufacturers to improve the fuel efficiency of their vehicles.    Engin...\nEngines technology is constantly evolving. Smaller, higher-powered engines are placing   greater demands on motor oil than ever before .   Oil needs to be strong enough to cope with these demands a...\nAs you\x92ve just seen, these are exciting and challenging times in the motor oil industry.  Castrol\x92s response to these challenges is to     invest in research and development...\nBg4hsI7AGpo\nThe new Brand123 App introduction',
#  '548': '{"title": "SG - Journey Plan", "primaryField": "field1", "page1": {"header": "{CARD_DESCRIPTION}", "field1": {"type": "Text", "name": "Account Name", "sequence": 1}, "sequence": 1}, "maxSubmissions": 99999}\n\n\n{"title": "SG - Journey Plan Check Out", "primaryField": "field1", "page1": {"field2": {"type": "Number", "name": "Order Value", "sequence": 2}, "header": "{CARD_DESCRIPTION}", "field1": {"type": "Number", "name": "Order Volume", "sequence": 1}, "sequenc...',
#  '558': 'Most people don\x92t know why, or just how much the type of oil they use affects their engine\x92s lifespan and performance.   To answer your customer\x92s questions with confidence, you need to know a bit about oil.\nIt creates a  thin lubricating layer  between metal surfaces, which stops them from grinding against each other and becoming worn or damaged.  Oil also  prevents corrosion , h...\nCar engines operate under immense  heat  and  pressure .    The oil needs to be strong enough to  keep the hot metal surfaces apart  so that...\nSome parts of a car\x92s engine can rotate at 150,000 rpm - that\x92s   faster than a jet\x92s engine!\nTemperatures in the piston area of a car can reach   over 350°C.     That\x92s   three times hotter     than the temperature at w...\nEngines work under pressure that can reach up to   10 tonnes per cm squared .    That\x92s equal to balancing   7 mid sized cars on one fingernail!\n9RSWs44PdkE\nThe journey of oil around a car engine takes as little as five seconds. In this time it protects critical engine parts, preventing damage. This short film take us on this incredible journey, truly demonstrating oil in action.',
#  '561': 'There are three types of engine oils:\nSynthetic oils   like Castrol Edge are chemically synthesised to meet the exact demands of modern engines.    This makes them more expensive to produce, but because they are tailor made,\nThey provide better performance, protection and fuel economy than mineral oils, but at a cheaper cost, where full synthetic performance is not necessary.\nBetter lubrication  at both hot and cold temperatures   Increased horsepower and torque  due to reduced friction  Enhanced cleanliness and  superior engine protection\nI cannot switch back to conventional motor oil once I\x92ve used synthetic oil    This is a common myth and   completely untrue     You can switch back and forth at any ...\nOnly high performance and luxury cars need synthetic oils      Any car   can use synthetic oils.    Synthetic oils will enhance the engine  ...\nUsing synthetic motor oil will void my vehicle\x92s warranty      No.      Synthetics are formulated to not only meet   minimum indust...\nViscosity modifiers   allow the oils to work effectively at high and low temperatures.      Pour point depressants   help lubricants to flow ...\nCorrosion inhibitors     prevent water and acids from corroding the metal.    Friction modifiers   reduce the friction between movi...\nThey tend to be  cheaper than synthetic oils ; however they do not provide the best performance, protection or fuel economy.  ?',
#  '565': "Viscosity is a measure of how easily a liquid flows \x96 or in other words, it's   a measure of how \x91thick\x92 or \x91thin\x92 the liquid is.     To demonstrate this, answer yourself this questio...\nYes, water will flow faster than honey!    This is because water is \x91thinner\x92 than honey.  Hence, it can be said that:    \x91Thin\x92 liquids have a lower viscosity and fl...\nNow if you heat the honey up, what would happen to its thickness?   As you heat the honey, it would get  \x91thinner\x92  and its  viscosity would fall.   The same is true of the oil in an eng...\nAt low temperatures oil gets thicker and its viscosity increases.     If the viscosity is too high when the engine is cold, the oil won\x92t be able to move around the engine and protec...\nBecause the viscosity of oil changes with the temperature, multi-grade oils were developed to provide protection across a range of operating temperatures.  The  SAE (Society of Automotive Engineers)  scale shows the  viscosi...\nLet\x92s look at what  5W-30  means in this image.      The first number followed by the letter  W  describes the viscosi...\nThe second number describes how thick the oil is at the engine\x92s normal operating temperature.     The higher the second number, the thicker the oil.   If it's too thin when hot...",
#  '570': "Oil specifications define what type of engine a particular oil is suitable for and describe its qualities, such as   endurance, strength and fuel efficiency .     ?Using the correct oil ...\nACEA (association des constructeurs européens d'automobiles)  governs oil specifications in Europe  ACEA sets the standards for European engine lubricant specification. All oils have to pass a sequence of tests, which are updated...\nEach of the   categories A, B C and E   is further sub-divided. Each sub-category has a number and offers a different level of oil performance.   ?Catalyst compatibility oils . Categ...\nOEM (Original Equipment Manufacturer)    specifications are developed by the  car manufacturers   ?Most OEMs have their own specific set of requirements for their car\x92s engines and these are defined...\nAll oils are created for a specific use and tested to guarantee their performance.   For example, some are designed to keep high-mileage vehicles operating for longer, whilst others are meant for high-performance engines.",
#  '578': "Did you know that changing the oil regularly is probably the single most important thing that your customers can do to ensure proper engine function, reduce engine repairs and maintain their engine\x92s performance.  The next set of cards will rev...\nChanging a vehicle's engine oil on a regular basis ensures   proper engine oil lubrication   and   reduces friction  .    This prevents metal pa...\nOld, worn-out engine oil cannot effectively absorb engine heat.   Replacing a vehicle's engine oil with new, high-quality engine oil will help to regulate engine operating temperatures.\nAs oil moves around an engine it picks up tiny, microscopic contaminates and engine wear particles.    These particles are transported to the oil filter, which sieves them out.   Fresh oil is better able to ...\nEngine sludge  is a combination of degraded engine oil, engine wear particles and dirt. It can be highly damaging to an engine.      Changing the oil removes engine sludge and helps maintain ...\nThe length of time, or distance travelled, between oil changes depends on lots of factors such as the type of car, the driving style and environment.  To reduce repairs and maintain performance, it\x92s essential to follow the manufacturer\x92s rec...\nYes it is normal. Every time you start the car it will burn off a tiny amount of oil.   Over time, this can cause the oil levels to drop, particularly if you do a lot of short journeys.  However ...\nThe warning light will come on when the oil pressure drops and by this time the engine could have been damaged.    It\x92s best to use the dipstick to check the oil levels a couple of times a month and top up wit...\nNew oil has a yellowish brown colour, which will naturally get darker as the oil gets older and dirtier.     Diesel engine oil goes black very quickly but is still OK for the length of the oil service interval.\n9RSWs44PdkE\nThe journey of oil around a car engine takes as little as 5 secs.In this little time, it protects critical engine parts and prevents damage.This short film takes us through this incredible journey.",
#  '622': 'Everyday driving causes build-up and sludge in the engine  Sludge can block an engine\x92s vital oilways  If untreated, it can rob an engine of its power and ultimately, its life.?\nCastrol GTX  DOUBLE ACTION FORMULA  cleans away old sludge, and protects against new sludge formation  Removing sludge keeps engine cool and clean and extends engine life\nCastrol GTX has a unique  Double Action formula    This formula clears away dirt particles from engine oilways and prevents the smaller dirt particles to joining together\nIrv Gordon got his new Volvo P1800S in 1966. Now more than 50 years later, he is still using the same car.   He has driven more than  3 million miles - a world record!    Irv has used  ONLY Castrol GT...\nHOW WELL DO YOU KNOW YOUR CASTROL BRANDS?   Here is a chance for you to find out - and stand a chance to win prizes at the same time!    In this  BrandCheck series , you will get five questio...',
#  '623': 'When an engine starts, it takes 20 minutes for the oil to reach an optimal temperature   This leaves the engine exposed to damage during warm-up.  75% of engine damage happens during warm-up!\nCastrol MAGNATEC  contains intelligent molecules that cling to the engine, providing an extra layer of protection and dramatically reducing engine wear during engine warm-up and start.     Castrol MAGN...\nCastrol MAGNATEC  offers protection during start and warm-up.   Castrol MAGNATEC STOP-START  specially helps in protecting engines in stop-start activity in congestions, etc.\nCastrol MAGNATEC protects engines during warm-up because of its  intelligent molecules\nCastrol MAGNATEC STOP-START specifically protects the engine in busy traffic conditions, offering 20%* more protection from damaging stop-start wear.\nTraffic is getting increasingly busy  Research by Castrol and TomTom shows that even a normal driver can stop and start up to 18,000** times a year\nEach time we have to stop and wait in traffic, for example at a red traffic light, the engine is idle  This idling causes damaging wear because loads on critical engine parts can be up to 60% higher than at highway speeds\nHOW WELL DO YOU KNOW YOUR CASTROL BRANDS?   Here is a chance for you to find out - and stand a chance to win prizes at the same time!    In this  BrandCheck series , you will get five questio...',
#  '624': 'Engines today bring high performance, but also face  double the engine pressure   The only thing protecting engines is a thin layer of oil  If the engine oil cannot withstand the high pressure, the engines will fail\nCastrol EDGE has Titanium FST   FST = Fluid Strength Technology  FST doubles oil strength      Castrol EDGE can handle high engine pressure!\nHOW WELL DO YOU KNOW YOUR CASTROL BRANDS?   Here is a chance for you to find out - and stand a chance to win prizes at the same time!    In this  BrandCheck series , you will get five questio...',
#  '634': 'DEMO JOURNEY PLAN\n\n\n{"title": "PH Demo - Journey Plan", "primaryField": "field1", "page1": {"field2": {"type": "Text", "name": "Volume Objective", "sequence": 2}, "header": "{CARD_DESCRIPTION}", "field1": {"type": "Text", "name": "Account Name", "sequence": 1}, "sequence": ...\nAPPLICATION FOR UNSCHEDULED CHECK-IN\n\n\n{"title": "PH Demo - Unscheduled Check-in", "primaryField": "field1", "page1": {"field2": {"type": "Text", "name": "Volume Objective", "sequence": 2}, "header": "{CARD_DESCRIPTION}", "field1": {"type": "Text", "name": "Account Name", "sequence": 1}, "seq...\nSUMMARY OF THE JOURNEY PLAN'}

# %% [markdown]
# ### Pre-process the file using text pre-processing steps

# %%
# convert case, remove punctuations
# stem the words
stop = stopwords.words('english')
snowball = nltk.SnowballStemmer('english')

def preprocess(toks):
    toks = [ t.lower() for t in toks if t not in string.punctuation ]
    toks = [t for t in toks if t not in stop ]
    toks = [ snowball.stem(t) for t in toks ]
#   toks = [ wnl.lemmatize(t) for t in toks ]
    toks_clean = [ t for t in toks if len(t) >= 3 ]
    return toks_clean

# list of cleaned tokens for the documents
all_streams_cleaned_tokens = []

stream_ids = list(stream_details_dict)

for k in stream_details_dict:
    stream_content = stream_details_dict[k]
    stream_content_tokens = nltk.word_tokenize(stream_content)
    stream_cleaned_tokens = preprocess(stream_content_tokens)
    all_streams_cleaned_tokens.append(stream_cleaned_tokens)

# %% [markdown]
# ### Term frequency for the terms

# %%
len(all_streams_cleaned_tokens)
# Out:
# 113

# %%
# check the frequencies
# perform TF-IDF to get the scores for words for each document
# generate the tags based on the TF-IDF scores
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

all_streams_cleaned_text = [ ' '.join(f) for f in all_streams_cleaned_tokens ]
all_streams_cleaned_text[0]
# Out:
# 'txmak2kzay4 nmeujebo1ac eeutxfhp3go castrol launch strongest ever oil use titanium fluid strengthth set-uptoday\x92 engin effici power led doubl pressur engin oil stronger.th reason buycastrol ... kirnvrufj3i take world-class driver race clone join neuroscientist dr. jack lewi talk need achiev maximum perform track.se next market visit ahomxmbs_no castrol edg titanium trial present clone rival watch clone aston martin vulcan driver darren turner pit ultim rival take titanium strong excit video 0outa7eurbg vp2-cendpt4'

# %%
all_streams_count_vectorizer = CountVectorizer(min_df = 2)
all_streams_tf = all_streams_count_vectorizer.fit_transform(all_streams_cleaned_text)

# %%
all_streams_tf
# Out:
# <113x965 sparse matrix of type '<class 'numpy.int64'>'
# 	with 6838 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### TFIDF vectorizer for the terms

# %%
# And tfidf indexing
all_streams_tfidf_vectorizer = TfidfVectorizer(min_df = 2)
all_streams_tfidf = all_streams_tfidf_vectorizer.fit_transform(all_streams_cleaned_text)
all_streams_tfidf
# Out:
# <113x965 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6838 stored elements in Compressed Sparse Row format>

# %%
len(all_streams_tfidf_vectorizer.vocabulary_)
# Out:
# 965

# %%
(all_streams_tfidf_vectorizer.vocabulary_)
# Out:
# {'000': 0,
#  '000kg': 1,
#  '0outa7eurbg': 2,
#  '10': 3,
#  '100': 4,
#  '120': 5,
#  '123': 6,
#  '16': 7,
#  '18': 8,
#  '1899': 9,
#  '1906': 10,
#  '1968': 11,
#  '1980s': 12,
#  '1st': 13,
#  '2002': 14,
#  '2005': 15,
#  '2012': 16,
#  '2017': 17,
#  '2018': 18,
#  '2safhlj0fgg': 19,
#  '30': 20,
#  '31st': 21,
#  '5hofo': 22,
#  '5w': 23,
#  '88': 24,
#  '9rsws44pdke': 25,
#  '_fmbvrsf4pe': 26,
#  'abl': 27,
#  'abras': 28,
#  'absorb': 29,
#  'accept': 30,
#  'accord': 31,
#  'account': 32,
#  'acea': 33,
#  'achiev': 34,
#  'acid': 35,
#  'acknowledg': 36,
#  'acquir': 37,
#  'acquisit': 38,
#  'across': 39,
#  'action': 40,
#  'activ': 41,
#  'adapt': 42,
#  'add': 43,
#  'address': 44,
#  'adjust': 45,
#  'admin': 46,
#  'advanc': 47,
#  'advocaci': 48,
#  'aft': 49,
#  'ag': 50,
#  'ahomxmbs_no': 51,
#  'allow': 52,
#  'almost': 53,
#  'along': 54,
#  'alreadi': 55,
#  'also': 56,
#  'alway': 57,
#  'ambit': 58,
#  'amount': 59,
#  'amp': 60,
#  'and': 61,
#  'anoth': 62,
#  'answer': 63,
#  'anti': 64,
#  'apart': 65,
#  'app': 66,
#  'appear': 67,
#  'applic': 68,
#  'approv': 69,
#  'arabia': 70,
#  'area': 71,
#  'aris': 72,
#  'around': 73,
#  'arrow': 74,
#  'ask': 75,
#  'assess': 76,
#  'associ': 77,
#  'aston': 78,
#  'attach': 79,
#  'audi': 80,
#  'autom': 81,
#  'automat': 82,
#  'automobil': 83,
#  'automot': 84,
#  'avaiabl': 85,
#  'avail': 86,
#  'averag': 87,
#  'aviat': 88,
#  'away': 89,
#  'back': 90,
#  'badg': 91,
#  'bahrain': 92,
#  'balanac': 93,
#  'balanc': 94,
#  'ball': 95,
#  'band': 96,
#  'banner': 97,
#  'base': 98,
#  'basi': 99,
#  'becom': 100,
#  'began': 101,
#  'behav': 102,
#  'behind': 103,
#  'believ': 104,
#  'benefici': 105,
#  'benefit': 106,
#  'best': 107,
#  'better': 108,
#  'beyond': 109,
#  'black': 110,
#  'block': 111,
#  'boost': 112,
#  'bottom': 113,
#  'brand': 114,
#  'brandcheck': 115,
#  'break': 116,
#  'breakdow': 117,
#  'breakdown': 118,
#  'bring': 119,
#  'british': 120,
#  'brown': 121,
#  'build': 122,
#  'burn': 123,
#  'busi': 124,
#  'buycastrol': 125,
#  'camera': 126,
#  'camp': 127,
#  'campaign': 128,
#  'captur': 129,
#  'car': 130,
#  'card': 131,
#  'card_descri': 132,
#  'card_descript': 133,
#  'case': 134,
#  'cash': 135,
#  'castrol': 136,
#  'catalog': 137,
#  'catalyst': 138,
#  'categ': 139,
#  'categori': 140,
#  'caus': 141,
#  'cendpt4': 142,
#  'center': 143,
#  'centimetr': 144,
#  'central': 145,
#  'ch_2i9dxdsi': 146,
#  'challeng': 147,
#  'chanc': 148,
#  'chang': 149,
#  'charl': 150,
#  'cheaper': 151,
#  'cheapsid': 152,
#  'check': 153,
#  'cheers': 154,
#  'chemic': 155,
#  'cholesterol': 156,
#  'christma': 157,
#  'claim': 158,
#  'class': 159,
#  'clean': 160,
#  'cleanli': 161,
#  'clear': 162,
#  'click': 163,
#  'cling': 164,
#  'clog': 165,
#  'clone': 166,
#  'clutch': 167,
#  'code': 168,
#  'col': 169,
#  'cold': 170,
#  'collect': 171,
#  'colour': 172,
#  'combin': 173,
#  'come': 174,
#  'comment': 175,
#  'common': 176,
#  'compani': 177,
#  'company': 178,
#  'compat': 179,
#  'competit': 180,
#  'complet': 181,
#  'compon': 182,
#  'condit': 183,
#  'congest': 184,
#  'congratul': 185,
#  'connect': 186,
#  'constant': 187,
#  'constructeur': 188,
#  'consum': 189,
#  'contact': 190,
#  'contain': 191,
#  'contamin': 192,
#  'content': 193,
#  'continu': 194,
#  'contrapt': 195,
#  'convent': 196,
#  'convers': 197,
#  'convert': 198,
#  'cool': 199,
#  'corner': 200,
#  'correct': 201,
#  'corrod': 202,
#  'corros': 203,
#  'cost': 204,
#  'could': 205,
#  'countless': 206,
#  'countri': 207,
#  'coupl': 208,
#  'cours': 209,
#  'crb': 210,
#  'creat': 211,
#  'credit': 212,
#  'criteria': 213,
#  'critic': 214,
#  'curios': 215,
#  'custom': 216,
#  'damag': 217,
#  'damage': 218,
#  'dark': 219,
#  'darker': 220,
#  'darren': 221,
#  'date': 222,
#  'day': 223,
#  'dealer': 224,
#  'dec': 225,
#  'deduct': 226,
#  'defi': 227,
#  'defin': 228,
#  'degrad': 229,
#  'deliv': 230,
#  'demand': 231,
#  'demo': 232,
#  'demonstr': 233,
#  'depend': 234,
#  'depress': 235,
#  'des': 236,
#  'describ': 237,
#  'deserv': 238,
#  'design': 239,
#  'detail': 240,
#  'develop': 241,
#  'devic': 242,
#  'diesel': 243,
#  'differ': 244,
#  'dipstick': 245,
#  'dirt': 246,
#  'dirtier': 247,
#  'discret': 248,
#  'display': 249,
#  'distanc': 250,
#  'distributor': 251,
#  'divid': 252,
#  'don': 253,
#  'doubl': 254,
#  'dr': 255,
#  'drain': 256,
#  'dramat': 257,
#  'drive': 258,
#  'driven': 259,
#  'driver': 260,
#  'drop': 261,
#  'drove': 262,
#  'dsr': 263,
#  'due': 264,
#  'duplic': 265,
#  'earli': 266,
#  'earn': 267,
#  'easi': 268,
#  'easili': 269,
#  'economi': 270,
#  'edg': 271,
#  'edge': 272,
#  'edit': 273,
#  'eeutxfhp3go': 274,
#  'effect': 275,
#  'effici': 276,
#  'either': 277,
#  'ellk3pogvd': 278,
#  'emiss': 279,
#  'enabl': 280,
#  'end': 281,
#  'endur': 282,
#  'eng': 283,
#  'engag': 284,
#  'engin': 285,
#  'engine': 286,
#  'enhanc': 287,
#  'enjoy': 288,
#  'enough': 289,
#  'ensur': 290,
#  'enter': 291,
#  'entitl': 292,
#  'entrepreneur': 293,
#  'environ': 294,
#  'equip': 295,
#  'equival': 296,
#  'error': 297,
#  'especi': 298,
#  'essenti': 299,
#  'etc': 300,
#  'europ': 301,
#  'european': 302,
#  'européen': 303,
#  'even': 304,
#  'event': 305,
#  'ever': 306,
#  'everi': 307,
#  'everyday': 308,
#  'exact': 309,
#  'exampl': 310,
#  'excess': 311,
#  'excit': 312,
#  'exclus': 313,
#  'expens': 314,
#  'experi': 315,
#  'expertis': 316,
#  'explain': 317,
#  'expos': 318,
#  'extend': 319,
#  'extent': 320,
#  'extra': 321,
#  'face': 322,
#  'factor': 323,
#  'fail': 324,
#  'fall': 325,
#  'fast': 326,
#  'faster': 327,
#  'feedback': 328,
#  'feel': 329,
#  'field1': 330,
#  'field2': 331,
#  'field3': 332,
#  'field8': 333,
#  'film': 334,
#  'filter': 335,
#  'find': 336,
#  'first': 337,
#  'five': 338,
#  'flag': 339,
#  'flagship': 340,
#  'flight': 341,
#  'flow': 342,
#  'fluid': 343,
#  'focus': 344,
#  'focuss': 345,
#  'foil': 346,
#  'follow': 347,
#  'forc': 348,
#  'ford': 349,
#  'foreign': 350,
#  'form': 351,
#  'format': 352,
#  'formul': 353,
#  'formula': 354,
#  'forth': 355,
#  'forward': 356,
#  'founder': 357,
#  'four': 358,
#  'franchis': 359,
#  'free': 360,
#  'freedom': 361,
#  'fresh': 362,
#  'friction': 363,
#  'fst': 364,
#  'fuel': 365,
#  'fulfil': 366,
#  'full': 367,
#  'function': 368,
#  'garner': 369,
#  'gear': 370,
#  'genuin': 371,
#  'geo': 372,
#  'get': 373,
#  'ggy96ga0ytg': 374,
#  'gift': 375,
#  'give': 376,
#  'glad': 377,
#  'glaze': 378,
#  'global': 379,
#  'gloqo': 380,
#  'go': 381,
#  'goe': 382,
#  'good': 383,
#  'gordon': 384,
#  'got': 385,
#  'govern': 386,
#  'grad': 387,
#  'graviti': 388,
#  'greas': 389,
#  'great': 390,
#  'growth': 391,
#  'gtx': 392,
#  'guarante': 393,
#  'hand': 394,
#  'handl': 395,
#  'happen': 396,
#  'happi': 397,
#  'harder': 398,
#  'harm': 399,
#  'harsh': 400,
#  'head': 401,
#  'header': 402,
#  'headquart': 403,
#  'heat': 404,
#  'heel': 405,
#  'held': 406,
#  'help': 407,
#  'henc': 408,
#  'heritag': 409,
#  'high': 410,
#  'higher': 411,
#  'histor': 412,
#  'histori': 413,
#  'hit': 414,
#  'honey': 415,
#  'hope': 416,
#  'horsepow': 417,
#  'hot': 418,
#  'howev': 419,
#  'hundr': 420,
#  'icon': 421,
#  'idl': 422,
#  'imag': 423,
#  'immedi': 424,
#  'import': 425,
#  'improv': 426,
#  'in': 427,
#  'incas': 428,
#  'incent': 429,
#  'includ': 430,
#  'increas': 431,
#  'incred': 432,
#  'indic': 433,
#  'individu': 434,
#  'indust': 435,
#  'industri': 436,
#  'inform': 437,
#  'inhibitor': 438,
#  'innov': 439,
#  'inquiri': 440,
#  'instal': 441,
#  'instant': 442,
#  'intellig': 443,
#  'interact': 444,
#  'interest': 445,
#  'internati': 446,
#  'interv': 447,
#  'introduc': 448,
#  'involv': 449,
#  'irv': 450,
#  'it': 451,
#  'jack': 452,
#  'join': 453,
#  'journey': 454,
#  'keep': 455,
#  'key': 456,
#  'kind': 457,
#  'kirnvrufj3i': 458,
#  'know': 459,
#  'knowledg': 460,
#  'kuwait': 461,
#  'last': 462,
#  'latest': 463,
#  'launch': 464,
#  'layer': 465,
#  'lead': 466,
#  'learn': 467,
#  'least': 468,
#  'leav': 469,
#  'led': 470,
#  'left': 471,
#  'legisl': 472,
#  'length': 473,
#  'let': 474,
#  'letter': 475,
#  'level': 476,
#  'lewi': 477,
#  'life': 478,
#  'light': 479,
#  'lik': 480,
#  'like': 481,
#  'limit': 482,
#  'line': 483,
#  'liquid': 484,
#  'list': 485,
#  'littl': 486,
#  'load': 487,
#  'local': 488,
#  'login': 489,
#  'london': 490,
#  'long': 491,
#  'longer': 492,
#  'look': 493,
#  'loss': 494,
#  'lot': 495,
#  'love': 496,
#  'low': 497,
#  'lower': 498,
#  'lubric': 499,
#  'luxuri': 500,
#  'made': 501,
#  'magnatec': 502,
#  'magnet': 503,
#  'main': 504,
#  'maintain': 505,
#  'major': 506,
#  'make': 507,
#  'manag': 508,
#  'mani': 509,
#  'manual': 510,
#  'manufactur': 511,
#  'manufacturer': 512,
#  'map': 513,
#  'mar': 514,
#  'mark': 515,
#  'market': 516,
#  'martin': 517,
#  'maximum': 518,
#  'maxsubmiss': 519,
#  'may': 520,
#  'mean': 521,
#  'meant': 522,
#  'measur': 523,
#  'mechan': 524,
#  'meet': 525,
#  'member': 526,
#  'merchandis': 527,
#  'merri': 528,
#  'messag': 529,
#  'met': 530,
#  'metal': 531,
#  'method': 532,
#  'microscop': 533,
#  'mile': 534,
#  'mileag': 535,
#  'million': 536,
#  'miner': 537,
#  'minim': 538,
#  'minimis': 539,
#  'minimum': 540,
#  'minut': 541,
#  'mission': 542,
#  'mobil': 543,
#  'modern': 544,
#  'modifi': 545,
#  'molecul': 546,
#  'moment': 547,
#  'momentari': 548,
#  'momentarili': 549,
#  'month': 550,
#  'motor': 551,
#  'motorcycl': 552,
#  'motoris': 553,
#  'move': 554,
#  'movi': 555,
#  'much': 556,
#  'multi': 557,
#  'multipl': 558,
#  'must': 559,
#  'mutual': 560,
#  'myth': 561,
#  'name': 562,
#  'nasa': 563,
#  'natur': 564,
#  'navig': 565,
#  'necessari': 566,
#  'need': 567,
#  'neuroscientist': 568,
#  'new': 569,
#  'next': 570,
#  'nmeujebo1ac': 571,
#  'no': 572,
#  'normal': 573,
#  'notic': 574,
#  'notifi': 575,
#  'nps': 576,
#  'number': 577,
#  'oem': 578,
#  'of': 579,
#  'offer': 580,
#  'oil': 581,
#  'oilway': 582,
#  'old': 583,
#  'older': 584,
#  'oman': 585,
#  'one': 586,
#  'open': 587,
#  'oper': 588,
#  'opera': 589,
#  'optim': 590,
#  'optimum': 591,
#  'option': 592,
#  'origin': 593,
#  'other': 594,
#  'oubl': 595,
#  'out': 596,
#  'overview': 597,
#  'owe': 598,
#  'owner': 599,
#  'oxid': 600,
#  'oycu07ay5ec': 601,
#  'pack': 602,
#  'packabl': 603,
#  'page1': 604,
#  'paid': 605,
#  'part': 606,
#  'particip': 607,
#  'particl': 608,
#  'particular': 609,
#  'partner': 610,
#  'partnership': 611,
#  'pass': 612,
#  'passeng': 613,
#  'past': 614,
#  'payout': 615,
#  'pcos': 616,
#  'pd9jkfjreni': 617,
#  'peak': 618,
#  'pend': 619,
#  'per': 620,
#  'perform': 621,
#  'performance': 622,
#  'permiss': 623,
#  'permissi': 624,
#  'person': 625,
#  'petroleum': 626,
#  'phase': 627,
#  'photo': 628,
#  'physic': 629,
#  'pick': 630,
#  'pictur': 631,
#  'pioneer': 632,
#  'piston': 633,
#  'pit': 634,
#  'place': 635,
#  'plan': 636,
#  'play': 637,
#  'pleas': 638,
#  'point': 639,
#  'polici': 640,
#  'poor': 641,
#  'pop': 642,
#  'pour': 643,
#  'power': 644,
#  'precis': 645,
#  'premium': 646,
#  'present': 647,
#  'pressur': 648,
#  'prevent': 649,
#  'previous': 650,
#  'primaryfield': 651,
#  'prize': 652,
#  'pro': 653,
#  'probabl': 654,
#  'problem': 655,
#  'produc': 656,
#  'product': 657,
#  'profil': 658,
#  'profit': 659,
#  'program': 660,
#  'programm': 661,
#  'progress': 662,
#  'prompt': 663,
#  'proof': 664,
#  'proper': 665,
#  'proposit': 666,
#  'protec': 667,
#  'protect': 668,
#  'prov': 669,
#  'provid': 670,
#  'provider': 671,
#  'purchas': 672,
#  'push': 673,
#  'qual': 674,
#  'qualiti': 675,
#  'questio': 676,
#  'question': 677,
#  'quick': 678,
#  'quizz': 679,
#  'race': 680,
#  'radio': 681,
#  'rais': 682,
#  'rang': 683,
#  'rea': 684,
#  'reac': 685,
#  'reach': 686,
#  'read': 687,
#  'readi': 688,
#  'realli': 689,
#  'reason': 690,
#  'rec': 691,
#  'receiv': 692,
#  'recent': 693,
#  'reciev': 694,
#  'recommend': 695,
#  'record': 696,
#  'redeem': 697,
#  'redempt': 698,
#  'redu': 699,
#  'reduc': 700,
#  'refer': 701,
#  'refresh': 702,
#  'regul': 703,
#  'regular': 704,
#  'reject': 705,
#  'releas': 706,
#  'reliev': 707,
#  'remain': 708,
#  'remov': 709,
#  'renaut': 710,
#  'rep': 711,
#  'repair': 712,
#  'replac': 713,
#  'repres': 714,
#  'request': 715,
#  'requir': 716,
#  'research': 717,
#  'respect': 718,
#  'respond': 719,
#  'result': 720,
#  'rev': 721,
#  'reward': 722,
#  'ride': 723,
#  'right': 724,
#  'rival': 725,
#  'road': 726,
#  'rob': 727,
#  'role': 728,
#  'rover': 729,
#  'rpxav9ybska': 730,
#  'rub': 731,
#  'runni': 732,
#  'sae': 733,
#  'said': 734,
#  'sale': 735,
#  'saniti': 736,
#  'saudi': 737,
#  'say': 738,
#  'scale': 739,
#  'scheme': 740,
#  'score': 741,
#  'screen': 742,
#  'scroll': 743,
#  'se': 744,
#  'second': 745,
#  'secret': 746,
#  'secs': 747,
#  'section': 748,
#  'secur': 749,
#  'see': 750,
#  'segment': 751,
#  'select': 752,
#  'sell': 753,
#  'seper': 754,
#  'sequenc': 755,
#  'seri': 756,
#  'servic': 757,
#  'set': 758,
#  'sever': 759,
#  'sgr2uevmfgm': 760,
#  'share': 761,
#  'sharpli': 762,
#  'shift': 763,
#  'short': 764,
#  'show': 765,
#  'shuttl': 766,
#  'siev': 767,
#  'signific': 768,
#  'sinc': 769,
#  'singl': 770,
#  'situat': 771,
#  'sludg': 772,
#  'slump': 773,
#  'smaller': 774,
#  'smooth': 775,
#  'smoother': 776,
#  'societi': 777,
#  'solv': 778,
#  'space': 779,
#  'special': 780,
#  'specialti': 781,
#  'specif': 782,
#  'speed': 783,
#  'sponsorship': 784,
#  'squar': 785,
#  'stage': 786,
#  'stand': 787,
#  'standard': 788,
#  'start': 789,
#  'state': 790,
#  'status': 791,
#  'step': 792,
#  'stiffen': 793,
#  'stiletto': 794,
#  'still': 795,
#  'stop': 796,
#  'storag': 797,
#  'stori': 798,
#  'stream': 799,
#  'strength': 800,
#  'strengthth': 801,
#  'stress': 802,
#  'stretch': 803,
#  'strong': 804,
#  'stronger': 805,
#  'strongest': 806,
#  'style': 807,
#  'sub': 808,
#  'subject': 809,
#  'submiit': 810,
#  'submiss': 811,
#  'submit': 812,
#  'substanc': 813,
#  'success': 814,
#  'suitabl': 815,
#  'summari': 816,
#  'sump': 817,
#  'superior': 818,
#  'suppli': 819,
#  'sure': 820,
#  'surfac': 821,
#  'survey': 822,
#  'switch': 823,
#  'symbol': 824,
#  'synthesis': 825,
#  'synthet': 826,
#  'system': 827,
#  'ta4': 828,
#  'tag': 829,
#  'tailor': 830,
#  'take': 831,
#  'talk': 832,
#  'tar': 833,
#  'team': 834,
#  'technolog': 835,
#  'technology': 836,
#  'temperatur': 837,
#  'tend': 838,
#  'term': 839,
#  'termin': 840,
#  'test': 841,
#  'text': 842,
#  'th': 843,
#  'that': 844,
#  'thi': 845,
#  'thick': 846,
#  'thicker': 847,
#  'thin': 848,
#  'thing': 849,
#  'thinner': 850,
#  'thought': 851,
#  'three': 852,
#  'throughout': 853,
#  'thus': 854,
#  'time': 855,
#  'tini': 856,
#  'titanium': 857,
#  'titl': 858,
#  'to': 859,
#  'today': 860,
#  'togeth': 861,
#  'took': 862,
#  'tool': 863,
#  'top': 864,
#  'torqu': 865,
#  'total': 866,
#  'tower': 867,
#  'track': 868,
#  'traff': 869,
#  'traffic': 870,
#  'train': 871,
#  'transact': 872,
#  'transatlant': 873,
#  'transmax': 874,
#  'transmiss': 875,
#  'transmit': 876,
#  'transport': 877,
#  'travel': 878,
#  'tri': 879,
#  'trial': 880,
#  'tribe': 881,
#  'truck': 882,
#  'true': 883,
#  'trust': 884,
#  'turn': 885,
#  'turner': 886,
#  'twice': 887,
#  'two': 888,
#  'txmak2kzay4': 889,
#  'typ': 890,
#  'type': 891,
#  'uae': 892,
#  'ultim': 893,
#  'understand': 894,
#  'uniqu': 895,
#  'unt': 896,
#  'untreat': 897,
#  'untru': 898,
#  'up': 899,
#  'updat': 900,
#  'upload': 901,
#  'upon': 902,
#  'upto': 903,
#  'uptoday': 904,
#  'use': 905,
#  'user': 906,
#  'usual': 907,
#  'valid': 908,
#  'valu': 909,
#  'variant': 910,
#  'varieti': 911,
#  'vecton': 912,
#  'vehicl': 913,
#  'vehicle': 914,
#  'victorinox': 915,
#  'video': 916,
#  'view': 917,
#  'viscos': 918,
#  'viscosi': 919,
#  'vision': 920,
#  'visit': 921,
#  'vital': 922,
#  'void': 923,
#  'volkswagen': 924,
#  'volum': 925,
#  'volvo': 926,
#  'vouch': 927,
#  'voucher': 928,
#  'vp2': 929,
#  'vulcan': 930,
#  'wait': 931,
#  'wakefield': 932,
#  'want': 933,
#  'warm': 934,
#  'warn': 935,
#  'warranti': 936,
#  'watch': 937,
#  'water': 938,
#  'way': 939,
#  'we': 940,
#  'wear': 941,
#  'weather': 942,
#  'welcom': 943,
#  'well': 944,
#  'wheel': 945,
#  'whilst': 946,
#  'win': 947,
#  'winner': 948,
#  'wish': 949,
#  'wit': 950,
#  'withstand': 951,
#  'won': 952,
#  'word': 953,
#  'work': 954,
#  'workin': 955,
#  'workshop': 956,
#  'world': 957,
#  'worn': 958,
#  'would': 959,
#  'year': 960,
#  'yellowish': 961,
#  'yes': 962,
#  'yet': 963,
#  'zoom': 964}

# %%
token_values = {all_streams_tfidf_vectorizer.vocabulary_[token]: token for token in all_streams_tfidf_vectorizer.vocabulary_}

# %%
all_streams_tfidf.shape
# Out:
# (113, 965)

# %%
all_streams_tfidf_coo = all_streams_tfidf.tocoo()
len(all_streams_tfidf_coo.row)
# Out:
# 6838

# %%
len(all_streams_tfidf_coo.col)
# Out:
# 6838

# %%
similarities = cosine_similarity(all_streams_tfidf)

# %%
type(similarities)
# Out:
# numpy.ndarray

# %%
similarities.shape
# Out:
# (113, 113)

# %%
K = 5

# %%
cosine_similar_streams = {}
for original_stream_index, cosine_similarities in enumerate(similarities):
    cosine_similar_streams[stream_ids[original_stream_index]] = []
    most_similar_stream_indices = np.argsort(cosine_similarities)[-K:]
    for similar_stream_index in most_similar_stream_indices:
        cosine_similar_streams[stream_ids[original_stream_index]].append(stream_ids[similar_stream_index])
 
cosine_similar_streams
# Out:
# {'1089': ['2034', '2035', '1128', '2010', '1089'],
#  '1090': ['316', '202', '2281', '2436', '1090'],
#  '1095': ['523', '199', '233', '2408', '1095'],
#  '1128': ['1089', '1644', '2512', '2401', '1128'],
#  '1267': ['2033', '2376', '1661', '201', '1267'],
#  '1347': ['202', '1499', '1512', '1655', '1347'],
#  '1498': ['2405', '2380', '199', '2265', '1498'],
#  '1499': ['1659', '2374', '2381', '2266', '1499'],
#  '1512': ['2062', '1662', '2523', '1499', '1512'],
#  '163': ['507', '1498', '199', '419', '163'],
#  '1644': ['1128', '2062', '2401', '1644', '2512'],
#  '1655': ['316', '202', '1512', '1347', '1655'],
#  '1658': ['2380', '2265', '2405', '2373', '1658'],
#  '1659': ['2031', '2266', '2381', '2374', '1659'],
#  '1660': ['2375', '2407', '2267', '2382', '1660'],
#  '1661': ['2033', '2376', '1267', '201', '1661'],
#  '1662': ['622', '1512', '624', '2062', '1662'],
#  '1670': ['2038', '2382', '2032', '2267', '1670'],
#  '1857': ['232', '475', '316', '202', '1857'],
#  '199': ['2380', '2405', '2265', '1498', '199'],
#  '2003': ['2112', '2248', '2116', '2115', '2003'],
#  '2006': ['2003', '2248', '2111', '2112', '2006'],
#  '201': ['2033', '2376', '1661', '1267', '201'],
#  '2010': ['1089', '2034', '2105', '2035', '2010'],
#  '202': ['2376', '2597', '316', '202', '475'],
#  '203': ['2374', '2037', '245', '2031', '203'],
#  '2030': ['2265', '1498', '2104', '2036', '2030'],
#  '2031': ['203', '2266', '2103', '2037', '2031'],
#  '2032': ['2267', '1670', '2102', '2038', '2032'],
#  '2033': ['201', '1661', '2039', '2101', '2033'],
#  '2034': ['1089', '2010', '2035', '2034', '2105'],
#  '2035': ['1089', '2010', '2035', '2034', '2105'],
#  '2036': ['2265', '1498', '2104', '2030', '2036'],
#  '2037': ['2381', '2266', '2103', '2031', '2037'],
#  '2038': ['2267', '1670', '2102', '2032', '2038'],
#  '2039': ['1661', '2376', '2033', '2101', '2039'],
#  '205': ['2032', '2382', '1670', '2267', '205'],
#  '206': ['2267', '205', '1498', '199', '206'],
#  '2062': ['2401', '1644', '2512', '1662', '2062'],
#  '2101': ['1661', '2376', '2033', '2101', '2039'],
#  '2102': ['205', '1670', '2038', '2032', '2102'],
#  '2103': ['2381', '2031', '2266', '2037', '2103'],
#  '2104': ['2265', '1498', '2030', '2036', '2104'],
#  '2105': ['1089', '2010', '2035', '2034', '2105'],
#  '2111': ['2003', '2248', '2006', '2111', '2112'],
#  '2112': ['2003', '2248', '2006', '2111', '2112'],
#  '2115': ['2112', '2248', '2003', '2116', '2115'],
#  '2116': ['2112', '2003', '2115', '2248', '2116'],
#  '2248': ['2112', '2003', '2115', '2116', '2248'],
#  '2265': ['2405', '199', '2380', '1498', '2265'],
#  '2266': ['1659', '2103', '2037', '2381', '2266'],
#  '2267': ['2407', '205', '1670', '1660', '2267'],
#  '2281': ['1090', '475', '316', '202', '2281'],
#  '229': ['236', '2513', '237', '417', '229'],
#  '230': ['548', '2401', '230', '236', '2513'],
#  '231': ['2030', '199', '2036', '1498', '231'],
#  '232': ['2266', '2037', '2031', '233', '232'],
#  '233': ['2037', '2550', '2266', '232', '233'],
#  '236': ['548', '2401', '230', '236', '2513'],
#  '237': ['236', '2513', '237', '417', '229'],
#  '2373': ['1658', '2265', '2380', '2405', '2373'],
#  '2374': ['2031', '2266', '2381', '1659', '2374'],
#  '2375': ['2382', '2267', '1660', '2407', '2375'],
#  '2376': ['2101', '1267', '201', '1661', '2376'],
#  '2377': ['2034', '2105', '2435', '1089', '2377'],
#  '2380': ['2373', '1498', '2265', '2405', '2380'],
#  '2381': ['2037', '2374', '2266', '1659', '2381'],
#  '2382': ['2407', '2267', '1670', '1660', '2382'],
#  '2392': ['548', '2401', '364', '2511', '2392'],
#  '2401': ['230', '236', '2513', '1128', '2401'],
#  '2405': ['1498', '2373', '2265', '2380', '2405'],
#  '2406': ['2103', '1659', '2266', '2381', '2406'],
#  '2407': ['1670', '2375', '2267', '1660', '2407'],
#  '2408': ['199', '203', '233', '1095', '2408'],
#  '2409': ['199', '524', '427', '426', '2409'],
#  '2433': ['548', '2511', '2401', '2433', '2525'],
#  '2434': ['2062', '624', '524', '1662', '2434'],
#  '2435': ['2523', '2034', '2105', '2035', '2435'],
#  '2436': ['1090', '2033', '2101', '2039', '2436'],
#  '244': ['2380', '2265', '2405', '1658', '244'],
#  '2444': ['202', '244', '2115', '2597', '2444'],
#  '245': ['1659', '2266', '2374', '203', '245'],
#  '246': ['2375', '1670', '2267', '205', '246'],
#  '2511': ['236', '2513', '230', '548', '2511'],
#  '2512': ['1128', '2062', '2401', '1644', '2512'],
#  '2513': ['548', '2401', '230', '236', '2513'],
#  '2523': ['2035', '2105', '2377', '2435', '2523'],
#  '2525': ['548', '2511', '2401', '2433', '2525'],
#  '2550': ['2382', '1660', '2267', '2407', '2550'],
#  '2597': ['316', '202', '2373', '244', '2597'],
#  '316': ['2376', '2597', '316', '202', '475'],
#  '364': ['230', '2513', '236', '548', '364'],
#  '417': ['236', '2513', '237', '417', '229'],
#  '419': ['507', '1498', '199', '419', '163'],
#  '426': ['199', '2373', '427', '2409', '426'],
#  '427': ['523', '578', '426', '2409', '427'],
#  '475': ['2376', '2597', '316', '202', '475'],
#  '507': ['1498', '2380', '2405', '2373', '507'],
#  '519': ['578', '523', '524', '519', '561'],
#  '521': ['578', '523', '558', '565', '521'],
#  '522': ['524', '523', '578', '522', '570'],
#  '523': ['2103', '2550', '558', '523', '578'],
#  '524': ['519', '561', '523', '578', '524'],
#  '548': ['230', '2513', '2401', '634', '548'],
#  '558': ['2381', '206', '523', '578', '558'],
#  '561': ['578', '523', '524', '519', '561'],
#  '565': ['578', '523', '558', '565', '521'],
#  '570': ['524', '523', '578', '522', '570'],
#  '578': ['2103', '2550', '558', '523', '578'],
#  '622': ['2032', '2267', '205', '1670', '622'],
#  '623': ['245', '2037', '2031', '203', '623'],
#  '624': ['2265', '199', '2380', '2405', '624'],
#  '634': ['230', '236', '2513', '548', '634']}

# %%
print(stream_details_dict['1089'])
print("Stream 2034")
print(stream_details_dict['2034'])
print("Stream 2035")
print(stream_details_dict['2035'])
# Out:
# Welcome Team! Were really glad you are part of this journey!  In this stream you will find out more about the program and its fantastic benefits.   But first, scroll to the next card to complete a small survey, to help us guide your ...
# This tool is used to capture the brand survey information.       "On a scale of 1-10, how likely are you to recommend a Castrol brand to a customer?"         You cannot edit this c...
#
#
# {"title": "Brand Survey", "primaryField": "field1", "page1": {"header": "{CARD_DESCRIPTION}", "field1": {"type": "Text", "name": "NPS Score", "sequence": 1}, "sequence": 1}, "maxSubmissions": 1}
# This 123 App is your portal to stay  connected and up-to-date  with Castrol brands and promos.   You will be refreshed with the right information, to enable the best sales conversations.   By interacting wit...
# Up-to-date   knowledge on Castrol Brand 123 messaging
# Interactive quizzes to let you   track your progress   and growth
# Badges and Competitions that entitle you to   great gifts and rewards!
# The Castrol Zoom App provides interactive information, competitions and rewards on all things Castrol!      Enjoy the journey!
# EllK3pOGVds
# Welcome Team! Were really glad you are part of this journey!  Castrol Zoom is your mobile app for all information and tools about Castrol.    Earn points &amp; redeem rewards by interacting with the co...
# Welcome Team! Were really glad you are part of this journey!  Castrol Zoom is your mobile app for all information and tools about Castrol.    Earn points &amp; redeem rewards by interacting with the co...
# Up-to-date   knowledge on Castrol Brand 123 messaging
# Interactive quizzes to let you   track your progress   and growth
# Sales incentives   and brand points rewarded immediately.
# Badges and Competitions that entitle you to   great gifts and rewards!
# EllK3pOGVds
# Welcome Team! Were really glad you are part of this journey!  Castrol Zoom is your mobile app for all information and tools about Castrol.    Earn points &amp; redeem rewards by interacting with the co...
# Welcome Team! Were really glad you are part of this journey!  Castrol Zoom is your mobile app for all information and tools about Castrol.    Earn points &amp; redeem rewards by interacting with the co...
# Up-to-date   knowledge on Castrol Brand 123 messaging
# Interactive quizzes to let you   track your progress   and growth
# Sales incentives   and brand points rewarded immediately.
# Badges and Competitions that entitle you to   great gifts and rewards!
